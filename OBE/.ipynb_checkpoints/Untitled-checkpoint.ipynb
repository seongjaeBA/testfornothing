# %%
import os
import pandas as pd
import numpy as np

# %%
def age_to_numeric(x):
    if x=='초1':
        return 1
    if x=='초2':
        return 2
    if x=='초3':
        return 3
    if x=='초4':
        return 4
    if x=='초5':
        return 5
    if x=='초6':
        return 6
    if x=='중1':
        return 7
    
def ID_to_IDNum(x):
    temp = str(x).strip().split('_')
    if len(temp) < 2:
        return np.nan
    return int(temp[2])

# %%
list_child = pd.read_csv('./data/list.csv', encoding = "euc_kr", na_values = 'empty')
list_child['IDNum'] = list_child['UID'].apply(ID_to_IDNum)
list_child['AgeNum'] = list_child['Age'].apply(age_to_numeric)

data_fnirs = pd.read_csv('./data/fnirs_feature_0322.csv', encoding = "euc_kr", na_values = 'empty')
data_fnirs['age_num'] = data_fnirs['fnirs_age'].apply(age_to_numeric)
data_fnirs.rename({'fnirs_idnum' : 'IDNum'}, inplace = True, axis = 'columns')

# data_fnirs = pd.read_csv('./data/ex_csv.csv', encoding = "euc_kr", na_values = 'empty')
# data_fnirs['age_num'] = data_fnirs['fnirs_basic_age'].apply(age_to_numeric)
# data_fnirs.rename({'fnirs_idnum' : 'IDNum'}, inplace = True, axis = 'columns')

data_meta = pd.read_excel('./data/total_meta.xlsx', encoding = "euc_kr", na_values = 'empty')
data_meta['IDNum'] = data_meta['아동연구번호'].apply(ID_to_IDNum)
data_meta['AgeNum'] = data_meta['학년_1'].apply(age_to_numeric)

# %%
data_fnirs.columns

# %%
data_meta.columns

# %%
data_meta = data_meta.drop(['검사장소', '아동연구번호', '아동명', '성별_1','학년', '학년_1',
       '생년월일', '연령(만:개월)', '연령 월', '검사자', 
       'CCTT-1_%ile', 
       'CCTT-2_%ile', '간섭지표A_Raw Socre', '간섭지표A_%ile', '간섭지표B_Raw Socre',
       '간섭지표B_T Score', '간섭지표B_%ile', 'cong acc', 'cong rt',
       'incong acc', 'incog_rt', 'Unnamed: 44', 'Unnamed: 45',
       ], axis=1)
data_meta.columns

# %%
eng_index = ['no', 'date', 'sex', 'age', 'DSF', 'LDSF', 'DSB', 'LDSB',
       'DS_Raw_score', 'DS_T_score', 'type', 'Coding_Raw_score', 'Coding_T_score',
       'SymbolSearchRaw_score', 'SymbolSearch_T_score', 'CCTT1_Raw_score',
       'CCTT1_T_score', 'CCTT2_Raw_socre', 'CCTT2_T_score',
       'CBTTF_acc', 'CBTTB_acc',             
       'GNG_acc', 'GNG_rt',
       'STROOP_acc', 'STROOP_rt', 'TWOBACK_acc',
       'TWOBACK2_rt','IDNum', 'grade' ]


data_meta.columns = eng_index


data_meta.describe()

# %%
data_meta.shape

# %%
data_meta.dropna(subset=['no'])

# %%
data_fnirs['fnirs_task'].unique()

# %%
print(set(data_fnirs['fnirs_task']))

# %%
print(data_fnirs['fnirs_task'].unique())

# %%
#task 별 fnirs 데이터
for task in set(data_fnirs['fnirs_task']):
    task_list[task - 1] =  data_fnirs.query('fnirs_task == "' + task + '"')
    
    if '' in task.fnirs_task and '' in task.fnirs_task:

# %%
# markerinfo = 'LV1/0/1111/1200'

for markerinfo in set(data['marker']):
    marker = markerinfo.split('/')
    perform_data[level] = marker[0]
    perform_data[correct] = marker[1]
    perform_data[action] = marker[2]
    perform_data[rt] = marker[3]

#     for i in range(0,4):
#         print(marker[i])

# %%
task_list = ['CBTTF', 'CBTTB', 'GNG', 'TWOBACK', 'STRC', 'STRI', 'REPEAT', 'MIND', 'FOLD']

# %%
path = os.getcwd()
file = os.path.join(path, "data", 'WJ_may_3rd_PerfMarker.xlsx')

for i in range(len(task_list)):
    Task[task_list[i]] = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[i], header=0).T.dropna(how = 'all')
    Task[task_list[i]] = pd.DataFrame.from_dict(Task[task_list[i]])
    Task[task_list[i]] = Task[task_list[i]].replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['', '', ''])
    
    
# CBTTF1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[0], header=0).T
# CBTTB1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[1], header=0).T 
# GNG1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[2], header=0).T 
# TWOBACK1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[3], header=0).T 
# STRC1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[4], header=0).T 
# STRI1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[5], header=0).T 
# REPEAT1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[6], header=0).T 
# MIND1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[7], header=0).T
# FOLD1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[8], header=0).T

# CBTTF = CBTTF1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# CBTTB = CBTTB1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# GNG = GNG1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# TWOBACK = TWOBACK1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# STRC = STRC1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# STRI = STRI1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# REPEAT = REPEAT1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# MIND = MIND1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])
# FOLD = FOLD1.replace(['TASKMARKER\r', '<missing>','OUTTOUCH\r'],['','',''])

# %%
Cor_list = []
RT = []
for i in range(len(FOLD1.index)):
    Cor = 0
    RT_list = []
    for j in range(len(FOLD1.columns)):
        marker = FOLD1[j][i].split('/')
        if 'LV' in marker[0]:
            Cor += int(marker[1])
        else:
            continue
            
        if '1' in marker[1]:
            RTint = int(marker[3][:-1])
            RT_list.append(RTint)

    Cor_list.append(Cor)
    if len(RT_list) is not 0:
        RT.append(sum(RT_list) / len(RT_list))
    else:
        RT.append(0)

## 빈 colunmn이 있어서 유효하지 않음
# ACC_list = [x / len(FOLD1.columns) for x in Cor_list]
ACC_list = [x / 14 for x in Cor_list]


FOLD['Cor'] = Cor_list
FOLD['ACC'] = ACC_list
FOLD['RT'] = RT

FOLD.describe()

# %%
task_list = ['REST', 'CBTTF', 'CBTTB', 'GNG', 'TWOBACK', 'STRC', 'STRI', 'REPEAT', 'MIND', 'FOLD']

# %%
import os
import math
import pandas as pd
import numpy as np
import requests
from requests.auth import HTTPBasicAuth

# %%
Task = {}

path = os.getcwd()
# file = os.path.join(path, "data", 'sj_perforamance.xls')
file = os.path.join(path, "data", 'output1.xlsx')

for i in range(len(task_list)):
    Task[task_list[i]] = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[i], header=None).T.dropna(how = 'all')
    Task[task_list[i]] = pd.DataFrame.from_dict(Task[task_list[i]])
    Task[task_list[i]] = Task[task_list[i]].replace(['TASKMARKER','OUTTOUCH'],[np.nan, np.nan]).dropna(axis = 1, how = 'all')
    Task[task_list[i]] = Task[task_list[i]].fillna('damm')
    
# print(Task['CBTTF'])
print(Task['STRC'].index)

## 위의 for loop로 해결
# ALL = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[0], header=0).T.dropna(how = 'all')
# CBTTF1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[1], header=0).T.dropna(how = 'all')
# CBTTB1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[2], header=0).T.dropna(how = 'all')
# GNG1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[3], header=0).T.dropna(how = 'all') 
# TWOBACK1 = pd.read_ex-05cel(open(file, 'rb'), sheet_name = '%s' % task_list[4], header=0).T.dropna(how = 'all') 
# STRC1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[5], header=0).T.dropna(how = 'all') 
# STRI1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[6], header=0).T.dropna(how = 'all') 
# REPEAT1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[7], header=0).T.dropna(how = 'all') 
# MIND1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[8], header=0).T.dropna(how = 'all')
# FOLD1 = pd.read_excel(open(file, 'rb'), sheet_name = '%s' % task_list[9], header=0).T.dropna(how = 'all')


# CBTTF = CBTTF1.replace(['TASKMARKER','OUTTOUCH'],['', ''])
# CBTTB = CBTTB1.replace(['TASKMARKER', 'OUTTOUCH'],['', ''])
# GNG = GNG1.replace(['TASKMARKER','OUTTOUCH'],['', ''])
# TWOBACK = TWOBACK1.replace(['TASKMARKER','OUTTOUCH'],['', ''])
# STRC = STRC1.replace(['TASKMARKER','OUTTOUCH'],['', ''])
# STRI = STRI1.replace(['TASKMARKER','OUTTOUCH'],['', ''])
# REPEAT = REPEAT1.replace(['TASKMARKER','OUTTOUCH'],['', ''])
# MIND = MIND1.replace(['TASKMARKER','OUTTOUCH'],['', ''])
# FOLD = FOLD1.replace(['TASKMARKER','OUTTOUCH'],['', ''])

# %%
path = os.getcwd()
file = os.path.join(path, "data", 'wj_list.xlsx')
List = pd.read_excel(open(file, 'rb'), header=0)

for task in task_list:
    pack = pd.DataFrame(Task[task][0])
    idx = Task[task].index
    print(idx)
    print(col)
    col = Task[task].columns
    if 'GNG' in task or 'TWOBACK' in task or 'STRC' in task or 'STRI' in task  or 'FOLD' in task:
        Cor_list = []
        RT = []
        Acc =[]
        for i in idx:
            Cor = 0
            LV = 0
            RT_list = []
            for j in col:
                if Task[task][j][i] == 'damm':
                    pass
                else:     
                    marker = Task[task][j][i].split('/')
                if 'LV' in marker[0]:
                    Cor += int(marker[1])
                    LV += 1
                else:
                    continue
            
#                 print(marker)
                if int(marker[3]) < 2000 :
                    if '1-1' in marker[2]:
                        RTint = int(marker[3])
                        RT_list.append(RTint)
            Cor_list.append(Cor)
            if len(RT_list) is not 0:
                RT.append(sum(RT_list) / len(RT_list))
            else:
                RT.append(0)
            
            Acc.append(Cor/LV)
            
        ## 빈 colunmn이 있어서 유효하지 않음
        pack['%s_Cor' % task] = Cor_list
        pack['%s_RT' % task] = RT
        pack['%s_ACC' % task] = Acc

   
        print(task)
        print('정답률, 반응시간')
        
        
    elif 'CBTTF' in task or 'CBTTB' in task or 'MIND' in task or 'REPEAT' in task:
        Cor_list = []
        for i in idx:
            Cor = 0
            LV = 0
            for j in col:
                if Task[task][j][i] == 'damm':
                    pass
                else:
#             
                    marker = Task[task][j][i].split('/')
                
                if 'LV' in marker[0]:
                    Cor += int(marker[1])
                    LV += 1
                else:
                    continue

            Cor_list.append(Cor)

        ACC_list = [x / LV for x in Cor_list]
        pack['%s_Cor' % task] = Cor_list
        pack['%s_ACC' % task] = ACC_list
        
        print(task)
        print('정답률')
        
    else:
        print(task)
        print('pass')
        pass
    List = List.merge(pack, left_on='name', right_on=0 , how = 'outer')

List.pop('0_x')
List.pop('0_y')
List.to_excel('Result1.xlsx')

# %%
import os
import datetime
import requests
import math
import pandas as pd
import numpy as np
from requests.auth import HTTPBasicAuth
# from datetime import date
# from datetime import datetime


def data_merge(WJ_list = 'wj_list', raw_file = 'output', merge = 'merge'):
    """
        작성자: sjyoo
        작성일: 190612
        기능: list와 raw 파일 AVG, RT 등을 merge
        입력: 데이터 table <- 지금은 excel file
        출력: C:/Users/OBELAB_JH_DESKTOP/Documents/GitHub/testfornothing/OBE/data/ ~~ xlsx파일
        용례: data_merge(리스트, 로우 데이타, 멀지 아웃풋)
        배고프네...
    """
    Task = {}
    task_list = ['REST', 'CBTTF', 'CBTTB', 'GNG', 'TWOBACK', 'STRC', 'STRI', 'REPEAT', 'MIND', 'FOLD']

    path = os.getcwd()
    print('merge 시작')
    # file = os.path.join(path, "data", 'sj_perforamance.xls')
    f1 = os.path.join(path, "data", raw_file + '.xlsx')
    f2 = os.path.join(path, "data", WJ_list + '.xlsx')
    List = pd.read_excel(open(f2, 'rb'), header=0)

    for i in range(len(task_list)):
        Task[task_list[i]] = pd.read_excel(open(f1, 'rb'), sheet_name = '%s' % task_list[i], header=None).T.dropna(how = 'all')
        Task[task_list[i]] = pd.DataFrame.from_dict(Task[task_list[i]])
        Task[task_list[i]] = Task[task_list[i]].replace(['TASKMARKER','OUTTOUCH', 'TASKMARKER\r','OUTTOUCH\r'],['', '', '', '']).dropna(axis = 1, how = 'all')
        Task[task_list[i]] = Task[task_list[i]].fillna('damm')
        


    for task in task_list:
#         print(Task[task])
        print(task)
        pack = pd.DataFrame(Task[task][0])
        idx = Task[task].index
        # print(idx)
        # print(col)
        col = Task[task].columns
        
        if 'GNG' in task or 'TWOBACK' in task or 'STRC' in task or 'STRI' in task:
            Cor_list = []
            RT = []
            Acc =[]
#             print(Task[task])
            for i in idx:
                Cor = 0
                LV = 0
                RT_list = []
                for j in col:
                    if Task[task][j][i][:2] == 'LV':
                        marker = Task[task][j][i].split('/')
                        if 'LV' in marker[0]:
                            Cor += int(marker[1])
                            LV += 1
                            if '1-1' in marker[2]:
                                if int(marker[3]) < 2000 :
                                    RTint = int(marker[3])
                                    RT_list.append(RTint)
                        else:
                            continue
                    else:
                        pass
                 
                Cor_list.append(Cor)
                if len(RT_list) is not 0:
                    RT.append(sum(RT_list) / len(RT_list))
                else:
                    RT.append(0)
                
                Acc.append(Cor/LV)
                
            pack['%s_Cor' % task] = Cor_list
            pack['%s_RT' % task] = RT
            pack['%s_ACC' % task] = Acc
            print('정답률, 반응시간')
            print('과제 완료')
            
            
        elif 'CBTTF' in task or 'CBTTB' in task or 'MIND' in task or 'REPEAT' in task or 'FOLD' in task:
            Cor_list = []
            Acc =[]
            for i in idx:
                Cor = 0
                LV = 0
                for j in col:
                    if Task[task][j][i][:2] == 'LV':
                        marker = Task[task][j][i].split('/')
                        if 'LV' in marker[0]:
                            Cor += int(marker[1])
                            LV += 1
                        else:
                            continue
                    else:
                        pass

                Cor_list.append(Cor)
                if LV == 0:
                    Acc.append(0)
                else:
                    Acc.append(Cor/LV)
            
            pack['%s_Cor' % task] = Cor_list
            pack['%s_ACC' % task] = Acc
            print('정답률')
            print('과제 완료')
            
        else:
            print('과제 pass')
            pass
        List = List.merge(pack, left_on='name', right_on=0 , how = 'outer')

    List.pop('0_x')
    List.pop('0_y')
    List.to_excel(merge + '.xlsx')
    print('완료')
    return
    
def raw_to_LVAn(raw):
    marker = raw[raw].split('/')
    print(marker)
    # level_anlaysis = raw.pivot(columns = 'childName', values = 'raw')
    return

def raw_to_data(raw, output = 'output'):
    """
        작성자: sjyoo
        작성일: 190611
        기능: table을 분석용 파일로 내보내기(data.to_csv(sj_performance))
        입력: raw table(dataframe), output = export data name
        출력: excel file('C:/Users/OBELAB_JH_DESKTOP/Documents/GitHub/testfornothing/OBE/data/xxxx.xlsx)
        용례: data = raw_to_data(pandas DataFrame(raw), str(output))
    """
    task_num = raw['taskType'].unique()
    tasks = {1:'REST',2:'CBTTF',3:'CBTTB',4:'GNG',5:'TWOBACK',6:'STRC',7:'STRI',8:'VFT',9:'REPEAT',10:'MIND',11:'FOLD'}
    with pd.ExcelWriter('C:/Users/OBELAB_JH_DESKTOP/Documents/GitHub/testfornothing/OBE/data/'+ output + '.xlsx') as writer:
        for task in task_num:
            task_ind = raw.query('taskType == "' + task +'"')
#             data = task_ind.pivot(columns = 'childName', values = 'raw')
#             print(task_ind)
#             data = pd.pivot_table(task_ind, index = 'index', columns = 'childName', values = 'raw', aggfunc=np.sum, margins = True)
            data = pd.pivot_table(task_ind, index = 'index', columns = 'childName', values = 'raw', aggfunc=np.sum)
#             print(data)
            data.to_excel(writer, sheet_name=tasks[int(task)], index = None)
            print('%s  실행' % task)
    return 

def request_to_table(url, uuid, my_id, my_pw):
    """
        작성자: cmlee
        수정자: sjyoo
        작성일: 190509
        수정일: 190611 
        기능: 요청 정보를 이용해서 서버에서 데이터 테이블 형태로 반환
        입력: url, id, pw, taskuuid
        출력: pandas DataFrame : header + contents
        용례: raw = request_to_table(str(api_url), str(uuid)/ list(uuid), str(my_id), str(my_pw))
    """
    raw = pd.DataFrame()
    print('table 요청 시작')
    for child in uuid:
#         print(child)
        url_uuid = url + '?taskUUID=' + child
        r = requests.get(url=url_uuid, auth=HTTPBasicAuth(my_id, my_pw))
        r = r.content.decode("utf-8")
        r = r.split('\n')
        t_head = r.pop(0).split(',')
        t_head[-1] = t_head[-1][0:-1]
        t_body = [t.split(',') for t in r if t != '']
        data = pd.DataFrame(t_body, columns=t_head)
        data = data[data.taskUUID != '']
        # print(data)
        raw = pd.concat([data, raw], axis=0)
        print('%s 완료' % child)
    print("raw export 완료")
    return raw

def access_to_table(connect_info, uuid, table = 'uuid'):
    """
        작성자: sjyoo
        작성일: 190611
        기능: table 접속
        입력: connect_info: id, pw; uuid = taskuuid; table = 받고 싶은 데이터 table
        출력: pandas DataFrame : 현재는 performance 
        용례: raw = access_to_table(connect_info, uuid, table = 'uuid'&'raw'&'perf')
    """
    # base_url = 'http://ec2-15-164-48-95.ap-northeast-2.compute.amazonaws.com'
    base_url = 'http://obelab-api.com'
    api_uuid = base_url + '/api/analysis/taskuuid/'
    api_raw = base_url + '/api/analysis/metaraw/'
    api_perf = base_url + '/api/analysis/metamarker/'
    print('table access 시작')
    if table == 'uuid':
        return request_to_table(api_uuid, uuid, connect_info[0], connect_info[1])
    elif table == 'raw':
        return request_to_table(api_raw, uuid, connect_info[0], connect_info[1])
    elif table == 'perf':
        return request_to_table(api_perf, uuid, connect_info[0], connect_info[1])
    print("raw 완료")


def get_UUID(connect_info, date1 = '2000-01-01', date2 = '2030-01-01'):
    """
        작성자: sjyoo
        작성일: 190612
        기능: date로 아이디 뽑아내기. UUID 뽑을 거임.
        입력: 접속 정보, 시작일, 종료일
        출력: uuid 리스트
        용례: get_UUID(접속정보, 시작일, 종료일)
    """
    base_url = 'http://obelab-api.com'
    api_uuid = base_url + '/api/analysis/taskuuid/'

    uuid = pd.DataFrame()
    #지금은 다 불러와서 date로 filtering
    r = requests.get(url=api_uuid, auth=HTTPBasicAuth(connect_info[0], connect_info[1]))
    r = r.content.decode("utf-8")
    r = r.split('\n')
    t_head = r.pop(0).split(',')
    t_head[-1] = t_head[-1][0:-1]
    t_body = [t.split(',') for t in r]
    data = pd.DataFrame(t_body, columns=t_head)
    return data.query('taskCreated >= "' + date1 + '" and taskCreated <= "' + date2 +'"')

def server_connect_info():
    my_id = 'admin'
    my_pw = 'obe1234'

    return my_id, my_pw


if __name__ == "__main__":
    '''
        data_merge 에서 주소 수정하여 사용할 것.
        wj_list를 받을 방법도 생각할 것.
        용례 적어둘 것.
    '''
    connect_info = server_connect_info()
#     p_list = get_UUID(connect_info, '2019-05-24', '2019-06-10')
#     print(p_list)
#     target_child = p_list.taskUUID
#     target_child.drop(228)
#     print(target_child)
    target_child = ['Z47JwYOM'] 
#     target_child = ['ETMt9ghG', '4cCiSclJ', 'DTYMwUxL', 'QtKK7sCe', 'mZrzoY7s', 'byNKiAgk', 'zAQDxtWQ', 'i0FQPTiI', 
#     'eJURms0y', 'rKkMbuyf', '0FAE54zl', 'YFF4zQ1e', 'PEapshgr', '6hD3Z95T', 'FzF7DQcB', 'KO6fD1ut', 'VJBd04EA', '5I783px6', 'AqQKUZpj', 'B48dNhx8',
#     'W0UGkIyx', 'xZ7fS5mu', 'Y7yIkcbO', 'H7Ei5cjf', 'PqNn2Db6']
    print('명단 완료')
    raw = access_to_table(connect_info = connect_info, uuid=target_child, table = 'perf') #한예준
#     print(raw)
#     raw_to_LVAn(raw)
    raw_to_data(raw, '박혜빈')
    data_merge('wj_list', '박혜빈', 'Result_박혜빈')
# Out:
# 명단 완료
# table access 시작
# table 요청 시작
# Z47JwYOM 완료
# raw export 완료
# 1  실행
# 2  실행
# 3  실행
# 4  실행
# 5  실행
# 6  실행
# 7  실행
# 8  실행
# 9  실행
# 10  실행
# 11  실행
# merge 시작
# REST
# 과제 pass
# CBTTF
# 정답률
# 과제 완료
# CBTTB
# 정답률
# 과제 완료
# GNG
# 정답률, 반응시간
# 과제 완료
# TWOBACK
# 정답률, 반응시간
# 과제 완료
# STRC
# 정답률, 반응시간
# 과제 완료
# STRI
# 정답률, 반응시간
# 과제 완료
# REPEAT
# 정답률
# 과제 완료
# MIND
# 정답률
# 과제 완료
# FOLD
# 정답률
# 과제 완료
# 완료

# %%
import os
import datetime
import requests
import math
import pandas as pd
import numpy as np

path = os.getcwd()
file = os.path.join(path, "data", 'Result_0620.xlsx')
List = pd.read_excel(open(file, 'rb'), sheet_name ='data', header=0, index_col = 0)

List.columns
# Out:
# Index(['ID', 'Num', 'Date', 'time', 'Sex', 'grade', 'name', 'Hand',
#        'CBTTF_Cor', 'CBTTF_ACC', 'CBTTB_Cor', 'CBTTB_ACC', 'GNG_Cor', 'GNG_RT',
#        'GNG_ACC', 'TWOBACK_Cor', 'TWOBACK_RT', 'TWOBACK_ACC', 'STRC_Cor',
#        'STRC_RT', 'STRC_ACC', 'STRI_Cor', 'STRI_RT', 'STRI_ACC', 'REPEAT_Cor',
#        'REPEAT_ACC', 'MIND_Cor', 'MIND_ACC', 'FOLD_Cor', 'FOLD_ACC'],
#       dtype='object')

# %%
print(List)
# Out:
#                 ID  Num     Date  time  Sex  grade name    Hand  CBTTF_Cor  \
# 0    OBE_W_GN_0001    1   4월 20일  12.0    2      5  김보빈     NaN        NaN
# 1    OBE_W_GN_0002    2   4월 20일  14.0    2      5  김나영     NaN        NaN
# 2    OBE_W_GN_0003    3   4월 20일  16.0    1      2  임동권     NaN        NaN
# 3    OBE_W_GN_0004    4   4월 20일  18.0    2      5  구민선     NaN        NaN
# 4    OBE_W_GN_0005    5   4월 21일  12.0    1      2  양준영     NaN        NaN
# 5    OBE_W_GN_0006    6   4월 21일  14.0    2      5  박지인     NaN        NaN
# 6    OBE_W_GN_0007    7   4월 21일  16.0    1      5  박우민     NaN        NaN
# 7    OBE_W_GN_0008    8   4월 21일  18.0    1      5  김건호     NaN        NaN
# 9    OBE_W_GN_0009    9   4월 24일  16.0    2      2  이유주     NaN        NaN
# 11   OBE_W_GN_0010   10   4월 24일  18.0    1      5  고대현     NaN        NaN
# 12   OBE_W_GN_0011   11  4월 25일   16.0    2      2  황지혜     NaN        NaN
# 13   OBE_W_GN_0012   12  4월 25일   18.0    2      2  김시윤     NaN        NaN
# 14   OBE_W_GN_0013   13   4월 27일  12.0    2      2  임서윤     NaN        NaN
# 15   OBE_W_GN_0014   14   4월 27일  14.0    1      2  이수호     NaN        NaN
# 16   OBE_W_GN_0015   15   4월 27일  16.0    1      2  김서준     NaN        NaN
# 17   OBE_W_GN_0016   16   4월 27일  18.0    1      2  유영욱     NaN        NaN
# 18   OBE_W_GN_0017   17   4월 28일  12.0    2      5  박소현     NaN        NaN
# 19   OBE_W_GN_0018   18   4월 28일  14.0    1      5  이준우     NaN        NaN
# 20   OBE_W_GN_0019   19   4월 28일  16.0    2      2  이윤영     NaN        NaN
# 21   OBE_W_GN_0020   20   4월 28일  18.0    1      5  이준혁     NaN        NaN
# 22   OBE_W_GN_0021   21   5월 18일  12.0    2      1  강소율       우        NaN
# 23   OBE_W_GN_0022   22   5월 18일  12.0    1      1  박수현       우        NaN
# 24   OBE_W_GN_0023   23   5월 18일  14.0    2      1  김민채       좌        NaN
# 25   OBE_W_GN_0024   24   5월 18일  14.0    2      5  문지윤     NaN        NaN
# 10   OBE_W_GN_0025   25   5월 18일  16.0    2      2  이유주       우        NaN
# 27   OBE_W_GN_0026   26   5월 18일  16.0    1      2  곽건우       우        NaN
# 28   OBE_W_GN_0027   27   5월 18일  18.0    2      2  조수진  우(불명확)        NaN
# 29   OBE_W_GN_0028   28   5월 18일  18.0    2      4  조유현       우        NaN
# 30   OBE_W_GN_0029   29   5월 18일  12.0    1      2  김희성       x        NaN
# 31   OBE_W_GN_0030   30   5월 18일  12.0    2      3  정서연       우        NaN
# ..             ...  ...      ...   ...  ...    ...  ...     ...        ...
# 110  OBE_W_GN_0110  110    6월 2일  16.0    1      2   김운     NaN        6.0
# 111  OBE_W_GN_0111  111    6월 2일  16.0    1      4   김원       우        7.0
# 112  OBE_W_GN_0112  112    6월 2일  18.0    2      2  성윤경     NaN        NaN
# 113  OBE_W_GN_0113  113    6월 2일  18.0    1      4  성윤창     NaN        NaN
# 114  OBE_W_GN_0114  114    6월 8일  12.0    2      5  윤지유     NaN        6.0
# 115  OBE_W_GN_0115  115    6월 8일  12.0    2      3  윤시유     NaN        5.0
# 116  OBE_W_GN_0116  116    6월 8일  14.0    1      6  염태일     NaN        7.0
# 117  OBE_W_GN_0117  117    6월 8일  14.0    2      2  박지윤     NaN        5.0
# 118  OBE_W_GN_0118  118    6월 8일  16.0    1      3  박정후     NaN        7.0
# 119  OBE_W_GN_0119  119    6월 8일  16.0    1      3  김리환     NaN        5.0
# 120  OBE_W_GN_0120  120    6월 8일  18.0    2      6  신보영     NaN        NaN
# 121  OBE_W_GN_0121  121    6월 9일  14.0    1      3  양수호     NaN        6.0
# 122  OBE_W_GN_0122  122    6월 9일  14.0    2      1  양은서     NaN        4.0
# 123  OBE_W_GN_0123  123    6월 9일  16.0    2      4  한서윤     NaN        6.0
# 124  OBE_W_GN_0124  124    6월 9일  16.0    1      6  한예준     NaN        8.0
# 61   OBE_W_GN_0125  125    6월 9일  18.0    1      4  김건우     NaN        7.0
# 125  OBE_W_GN_0126  126    6월 9일  18.0    1      2  김민우     NaN        NaN
# 126  OBE_W_GN_0127  127    6월 9일  12.0    1      5  조훈영     NaN        8.0
# 127  OBE_W_GN_0128  128    6월 9일  12.0    1      2  조형오     NaN        4.0
# 128  OBE_W_GN_0129  129    6월 9일  14.0    1      1  김정후     NaN        NaN
# 129  OBE_W_GN_0130  130    6월 9일  14.0    2      1  신민서     NaN        5.0
# 130  OBE_W_GN_0131  131    6월 9일  16.0    2      1  김태희     NaN        6.0
# 131  OBE_W_GN_0132  132    6월 9일  16.0    2      3  김혜령     NaN        4.0
# 132  OBE_W_GN_0133  133    6월 9일  18.0    1      2  엄채혁     NaN        6.0
# 133  OBE_W_GN_0134  134    6월 9일  18.0    1      5  엄준혁     NaN        8.0
# 134  OBE_W_GN_0135  135    6월 9일  14.0    1      1  김도언     NaN        4.0
# 135  OBE_W_GN_0136  136    6월 9일  14.0    2      2  최온유     NaN        4.0
# 136  OBE_W_GN_0137  137    6월 9일  16.0    2      5  이지윤     NaN        7.0
# 137  OBE_W_GN_0138  138    6월 9일  16.0    1      2  이승민     NaN        4.0
# 138  OBE_W_GN_0139  139    6월 9일  18.0    2      3  신유나     NaN        7.0
#
#      CBTTF_ACC  ...  STRC_ACC  STRI_Cor      STRI_RT  STRI_ACC  REPEAT_Cor  \
# 0          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 1          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 2          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 3          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 4          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 5          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 6          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 7          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 9          NaN  ...       NaN       NaN          NaN       NaN         NaN
# 11         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 12         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 13         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 14         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 15         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 16         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 17         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 18         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 19         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 20         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 21         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 22         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 23         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 24         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 25         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 10         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 27         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 28         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 29         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 30         NaN  ...       NaN       NaN          NaN       NaN         NaN
# 31         NaN  ...       NaN       NaN          NaN       NaN         NaN
# ..         ...  ...       ...       ...          ...       ...         ...
# 110   0.666667  ...  1.000000      31.0  1342.076923  0.688889         0.0
# 111   0.777778  ...  1.000000      37.0  1434.600000  0.822222         0.0
# 112        NaN  ...       NaN       NaN          NaN       NaN         NaN
# 113        NaN  ...       NaN       NaN          NaN       NaN         NaN
# 114   0.666667  ...  1.000000      41.0  1190.000000  0.911111         7.0
# 115   0.555556  ...  0.931818      42.0  1347.100000  0.933333         5.0
# 116   0.777778  ...  1.000000      37.0  1310.090909  0.840909         2.0
# 117   0.555556  ...  0.739130      34.0  1500.000000  0.755556         4.0
# 118   0.777778  ...       NaN       NaN          NaN       NaN         NaN
# 119   0.555556  ...       NaN       NaN          NaN       NaN         NaN
# 120        NaN  ...       NaN       NaN          NaN       NaN         NaN
# 121   0.666667  ...  0.787234      44.0  1362.700000  0.977778         0.0
# 122   0.444444  ...  0.888889      28.0  1782.400000  0.595745         0.0
# 123   0.666667  ...  1.000000      45.0  1296.076923  1.000000         0.0
# 124   0.888889  ...  0.977778      45.0  1191.000000  1.000000         1.0
# 61    0.777778  ...  0.933333      41.0  1440.272727  0.911111         0.0
# 125        NaN  ...       NaN       NaN          NaN       NaN         NaN
# 126   0.888889  ...  0.978261      40.0  1398.600000  0.888889         1.0
# 127   0.444444  ...  0.977778      32.0  1499.285714  0.711111         0.0
# 128        NaN  ...       NaN       NaN          NaN       NaN         NaN
# 129   0.555556  ...  0.913043      17.0  1618.000000  0.377778         0.0
# 130   0.666667  ...  0.844444      32.0  1622.000000  0.711111         2.0
# 131   0.444444  ...  0.933333      40.0  1375.333333  0.888889         6.0
# 132   0.666667  ...  0.933333      34.0  1402.500000  0.755556         0.0
# 133   0.888889  ...  1.000000      40.0  1433.083333  0.869565         5.0
# 134   0.444444  ...  0.733333      16.0  1574.250000  0.363636         0.0
# 135   0.444444  ...  0.933333      39.0  1508.090909  0.886364         NaN
# 136   0.777778  ...  1.000000      41.0  1381.666667  0.911111         1.0
# 137   0.444444  ...  0.681818      17.0  1431.000000  0.377778         0.0
# 138   0.777778  ...  0.955556      40.0  1287.600000  0.909091         2.0
#
#      REPEAT_ACC  MIND_Cor  MIND_ACC  FOLD_Cor  FOLD_ACC
# 0           NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN       NaN
# 5           NaN       NaN       NaN       NaN       NaN
# 6           NaN       NaN       NaN       NaN       NaN
# 7           NaN       NaN       NaN       NaN       NaN
# 9           NaN       NaN       NaN       NaN       NaN
# 11          NaN       NaN       NaN       NaN       NaN
# 12          NaN       NaN       NaN       NaN       NaN
# 13          NaN       NaN       NaN       NaN       NaN
# 14          NaN       NaN       NaN       NaN       NaN
# 15          NaN       NaN       NaN       NaN       NaN
# 16          NaN       NaN       NaN       NaN       NaN
# 17          NaN       NaN       NaN       NaN       NaN
# 18          NaN       NaN       NaN       NaN       NaN
# 19          NaN       NaN       NaN       NaN       NaN
# 20          NaN       NaN       NaN       NaN       NaN
# 21          NaN       NaN       NaN       NaN       NaN
# 22          NaN       NaN       NaN       NaN       NaN
# 23          NaN       NaN       NaN       NaN       NaN
# 24          NaN       NaN       NaN       NaN       NaN
# 25          NaN       NaN       NaN       NaN       NaN
# 10          NaN       NaN       NaN       NaN       NaN
# 27          NaN       NaN       NaN       NaN       NaN
# 28          NaN       NaN       NaN       NaN       NaN
# 29          NaN       NaN       NaN       NaN       NaN
# 30          NaN       NaN       NaN       NaN       NaN
# 31          NaN       NaN       NaN       NaN       NaN
# ..          ...       ...       ...       ...       ...
# 110    0.000000      10.0  0.416667       4.0  0.285714
# 111    0.000000      10.0  0.416667       3.0  0.214286
# 112         NaN       NaN       NaN       NaN       NaN
# 113         NaN       NaN       NaN       NaN       NaN
# 114    0.777778      17.0  0.708333       3.0  0.214286
# 115    0.555556      13.0  0.541667       2.0  0.142857
# 116    0.222222      17.0  0.708333       5.0  0.357143
# 117    0.444444      15.0  0.625000       4.0  0.285714
# 118         NaN       NaN       NaN       NaN       NaN
# 119         NaN       NaN       NaN       NaN       NaN
# 120         NaN       NaN       NaN       NaN       NaN
# 121    0.000000      14.0  0.583333       2.0  0.142857
# 122    0.000000       9.0  0.375000       6.0  0.428571
# 123    0.000000      17.0  0.708333       7.0  0.500000
# 124    0.111111      16.0  0.666667       9.0  0.642857
# 61     0.000000      12.0  0.500000       2.0  0.142857
# 125         NaN       NaN       NaN       NaN       NaN
# 126    0.111111      13.0  0.541667       5.0  0.357143
# 127    0.000000       9.0  0.375000       1.0  0.071429
# 128         NaN       NaN       NaN       NaN       NaN
# 129    0.000000       7.0  0.291667       2.0  0.142857
# 130    0.222222      14.0  0.583333       3.0  0.214286
# 131    0.666667      17.0  0.708333       5.0  0.357143
# 132    0.000000      12.0  0.500000       2.0  0.142857
# 133    0.555556      15.0  0.625000       7.0  0.500000
# 134    0.000000      10.0  0.416667       2.0  0.142857
# 135         NaN       9.0  0.375000       2.0  0.142857
# 136    0.111111      17.0  0.708333       5.0  0.357143
# 137    0.000000      14.0  0.583333       5.0  0.357143
# 138    0.222222      15.0  0.625000       5.0  0.357143
#
# [139 rows x 30 columns]

# %%
List.describe()
# Out:
#               Num        time         Sex       grade  CBTTF_Cor  CBTTF_ACC  \
# count  139.000000  139.000000  139.000000  139.000000  79.000000  79.000000
# mean    70.000000   14.841727    1.474820    2.870504   5.873418   0.642475
# std     40.269923    2.779347    0.501172    1.573487   1.547265   0.177642
# min      1.000000    0.500000    1.000000    1.000000   1.000000   0.111111
# 25%     35.500000   14.000000    1.000000    1.500000   5.000000   0.555556
# 50%     70.000000   16.000000    1.000000    3.000000   6.000000   0.666667
# 75%    104.500000   16.000000    2.000000    4.000000   7.000000   0.777778
# max    139.000000   18.000000    2.000000    6.000000   9.000000   1.000000
#
#        CBTTB_Cor  CBTTB_ACC    GNG_Cor       GNG_RT  ...   STRC_ACC  \
# count  79.000000  79.000000  79.000000    79.000000  ...  77.000000
# mean    5.417722   0.596484  53.860759   755.816290  ...   0.894020
# std     1.437658   0.165586   8.197458    97.643081  ...   0.130583
# min     2.000000   0.222222  37.000000   592.404762  ...   0.352000
# 25%     4.500000   0.472222  48.000000   683.729054  ...   0.888889
# 50%     6.000000   0.600000  54.000000   735.870968  ...   0.933333
# 75%     6.000000   0.666667  59.000000   801.234921  ...   0.977778
# max     8.000000   0.888889  95.000000  1076.440000  ...   1.000000
#
#         STRI_Cor      STRI_RT   STRI_ACC  REPEAT_Cor  REPEAT_ACC   MIND_Cor  \
# count  76.000000    76.000000  76.000000   74.000000   74.000000  75.000000
# mean   34.342105  1396.715674   0.756166    1.094595    0.121622  12.933333
# std    10.879403   266.771714   0.248284    1.844421    0.204936   3.553960
# min     0.000000     0.000000   0.000000    0.000000    0.000000   3.000000
# 25%    31.000000  1329.863636   0.683333    0.000000    0.000000  10.000000
# 50%    38.500000  1417.583333   0.846135    0.000000    0.000000  13.000000
# 75%    42.000000  1505.772727   0.933333    1.750000    0.194444  15.500000
# max    46.000000  1782.400000   1.000000    7.000000    0.777778  20.000000
#
#         MIND_ACC   FOLD_Cor   FOLD_ACC
# count  75.000000  77.000000  77.000000
# mean    0.531111   3.558442   0.253247
# std     0.151335   1.867263   0.134405
# min     0.125000   0.000000   0.000000
# 25%     0.416667   2.000000   0.142857
# 50%     0.541667   3.000000   0.214286
# 75%     0.625000   5.000000   0.357143
# max     0.833333   9.000000   0.642857
#
# [8 rows x 26 columns]

# %%
import sys
import pandas as pd
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib as mpl

shapiro = sp.stats.shapiro

norm = mpl.colors.Normalize(vmin=-1., vmax=1.)
norm(0.)

List.corr(min_periods=1)
# Out:
#                   Num      time       Sex     grade  CBTTF_Cor  CBTTF_ACC  \
# Num          1.000000 -0.010521 -0.049190 -0.063470  -0.009792   0.006989
# time        -0.010521  1.000000  0.023129  0.140264   0.061986   0.048362
# Sex         -0.049190  0.023129  1.000000 -0.004165  -0.073451  -0.079387
# grade       -0.063470  0.140264 -0.004165  1.000000   0.592076   0.625840
# CBTTF_Cor   -0.009792  0.061986 -0.073451  0.592076   1.000000   0.956837
# CBTTF_ACC    0.006989  0.048362 -0.079387  0.625840   0.956837   1.000000
# CBTTB_Cor   -0.099199  0.150396 -0.214180  0.519645   0.513971   0.544307
# CBTTB_ACC   -0.093980  0.126359 -0.232755  0.510858   0.485853   0.545811
# GNG_Cor      0.036754 -0.133680 -0.068608  0.325962   0.344283   0.338470
# GNG_RT       0.064828  0.086975  0.095209 -0.330283  -0.225674  -0.258424
# GNG_ACC      0.081909 -0.167613  0.028273  0.553537   0.405792   0.490409
# TWOBACK_Cor -0.140368 -0.270353 -0.104500 -0.113968  -0.082923  -0.149669
# TWOBACK_RT  -0.048389  0.267510  0.049840  0.046402  -0.018189  -0.013948
# TWOBACK_ACC  0.070679  0.038290 -0.055178  0.195086   0.213239   0.236711
# STRC_Cor     0.016873  0.019793  0.144687  0.330047   0.238697   0.229265
# STRC_RT      0.029649 -0.117532 -0.062729 -0.405992  -0.311865  -0.362363
# STRC_ACC    -0.000757  0.002241  0.124079  0.394844   0.220063   0.297161
# STRI_Cor     0.028948  0.075924  0.362539  0.535667   0.422608   0.483169
# STRI_RT      0.069516 -0.087601  0.120267 -0.097512  -0.095911  -0.136785
# STRI_ACC     0.028332  0.063023  0.328829  0.552125   0.416081   0.517802
# REPEAT_Cor   0.145827  0.137858  0.423883  0.409966   0.244873   0.272909
# REPEAT_ACC   0.145827  0.137858  0.423883  0.409966   0.244873   0.272909
# MIND_Cor     0.029647  0.106470  0.267622  0.549540   0.310245   0.341751
# MIND_ACC     0.080859  0.120255  0.274592  0.491581   0.302144   0.366482
# FOLD_Cor     0.063345 -0.035379  0.012573  0.442712   0.346173   0.369163
# FOLD_ACC     0.061785 -0.038599  0.005063  0.447363   0.342941   0.378388
#
#              CBTTB_Cor  CBTTB_ACC   GNG_Cor    GNG_RT  ...  STRC_ACC  \
# Num          -0.099199  -0.093980  0.036754  0.064828  ... -0.000757
# time          0.150396   0.126359 -0.133680  0.086975  ...  0.002241
# Sex          -0.214180  -0.232755 -0.068608  0.095209  ...  0.124079
# grade         0.519645   0.510858  0.325962 -0.330283  ...  0.394844
# CBTTF_Cor     0.513971   0.485853  0.344283 -0.225674  ...  0.220063
# CBTTF_ACC     0.544307   0.545811  0.338470 -0.258424  ...  0.297161
# CBTTB_Cor     1.000000   0.986412  0.275874 -0.292154  ...  0.396268
# CBTTB_ACC     0.986412   1.000000  0.236915 -0.274028  ...  0.429262
# GNG_Cor       0.275874   0.236915  1.000000 -0.574464  ...  0.178378
# GNG_RT       -0.292154  -0.274028 -0.574464  1.000000  ... -0.277603
# GNG_ACC       0.309979   0.333050  0.607209 -0.559154  ...  0.358770
# TWOBACK_Cor  -0.015935  -0.062598  0.126951 -0.066537  ... -0.132667
# TWOBACK_RT   -0.013525  -0.013120 -0.119951  0.104513  ... -0.067896
# TWOBACK_ACC   0.240836   0.242980 -0.005910 -0.008613  ...  0.035708
# STRC_Cor      0.360804   0.328698  0.358266 -0.377509  ...  0.725118
# STRC_RT      -0.354273  -0.348091 -0.247403  0.408286  ... -0.547615
# STRC_ACC      0.396268   0.429262  0.178378 -0.277603  ...  1.000000
# STRI_Cor      0.309697   0.289240  0.342609 -0.259976  ...  0.423756
# STRI_RT      -0.047107  -0.062806 -0.010462  0.279994  ... -0.174871
# STRI_ACC      0.329725   0.337772  0.311782 -0.271548  ...  0.489085
# REPEAT_Cor    0.039991   0.034939  0.156060 -0.146995  ...  0.147807
# REPEAT_ACC    0.039991   0.034939  0.156060 -0.146995  ...  0.147807
# MIND_Cor      0.077150   0.088508  0.133710 -0.044088  ...  0.247610
# MIND_ACC      0.105173   0.138125  0.084989 -0.029974  ...  0.282170
# FOLD_Cor      0.241610   0.256765  0.161579 -0.118182  ...  0.168971
# FOLD_ACC      0.246671   0.270548  0.151839 -0.120644  ...  0.188476
#
#              STRI_Cor   STRI_RT  STRI_ACC  REPEAT_Cor  REPEAT_ACC  MIND_Cor  \
# Num          0.028948  0.069516  0.028332    0.145827    0.145827  0.029647
# time         0.075924 -0.087601  0.063023    0.137858    0.137858  0.106470
# Sex          0.362539  0.120267  0.328829    0.423883    0.423883  0.267622
# grade        0.535667 -0.097512  0.552125    0.409966    0.409966  0.549540
# CBTTF_Cor    0.422608 -0.095911  0.416081    0.244873    0.244873  0.310245
# CBTTF_ACC    0.483169 -0.136785  0.517802    0.272909    0.272909  0.341751
# CBTTB_Cor    0.309697 -0.047107  0.329725    0.039991    0.039991  0.077150
# CBTTB_ACC    0.289240 -0.062806  0.337772    0.034939    0.034939  0.088508
# GNG_Cor      0.342609 -0.010462  0.311782    0.156060    0.156060  0.133710
# GNG_RT      -0.259976  0.279994 -0.271548   -0.146995   -0.146995 -0.044088
# GNG_ACC      0.493456 -0.098075  0.538958    0.316579    0.316579  0.310137
# TWOBACK_Cor -0.135306 -0.173912 -0.203559   -0.141384   -0.141384 -0.089418
# TWOBACK_RT   0.030062  0.199292  0.043869    0.091622    0.091622  0.049166
# TWOBACK_ACC  0.196029  0.095537  0.197286    0.007040    0.007040  0.116800
# STRC_Cor     0.391192 -0.160864  0.358636    0.092780    0.092780  0.077443
# STRC_RT     -0.411465  0.205569 -0.428105   -0.198154   -0.198154 -0.284890
# STRC_ACC     0.423756 -0.174871  0.489085    0.147807    0.147807  0.247610
# STRI_Cor     1.000000  0.159737  0.980426    0.382921    0.382921  0.606039
# STRI_RT      0.159737  1.000000  0.130692   -0.079920   -0.079920 -0.070935
# STRI_ACC     0.980426  0.130692  1.000000    0.390454    0.390454  0.612317
# REPEAT_Cor   0.382921 -0.079920  0.390454    1.000000    1.000000  0.419910
# REPEAT_ACC   0.382921 -0.079920  0.390454    1.000000    1.000000  0.419910
# MIND_Cor     0.606039 -0.070935  0.612317    0.419910    0.419910  1.000000
# MIND_ACC     0.572727 -0.069001  0.610446    0.442294    0.442294  0.946118
# FOLD_Cor     0.183982  0.046182  0.195369    0.131871    0.131871  0.322173
# FOLD_ACC     0.183360  0.038845  0.206598    0.135135    0.135135  0.325469
#
#              MIND_ACC  FOLD_Cor  FOLD_ACC
# Num          0.080859  0.063345  0.061785
# time         0.120255 -0.035379 -0.038599
# Sex          0.274592  0.012573  0.005063
# grade        0.491581  0.442712  0.447363
# CBTTF_Cor    0.302144  0.346173  0.342941
# CBTTF_ACC    0.366482  0.369163  0.378388
# CBTTB_Cor    0.105173  0.241610  0.246671
# CBTTB_ACC    0.138125  0.256765  0.270548
# GNG_Cor      0.084989  0.161579  0.151839
# GNG_RT      -0.029974 -0.118182 -0.120644
# GNG_ACC      0.312827  0.306942  0.321563
# TWOBACK_Cor -0.184150 -0.050598 -0.074209
# TWOBACK_RT   0.044561  0.082362  0.084569
# TWOBACK_ACC  0.068770  0.151471  0.150593
# STRC_Cor     0.045467  0.122195  0.115211
# STRC_RT     -0.255603 -0.159004 -0.164279
# STRC_ACC     0.282170  0.168971  0.188476
# STRI_Cor     0.572727  0.183982  0.183360
# STRI_RT     -0.069001  0.046182  0.038845
# STRI_ACC     0.610446  0.195369  0.206598
# REPEAT_Cor   0.442294  0.131871  0.135135
# REPEAT_ACC   0.442294  0.131871  0.135135
# MIND_Cor     0.946118  0.322173  0.325469
# MIND_ACC     1.000000  0.270003  0.283506
# FOLD_Cor     0.270003  1.000000  0.998181
# FOLD_ACC     0.283506  0.998181  1.000000
#
# [26 rows x 26 columns]

# %%
List[List.dtypes[(List.dtypes=="float64")|(List.dtypes=="int64")]
                        .index.values].hist(figsize=[15,15])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C37DAC5C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C304021780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30A424B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30A19F668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C3026A0320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C3038369E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C37E940240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C308692A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C308692780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30A5C2BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C3048A76D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C303FF1940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C303269470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C303AF8E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C37E0B40B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C37DACC320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30A85B518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30A8867F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C303177A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C37E2EFCC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C30300A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C303F931D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C37E8594E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30386FA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C37E296FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C302790588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C302B78B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C3028CB0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30A187630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C30A195BA8>]],
#       dtype=object)

# %%
from numpy.random import seed
from numpy.random import randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
import scipy.stats as stats

for feature in List:
    print(feature)
    if 'ID' in feature or 'Num' in feature or 'Date' in feature or 'time' in feature or 'Sex' in feature or 'grade' in feature or 'name' in feature or 'Hand' in feature: 
        print('pass')
        pass
    else:
        a = List[feature]
        qqplot(a,line='r')
        pyplot.show()
# Out:
# ID
# pass
# Num
# pass
# Date
# pass
# time
# pass
# Sex
# pass
# grade
# pass
# name
# pass
# Hand
# pass
# CBTTF_Cor
# CBTTF_ACC
# CBTTB_Cor
# CBTTB_ACC
# GNG_Cor
# GNG_RT
# GNG_ACC
# TWOBACK_Cor
# TWOBACK_RT
# TWOBACK_ACC
# STRC_Cor
# STRC_RT
# STRC_ACC
# STRI_Cor
# STRI_RT
# STRI_ACC
# REPEAT_Cor
# REPEAT_ACC
# MIND_Cor
# MIND_ACC
# FOLD_Cor
# FOLD_ACC

# %%
import seaborn as sns
from matplotlib import pyplot as plt

for feature in List:
    print(feature)
    if 'ID' in feature or 'Num' in feature or 'Date' in feature or 'time' in feature or 'Sex' in feature or 'name' in feature or 'Hand' in feature: 
        print('pass')
        pass
    else:
        a = List[feature]
        sns.distplot(a.dropna())
        plt.show()
# Out:
# ID
# pass
# Num
# pass
# Date
# pass
# time
# pass
# Sex
# pass
# grade
# name
# pass
# Hand
# pass
# CBTTF_Cor
# CBTTF_ACC
# CBTTB_Cor
# CBTTB_ACC
# GNG_Cor
# GNG_RT
# GNG_ACC
# TWOBACK_Cor
# TWOBACK_RT
# TWOBACK_ACC
# STRC_Cor
# STRC_RT
# STRC_ACC
# STRI_Cor
# STRI_RT
# STRI_ACC
# REPEAT_Cor
# REPEAT_ACC
# MIND_Cor
# MIND_ACC
# FOLD_Cor
# FOLD_ACC

# %%
print('나중에 볼 것')
g = sns.FacetGrid(List, row='grade', col='Sex')
g.map(sns.distplot, "FOLD_ACC")
plt.show()
# Out:
# 나중에 볼 것)

# %%
sns.jointplot(data=List, x='grade', y='FOLD_ACC', kind='reg', color='g')
plt.show()

# %%
df = List.pivot_table(index='FOLD_Cor', columns='grade', values='FOLD_ACC', aggfunc=np.median)
sns.heatmap(df, annot=True, fmt=".1f")
plt.show()

# %%
List1 = List[['grade', 'CBTTF_ACC', 'CBTTB_ACC', 'GNG_RT', 'GNG_ACC', 'TWOBACK_RT', 'TWOBACK_ACC',
       'STRC_RT', 'STRC_ACC', 'STRI_RT', 'STRI_ACC', 'REPEAT_ACC', 'MIND_ACC', 'FOLD_ACC']]
print(List1)
sns.heatmap(List1.corr(), fmt=".2f" )
plt.savefig('heatmap.png', format='png', dpi=300) 
plt.show()
# Out:
#      grade  CBTTF_ACC  CBTTB_ACC      GNG_RT   GNG_ACC   TWOBACK_RT  \
# 0        5        NaN        NaN         NaN       NaN          NaN
# 1        5        NaN        NaN         NaN       NaN          NaN
# 2        2        NaN        NaN         NaN       NaN          NaN
# 3        5        NaN        NaN         NaN       NaN          NaN
# 4        2        NaN        NaN         NaN       NaN          NaN
# 5        5        NaN        NaN         NaN       NaN          NaN
# 6        5        NaN        NaN         NaN       NaN          NaN
# 7        5        NaN        NaN         NaN       NaN          NaN
# 9        2        NaN        NaN         NaN       NaN          NaN
# 11       5        NaN        NaN         NaN       NaN          NaN
# 12       2        NaN        NaN         NaN       NaN          NaN
# 13       2        NaN        NaN         NaN       NaN          NaN
# 14       2        NaN        NaN         NaN       NaN          NaN
# 15       2        NaN        NaN         NaN       NaN          NaN
# 16       2        NaN        NaN         NaN       NaN          NaN
# 17       2        NaN        NaN         NaN       NaN          NaN
# 18       5        NaN        NaN         NaN       NaN          NaN
# 19       5        NaN        NaN         NaN       NaN          NaN
# 20       2        NaN        NaN         NaN       NaN          NaN
# 21       5        NaN        NaN         NaN       NaN          NaN
# 22       1        NaN        NaN         NaN       NaN          NaN
# 23       1        NaN        NaN         NaN       NaN          NaN
# 24       1        NaN        NaN         NaN       NaN          NaN
# 25       5        NaN        NaN         NaN       NaN          NaN
# 10       2        NaN        NaN         NaN       NaN          NaN
# 27       2        NaN        NaN         NaN       NaN          NaN
# 28       2        NaN        NaN         NaN       NaN          NaN
# 29       4        NaN        NaN         NaN       NaN          NaN
# 30       2        NaN        NaN         NaN       NaN          NaN
# 31       3        NaN        NaN         NaN       NaN          NaN
# ..     ...        ...        ...         ...       ...          ...
# 110      2   0.666667   0.666667  699.078947  0.794118  1371.000000
# 111      4   0.777778   0.666667  818.800000  0.841270  1250.500000
# 112      2        NaN        NaN         NaN       NaN          NaN
# 113      4        NaN        NaN         NaN       NaN          NaN
# 114      5   0.666667   0.555556  676.441860  0.895522  1051.800000
# 115      3   0.555556   0.300000  647.780488  0.969697   700.500000
# 116      6   0.777778   0.666667  647.238095  0.865672  1303.750000
# 117      2   0.555556   0.555556  799.206897  0.790323   889.631579
# 118      3   0.777778   0.666667  854.032258  0.786885     0.000000
# 119      3   0.555556   0.444444  778.685714  0.870968  1045.750000
# 120      6        NaN        NaN         NaN       NaN          NaN
# 121      3   0.666667   0.777778  702.567568  0.850746  1276.500000
# 122      1   0.444444   0.555556  783.354839  0.750000   700.500000
# 123      4   0.666667   0.555556  668.333333  0.910448   776.750000
# 124      6   0.888889   0.888889  658.921053  0.937500   988.250000
# 61       4   0.777778   0.777778  686.108108  0.892308   954.000000
# 125      2        NaN        NaN         NaN       NaN          NaN
# 126      5   0.888889   0.777778  653.162791  0.955882   615.000000
# 127      2   0.444444   0.555556  715.897436  0.893939   497.333333
# 128      1        NaN        NaN         NaN       NaN          NaN
# 129      1   0.555556   0.222222  831.823529  0.852459   962.500000
# 130      1   0.666667   0.444444  734.419355  0.793651  1442.250000
# 131      3   0.444444   0.666667  758.100000  0.793651  1053.454545
# 132      2   0.666667   0.666667  783.827586  0.721311   951.333333
# 133      5   0.888889   0.555556  877.379310  0.770492   804.500000
# 134      1   0.444444   0.444444  706.793103  0.774194   637.000000
# 135      2   0.444444   0.666667  755.200000  0.781250  1228.600000
# 136      5   0.777778   0.777778  658.894737  0.850746   540.000000
# 137      2   0.444444   0.555556  951.518519  0.745763  1105.625000
# 138      3   0.777778   0.777778  670.897436  0.909091  1121.000000
#
#      TWOBACK_ACC      STRC_RT  STRC_ACC      STRI_RT  STRI_ACC  REPEAT_ACC  \
# 0            NaN          NaN       NaN          NaN       NaN         NaN
# 1            NaN          NaN       NaN          NaN       NaN         NaN
# 2            NaN          NaN       NaN          NaN       NaN         NaN
# 3            NaN          NaN       NaN          NaN       NaN         NaN
# 4            NaN          NaN       NaN          NaN       NaN         NaN
# 5            NaN          NaN       NaN          NaN       NaN         NaN
# 6            NaN          NaN       NaN          NaN       NaN         NaN
# 7            NaN          NaN       NaN          NaN       NaN         NaN
# 9            NaN          NaN       NaN          NaN       NaN         NaN
# 11           NaN          NaN       NaN          NaN       NaN         NaN
# 12           NaN          NaN       NaN          NaN       NaN         NaN
# 13           NaN          NaN       NaN          NaN       NaN         NaN
# 14           NaN          NaN       NaN          NaN       NaN         NaN
# 15           NaN          NaN       NaN          NaN       NaN         NaN
# 16           NaN          NaN       NaN          NaN       NaN         NaN
# 17           NaN          NaN       NaN          NaN       NaN         NaN
# 18           NaN          NaN       NaN          NaN       NaN         NaN
# 19           NaN          NaN       NaN          NaN       NaN         NaN
# 20           NaN          NaN       NaN          NaN       NaN         NaN
# 21           NaN          NaN       NaN          NaN       NaN         NaN
# 22           NaN          NaN       NaN          NaN       NaN         NaN
# 23           NaN          NaN       NaN          NaN       NaN         NaN
# 24           NaN          NaN       NaN          NaN       NaN         NaN
# 25           NaN          NaN       NaN          NaN       NaN         NaN
# 10           NaN          NaN       NaN          NaN       NaN         NaN
# 27           NaN          NaN       NaN          NaN       NaN         NaN
# 28           NaN          NaN       NaN          NaN       NaN         NaN
# 29           NaN          NaN       NaN          NaN       NaN         NaN
# 30           NaN          NaN       NaN          NaN       NaN         NaN
# 31           NaN          NaN       NaN          NaN       NaN         NaN
# ..           ...          ...       ...          ...       ...         ...
# 110     0.605263  1181.916667  1.000000  1342.076923  0.688889    0.000000
# 111     0.657895  1176.857143  1.000000  1434.600000  0.822222    0.000000
# 112          NaN          NaN       NaN          NaN       NaN         NaN
# 113          NaN          NaN       NaN          NaN       NaN         NaN
# 114     0.487179  1068.076923  1.000000  1190.000000  0.911111    0.777778
# 115     0.435897  1206.125000  0.931818  1347.100000  0.933333    0.555556
# 116     0.605263  1204.583333  1.000000  1310.090909  0.840909    0.222222
# 117     0.410714  1304.500000  0.739130  1500.000000  0.755556    0.444444
# 118     0.666667          NaN       NaN          NaN       NaN         NaN
# 119     0.562500          NaN       NaN          NaN       NaN         NaN
# 120          NaN          NaN       NaN          NaN       NaN         NaN
# 121     0.538462  1447.600000  0.787234  1362.700000  0.977778    0.000000
# 122     0.435897  1578.909091  0.888889  1782.400000  0.595745    0.000000
# 123     0.463415  1348.125000  1.000000  1296.076923  1.000000    0.000000
# 124     0.621622  1266.909091  0.977778  1191.000000  1.000000    0.111111
# 61      0.475000  1344.090909  0.933333  1440.272727  0.911111    0.000000
# 125          NaN          NaN       NaN          NaN       NaN         NaN
# 126     0.604651  1258.166667  0.978261  1398.600000  0.888889    0.111111
# 127     0.641026  1287.571429  0.977778  1499.285714  0.711111    0.000000
# 128          NaN          NaN       NaN          NaN       NaN         NaN
# 129     0.473684  1503.428571  0.913043  1618.000000  0.377778    0.000000
# 130     0.540541  1251.250000  0.844444  1622.000000  0.711111    0.222222
# 131     0.511111  1273.875000  0.933333  1375.333333  0.888889    0.666667
# 132     0.431818  1349.666667  0.933333  1402.500000  0.755556    0.000000
# 133     0.578947  1263.266667  1.000000  1433.083333  0.869565    0.555556
# 134     0.621622  1364.666667  0.733333  1574.250000  0.363636    0.000000
# 135     0.631579  1257.222222  0.933333  1508.090909  0.886364         NaN
# 136     0.583333  1148.090909  1.000000  1381.666667  0.911111    0.111111
# 137     0.675000  1492.428571  0.681818  1431.000000  0.377778    0.000000
# 138     0.567568  1134.454545  0.955556  1287.600000  0.909091    0.222222
#
#      MIND_ACC  FOLD_ACC
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN
# 5         NaN       NaN
# 6         NaN       NaN
# 7         NaN       NaN
# 9         NaN       NaN
# 11        NaN       NaN
# 12        NaN       NaN
# 13        NaN       NaN
# 14        NaN       NaN
# 15        NaN       NaN
# 16        NaN       NaN
# 17        NaN       NaN
# 18        NaN       NaN
# 19        NaN       NaN
# 20        NaN       NaN
# 21        NaN       NaN
# 22        NaN       NaN
# 23        NaN       NaN
# 24        NaN       NaN
# 25        NaN       NaN
# 10        NaN       NaN
# 27        NaN       NaN
# 28        NaN       NaN
# 29        NaN       NaN
# 30        NaN       NaN
# 31        NaN       NaN
# ..        ...       ...
# 110  0.416667  0.285714
# 111  0.416667  0.214286
# 112       NaN       NaN
# 113       NaN       NaN
# 114  0.708333  0.214286
# 115  0.541667  0.142857
# 116  0.708333  0.357143
# 117  0.625000  0.285714
# 118       NaN       NaN
# 119       NaN       NaN
# 120       NaN       NaN
# 121  0.583333  0.142857
# 122  0.375000  0.428571
# 123  0.708333  0.500000
# 124  0.666667  0.642857
# 61   0.500000  0.142857
# 125       NaN       NaN
# 126  0.541667  0.357143
# 127  0.375000  0.071429
# 128       NaN       NaN
# 129  0.291667  0.142857
# 130  0.583333  0.214286
# 131  0.708333  0.357143
# 132  0.500000  0.142857
# 133  0.625000  0.500000
# 134  0.416667  0.142857
# 135  0.375000  0.142857
# 136  0.708333  0.357143
# 137  0.583333  0.357143
# 138  0.625000  0.357143
#
# [139 rows x 14 columns]

# %%
shapiro = sp.stats.shapiro
List2 = List[['Sex', 'grade',
       'CBTTF_Cor', 'CBTTF_ACC', 'CBTTB_Cor', 'CBTTB_ACC', 'GNG_Cor', 'GNG_RT',
       'GNG_ACC', 'TWOBACK_Cor', 'TWOBACK_RT', 'TWOBACK_ACC', 'STRC_Cor',
       'STRC_RT', 'STRC_ACC', 'STRI_Cor', 'STRI_RT', 'STRI_ACC', 'REPEAT_Cor',
       'REPEAT_ACC', 'MIND_Cor', 'MIND_ACC', 'FOLD_Cor', 'FOLD_ACC']]
for col in List2:
    print(col, '\n shapiro : %f ' % shapiro(List2['%s' %  col].dropna())[0], ' p-value : %f' %shapiro(List2['%s' %  col].dropna())[1])
# Out:
# Sex
#  shapiro : 0.635475   p-value : 0.000000
# grade
#  shapiro : 0.893363   p-value : 0.000000
# CBTTF_Cor
#  shapiro : 0.924315   p-value : 0.000168
# CBTTF_ACC
#  shapiro : 0.938095   p-value : 0.000830
# CBTTB_Cor
#  shapiro : 0.945438   p-value : 0.002061
# CBTTB_ACC
#  shapiro : 0.946818   p-value : 0.002458
# GNG_Cor
#  shapiro : 0.898431   p-value : 0.000012
# GNG_RT
#  shapiro : 0.927921   p-value : 0.000252
# GNG_ACC
#  shapiro : 0.968029   p-value : 0.044728
# TWOBACK_Cor
#  shapiro : 0.892371   p-value : 0.000007
# TWOBACK_RT
#  shapiro : 0.937409   p-value : 0.000764
# TWOBACK_ACC
#  shapiro : 0.985372   p-value : 0.505453
# STRC_Cor
#  shapiro : 0.751258   p-value : 0.000000
# STRC_RT
#  shapiro : 0.980879   p-value : 0.299422
# STRC_ACC
#  shapiro : 0.719328   p-value : 0.000000
# STRI_Cor
#  shapiro : 0.838124   p-value : 0.000000
# STRI_RT
#  shapiro : 0.628534   p-value : 0.000000
# STRI_ACC
#  shapiro : 0.838152   p-value : 0.000000
# REPEAT_Cor
#  shapiro : 0.655092   p-value : 0.000000
# REPEAT_ACC
#  shapiro : 0.655092   p-value : 0.000000
# MIND_Cor
#  shapiro : 0.978665   p-value : 0.236549
# MIND_ACC
#  shapiro : 0.978658   p-value : 0.236321
# FOLD_Cor
#  shapiro : 0.938259   p-value : 0.001005
# FOLD_ACC
#  shapiro : 0.942365   p-value : 0.001650

# %%
List.columns
# Out:
# Index(['ID', 'Num', 'Date', 'time', 'Sex', 'grade', 'name', 'Hand',
#        'CBTTF_Cor', 'CBTTF_ACC', 'CBTTB_Cor', 'CBTTB_ACC', 'GNG_Cor', 'GNG_RT',
#        'GNG_ACC', 'TWOBACK_Cor', 'TWOBACK_RT', 'TWOBACK_ACC', 'STRC_Cor',
#        'STRC_RT', 'STRC_ACC', 'STRI_Cor', 'STRI_RT', 'STRI_ACC', 'REPEAT_Cor',
#        'REPEAT_ACC', 'MIND_Cor', 'MIND_ACC', 'FOLD_Cor', 'FOLD_ACC'],
#       dtype='object')
