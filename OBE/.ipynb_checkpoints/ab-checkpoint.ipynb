# %%
#data input, output
import os
import sys
#split only ㅋ
import re
# 뭐에 쓰드라...
import math
# data 전처리, 분석용
import itertools
import pandas as pd
import numpy as np
import scipy as sp
from scipy import stats as st
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
import statsmodels.stats.api as sms
import statsmodels.api as sm
# 서버 requests
import requests
from requests.auth import HTTPBasicAuth
# age 추출
import datetime
from datetime import date
from dateutil.parser import parse
# figure 작업 용
from statsmodels.graphics.gofplots import qqplot
import matplotlib as mpl
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#이미지 작업용
import matplotlib.image as mpimg # np.array로 이미지 로드
from PIL import Image # 오브젝트로 로드  -> np.array로 캐스팅

# %%
def figure_out_perf(s_data = {}, gtype = 'bar', level = False):
    """
        작성자: sjyoo
        작성일: 190704
        기능: 행동 데이터 figure 추출
        입력: s_data(score 분리 데이터)
        출력: figure(A to Z).png export
        용례: figure_out_perf(s_data, gtype = ['bar', 'stem', 'image 작성중..', 'dist 따로 만들듯...'], 
                                level = boolen(지금은 레벨 점수 적용 여부))
    """
    #폰트 설정
    sns.set(font_scale=0.5)
    mpl.rcParams['axes.unicode_minus'] = False
    path = 'C:/Windows/Fonts/HYSNRL.ttf'
    font_name = fm.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
    
    for task in s_data:
        if 'REST' in task or 'VFT' in task:
            pass
        else:
            s_list = s_data[task].childName.unique()

            for child in s_list:
                s_child = s_data[task][s_data[task].childName == child]
                s_child = s_child.dropna(how = 'any')
                y = s_child['%s_Cor' % task].astype('int')
                y = y.replace(0, -1)
                
                #레벨 적용
                if level == True:
                    LV = [int(lv[2:]) for lv in s_child['%s_LV' % task]]
                    y = np.multiply(LV, y)
                
                fig = plt.figure()
                ax =plt.subplot(111)
                x_name=  s_child['ctime']
                n_groups = len(x_name)
                index = np.arange(n_groups)
                bar_width = 0.35
                opacity = 1
                
                # bar graph
                if gtype == 'bar':
                   

                    ax.bar(index, y.replace(y[y<0], np.nan), alpha=opacity, color='b')
                    ax.bar(index, y.replace(y[y>0], np.nan), alpha=opacity, color='r')
                    ax.set_xlabel('time')
                    ax.set_ylabel('%s_Cor' % task)
                    ax.set_title('%s Bar Chart' % (task))
#                     ax.set_ylim(-3,3)
                    
                    plt.savefig('%s_%s_%s.png' % (child, task, gtype), format = 'png', dpi = 300)
                    plt.show()

                # stem graph    
                elif gtype == 'stem':

                    ax.stem(index, y.replace(y[y<0], np.nan), markerfmt = 'C3o', basefmt = 'r', linefmt='grey')
                    ax.stem(index, y.replacey(y[y>0], np.nan), markerfmt = 'C0o', basefmt= 'r', linefmt='grey' )
                    ax.set_xlabel('time')
                    ax.set_ylabel('%s_Cor' % task)
                    ax.set_title('%s Stem Chart' % (task))
#                     ax.set_ylim(-3,3)
                    
                    plt.savefig('%s_%s_%s.png' % (child, task, gtype), format = 'png', dpi = 300)
                    plt.show()

                # Distribution figure
                elif gtype == 'image':
                    path = os.getcwd()
                    imf = os.path.join(path, 'graphboard.png')

                    image = mpimg.imread(imf)
                    plt.imshow(image)
#                     height, width, layer = image.shape
#                     f, axes = plt.subplots(2, 2, figsize=(8, 8*height/width))
                    ## original img plotting 
#                     axes[0][0].imshow(image[:, :, :]), axes[0][0].axis('off')
#                     axes[0][0].set_xticks([]), axes[0][0].set_yticks([])# 이걸 하지 않으면 tick이 남아있어서 간격이 생김. 
                    # Red, Green, Blue로 구분하여 표현. colormap 또한, 그 형식에 맞춰서 표현 
                    # 실제 그림을 보면 색깔별로 어느 정도 구분되어 있는 것을 알 수 있음. 
#                     cmaps = [plt.cm.Reds, plt.cm.Greens, plt.cm.Blues]
#                     for i in range(1, 4):
#                         axes[i//2][i%2].imshow(image[:, :, i-1], cmap=cmaps[i-1])
#                         axes[i//2][i%2].set_xticks([]), axes[i//2][i%2].set_yticks([])# 이걸 하지 않으면 tick이 남아있어서 간격이 생김. 
#                         axes[i//2][i%2].axis('off')
#                     plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
                    ## sutplots_adjust는 subplot 간에 간격을 붙이려고 쓴건데, 쓰고보니 어떻게 쓰는건지 모르겠음. 그냥 모르겠음...
                    plt.margins(0, 0, tight=False)
                    # pad_inches를 0으로 두고 저장하면, 공백없이 저장됨. 
#                     plt.savefig("../../assets/images/markdown_img/180628_1935_google_rgb.svg", pad_inches=0)
                    plt.show()
                    
                elif gtype == 'dist':

                    a = List[feature].dropna()
                    low = a[a < np.percentile(a, 30)].count()
                    high = a[a > np.percentile(a, 70)].count()
                    middle = a[(a <= np.percentile(a, 70))&(a >= np.percentile(a, 30))].count()

                    points = sns.distplot(a.dropna() 
            #                               , bins = 1000
                                          , fit=sp.stats.norm
                                          , hist =False, kde = True, kde_kws = {'shade' :True, 'kernel' : 'gau'
            #                                                                  , 'bw' : 0.1
                                                                                , 'clip' :(a.min(),a.max()) 
                                                                            }
                                         ).get_lines()[0].get_data()

                    x = points[0]
                    y = points[1]
            #         th = sms.DescrStatsW(a).tconfint_mean(0.0001)[0]
            #         se = sms.DescrStatsW(a).tconfint_mean(0.0001)[1]
                    plt.fill_between(x,y, where = x > np.percentile(a, 75), color='y', alpha=0.7, label = '높음')
                    plt.fill_between(x,y, where = x <  np.percentile(a, 25), color='y', alpha=0.7, label = '낮음')
                    plt.fill_between(x,y, where = (x <=  np.percentile(a, 75)) & (x >= np.percentile(a, 25)), color='b', alpha=0.7, label = '보통')
                    plt.fill_between(x,y, where = (x > np.percentile(a, 90)) &  (x < np.percentile(a, 10)), color='r', alpha=0.7, label = '높음')

            #         hito = plt.hist(a, alpha = 0.5, align  = 'right' )
            #         plt.text(.50, .5, '낮음 = %s , 중간 = %s , 보통 = %s' % (low, middle, high), horizontalalignment='center',
            #      verticalalignment='center',
            #      textcoords = 'axes fraction')
            #         plt.text(x.min(), hito[0].max(), '낮음 = %s , 보통 = %s, 높음 = %s' % (low, middle, high), style='italic',
            #         bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
            #         plt.annotate('낮음 = %s' % low, xy = (np.percentile(a, 25),np.percentile(a, 25)), xytext=(0.25, 0.5), textcoords = 'axes fraction', arrowprops = dict(color = 'g', alpha= 0.5))
            #         plt.annotate('중간 = %s' % middle, xy = (np.percentile(a, 50),np.percentile(a, 50)), xytext=(0.5, 0.7), textcoords = 'axes fraction', arrowprops = dict(color = 'g', alpha= 0.5))
            #         plt.annotate('높음 = %s' % high, xy = (np.percentile(a, 75),np.percentile(a, 75)), xytext=(0.75, 0.5), textcoords = 'axes fraction', arrowprops = dict(color = 'g', alpha= 0.5))


                    plt.savefig('%s_%s.png' % (feature, gtype), format = 'png', dpi = 1200)
                    plt.show()
    return

def data_scoring(raw = pd.DataFrame(), export = 'f_data'):
    """
        작성자: sjyoo
        작성일: 190704
        기능: 각 행동 데이터 response, index, ctime, taskUUID를 분리하여 코딩
        입력: raw = pd.DataFrame(raw data)
        출력: f_data.xlsx export & figure 용 data
        용례: s_data = data_scoring(list_raw, data, str(export excel file name))
    """
    tasks = {1:'REST',2:'CBTTF',3:'CBTTB',4:'GNG',5:'TWOBACK',6:'STRC',7:'STRI',8:'VFT',9:'REPEAT',10:'MIND',11:'FOLD'}
    GNG_LV = {'LV1':2500, 'LV2': 2250, 'LV3': 2000, 'LV4': 1750, 'LV5': 1500, 'LV6': 1250, 'LV7': 1000, 'LV8': 750, 'LV9': 750, 'LV10': 750, 'LV11': 750, 'LV12': 750} 
    print('scoring data listing 시작')
    s_data = {}
    with pd.ExcelWriter('C:/Users/OBELAB_JH_DESKTOP/Documents/GitHub/testfornothing/OBE/data/'+ export + '.xlsx') as writer:
        for k, v in tasks.items():
            print('key : '+ str(k) + ', value : ' + v)
            s_data[v] = raw[raw['taskType'] == str(k)]
            s_data[v] = s_data[v].replace(['TASKMARKER','OUTTOUCH', 'TASKMARKER\r','OUTTOUCH\r'],[np.nan, np.nan, np.nan, np.nan]).dropna(axis = 1, how = 'all')
#             s_data[v].fillna('')
            s_data[v] = s_data[v].replace('', np.nan)
            if 'GNG' in v or 'STRC' in v or 'STRI' in v or 'TWOBACK' in v or 'CBTTF' in v or 'CBTTB' in v or 'MIND' in v or 'REPEAT' in v or 'FOLD' in v:
                LV, Cor, Act, RT = [], [], [], []
                for ra in s_data[v]['ra']:
                    if pd.isnull(ra) == False:
                        marker = ra.split('/')
                    else:
                        marker = ['LV', 'Cor', 'Act', 'RT']
                        
#                     print(marker)   
                    LV.append(marker[0])
                    Cor.append(marker[1])
                    Act.append(marker[2])
                    RT.append(marker[3])
                s_data[v]['%s_LV' % v] = LV
                s_data[v]['%s_Cor' % v] = Cor
                s_data[v]['%s_Act' % v] = Act
                s_data[v]['%s_RT' % v] = RT
                print('%s 과제 완료' % v)
            else:
                pass

            s_data[v].to_excel(writer, sheet_name=v, index = None)
            
    print('정리 완료')
    return s_data


def data_merge(List = pd.DataFrame(), raw_data = {}, export = 'merge'):
    """
        작성자: sjyoo
        작성일: 190612
        기능: list와 raw 파일 COR, ACC, RT 등을 merge
        입력: list = pd.DataFrame(), raw_data = dict{}
        출력: merge.xlsx export
        용례: data_merge(list_raw, raw_data, str(export excel file name))
    """
    tasks = {1:'REST',2:'CBTTF',3:'CBTTB',4:'GNG',5:'TWOBACK',6:'STRC',7:'STRI',8:'VFT',9:'REPEAT',10:'MIND',11:'FOLD'}
    GNG_LV = {'LV1':2500, 'LV2': 2250, 'LV3': 2000, 'LV4': 1750, 'LV5': 1500, 'LV6': 1250, 'LV7': 1000, 'LV8': 750, 'LV9': 750, 'LV10': 750, 'LV11': 750, 'LV12': 750} 
#     task_stage = {'GNG':,
#                  'CBTTF':,
#                  'CBTTB':, 
#                  'REPEAT':,
#                  'FOLD': }
    print('merge 시작')
    m_data = {}
    m_data = raw_data
    for k, v in tasks.items():
        print('key : '+ str(k) + ', value : ' + v)
        m_data[v] = m_data[v].replace(['TASKMARKER','OUTTOUCH', 'TASKMARKER\r','OUTTOUCH\r'],[np.nan, np.nan, np.nan, np.nan]).T.dropna(axis = 1, how = 'all')
        m_data[v].fillna('')
        pack = pd.DataFrame()
        idx = m_data[v].index
        col = m_data[v].columns
        pack['taskUUID'] = idx
        RT, Acc, Max, Cor_list = [], [], [], []
        if 'GNG' in v:
            for i in idx:
                Cor, LV = 0, 0
                RT_list, LV_list = [], []
                for j in col:
                    if pd.isnull(m_data[v][j][i]) == False:
                        marker = m_data[v][j][i].split('/')
                        if 'LV' in marker[0]:
                            Cor += int(marker[1])
                            LV += 1
                            LV_list.append(int(marker[0][2:]))
                            if '1-1' in marker[2]:
                                if 'LV' in marker[3]:
                                    pass
                                else:
                                    if [int(marker[3]) < t for l, t in GNG_LV.items() if marker[0] == l]:
                                        RTint = int(marker[3])
                                        RT_list.append(RTint)
                        else:
                            pass
                    else:
                        pass
                if not LV_list:
                    Max.append(1)
                else:
                    Max.append(max(LV_list))
                Cor_list.append(Cor)
                if len(RT_list) is not 0:
                    RT.append(sum(RT_list) / len(RT_list))
                else:
                    RT.append(0)
                
                if LV == 0:
                    Acc.append(0)
                else:
                    Acc.append(Cor/LV)
                
            pack['%s_Cor' % v] = Cor_list
            pack['%s_RT' % v] = RT
            pack['%s_ACC' % v] = Acc
            pack['%s_max' % v] = Max
            print('정답률, 반응시간')
            print('과제 완료')
        
        elif 'STRC' in v or 'STRI' in v:
            for i in idx:
                Cor, LV = 0, 0
                RT_list = []
                for j in col:
                    if pd.isnull(m_data[v][j][i]) == False:
                        marker = m_data[v][j][i].split('/')
                        if 'LV' in marker[0]:
                            Cor += int(marker[1])
                            LV += 1
                            if marker[1] == '1':
                                if 'LV' in marker[3]:
                                    pass
                                else:
                                    if int(marker[3]) < 2000 :
                                        RTint = int(marker[3])
                                        RT_list.append(RTint)
                        else:
                            pass
                    else:
                        pass
                Cor_list.append(Cor)
                if len(RT_list) is not 0:
                    RT.append(sum(RT_list) / len(RT_list))
                else:
                    RT.append(0)
                
                if LV == 0:
                    Acc.append(0)
                else:
                    Acc.append(Cor/LV)
                
            pack['%s_Cor' % v] = Cor_list
            pack['%s_RT' % v] = RT
            pack['%s_ACC' % v] = Acc
            print('정답률, 반응시간')
            print('과제 완료')
            
        elif 'TWOBACK' in v:
            for i in idx:
                Cor, LV = 0, 0
                RT_list = []
                for j in col:
                    if pd.isnull(m_data[v][j][i]) == False:
                        marker = m_data[v][j][i].split('/')
                        if 'LV' in marker[0]:
                            Cor += int(marker[1])
                            LV += 1
                            if '1-1' in marker[2]:
                                if 'LV' in marker[3]:
                                    pass
                                else:
#                                 if int(marker[3]) < 2000 :
                                    RTint = int(marker[3])
                                    RT_list.append(RTint)
                        else:
                            pass
                    else:
                        pass
                Cor_list.append(Cor)
                if len(RT_list) is not 0:
                    RT.append(sum(RT_list) / len(RT_list))
                else:
                    RT.append(0)
                
                if LV == 0:
                    Acc.append(0)
                else:
                    Acc.append(Cor/LV)
                
            pack['%s_Cor' % v] = Cor_list
            pack['%s_RT' % v] = RT
            pack['%s_ACC' % v] = Acc
            print('정답률, 반응시간')
            print('과제 완료')
            
            
        elif 'CBTTF' in v or 'CBTTB' in v:
            for i in idx:
                Cor, LV = 0, 0
                LV_list = []
                for j in col:
                    if pd.isnull(m_data[v][j][i]) == False:
                        marker = m_data[v][j][i].split('/')
                        if 'LV' in marker[0]:
                            Cor += int(marker[1])
                            LV += 1
                            LV_list.append(int(marker[0][2:]))
                        else:
                            pass
                    else:
                        pass
#                 print(LV_list)
                if not LV_list:
                    Max.append(1)
                else:
                    Max.append(max(LV_list))
                Cor_list.append(Cor)
                if LV == 0:
                    Acc.append(0)
                else:
                    Acc.append(Cor/LV)
            pack['%s_Cor' % v] = Cor_list
            pack['%s_ACC' % v] = Acc
            pack['%s_max' % v] = Max
            print('정답률')
            print('과제 완료')
            
        elif 'MIND' in v or 'REPEAT' in v or 'FOLD' in v:
            for i in idx:
                Cor, LV = 0, 0
                LV_list = []
                for j in col:
                    if pd.isnull(m_data[v][j][i]) == False:
                        marker = m_data[v][j][i].split('/')
                        if 'LV' in marker[0]:
                            Cor += int(marker[1])
                            LV += 1
                            LV_list.append(int(marker[0][2:]))
                        else:
                            pass
                    else:
                        pass
#                 print(LV_list)
                if not LV_list:
                    Max.append(1)
                else:
                    Max.append(max(LV_list))
                Cor_list.append(Cor)
                if LV == 0:
                    Acc.append(0)
                else:
                    Acc.append(Cor/LV)
            pack['%s_Cor' % v] = Cor_list
            pack['%s_ACC' % v] = Acc
            pack['%s_max' % v] = Max
            print('정답률')
            print('과제 완료')    
        else:
            print('pass')
            pass
        
        List = List.merge(pack, on='taskUUID', how = 'outer')
    List['GNG_z'] = List['GNG_ACC'] / List['GNG_RT']*1000
    List['STRC_z'] =  List['STRC_ACC'] / List['STRC_RT']*1000
    List['STRI_z'] =  List['STRI_ACC'] / List['STRI_RT']*1000
    List['STRE'] =  abs(List['STRC_RT'] - List['STRI_RT'])/1000
    List['STRE_z'] =  abs(List['STRI_z'] - List['STRC_z'])
    List.to_excel(export + '.xlsx', sheet_name = 'data')
    print('caculate 완료')
    return List
    
def raw_to_data(raw):
    """
        작성자: sjyoo
        작성일: 190611
        기능: table을 분석용 dict로 내보내기
        입력: raw table(dataframe)
        출력: raw_data = dict{pd.DataFrame{task pivot)}
        용례: raw_data = raw_to_data(pandas DataFrame(raw))
        메모: 데이터에 따라 pivot/pivot_table 조절
    """
    tasks = {1:'REST',2:'CBTTF',3:'CBTTB',4:'GNG',5:'TWOBACK',6:'STRC',7:'STRI',8:'VFT',9:'REPEAT',10:'MIND',11:'FOLD'}
    task_num = raw['taskType'].unique()
    raw_data = {}
    for task in tasks.values():
        raw_data[task]= pd.DataFrame()
#     print(raw)
    for k in task_num:
        task_ind = raw.query('taskType == "' + k +'"')
#         print(task_ind)
        # data = task_ind.pivot(columns = 'childName', values = 'raw')
        # data = pd.pivot_table(task_ind, index = 'index', columns = 'childName', values = 'raw', aggfunc=np.sum, margins = True)
        raw_data[tasks[int(k)]] = pd.pivot_table(task_ind, index = 'index', columns = 'taskUUID', values = 'ra', aggfunc=np.sum)
        print('%s  실행' % k)
    return raw_data

def request_to_table(url, uuid, my_id, my_pw):
    """
        작성자: cmlee
        수정자: sjyoo
        작성일: 190509
        수정일: 190611 
        기능: 요청 정보를 이용해서 서버에서 데이터 테이블 형태로 반환
        입력: url, id, pw, taskuuid
        출력: pandas DataFrame : header + contents
        용례: raw, list_raw = request_to_table(str(api_url), str(uuid)/ list(uuid), str(my_id), str(my_pw))
    """
    raw = pd.DataFrame()
#     list_raw = pd.DataFrame()
    print('table 요청 시작')
    for child in uuid:
        print(child + '_로딩 중....')
        url_uuid = url + '?taskUUID=' + child
        r = requests.get(url=url_uuid, auth=HTTPBasicAuth(my_id, my_pw))
        r = r.content.decode("utf-8")
        r = re.split('\n|\r', r)
        t_head = r.pop(0).split(',')
        t_head[-1] = t_head[-1][0:-1]
        t_body = [t.split(',') for t in r if t != '']
        full = pd.DataFrame(t_body, columns=t_head)
        full = full[full.taskUUID != '']
        tasks = full['taskType'].unique()
        for task in tasks:
            task_raw = full.query('taskType == "' + str(task) +'"')
            mx = task_raw.taskSubID.max()
            if mx != '':
                t_mx_raw = task_raw.query('taskSubID == "'+str(mx)+'"')
                raw = pd.concat([raw, t_mx_raw], axis=0)
        print('%s 완료' % child)
#     list_raw['name'] = raw['childName']
#     list_raw['uuid'] = raw['taskUUID']
#     list_raw = list_raw.drop_duplicates(keep = 'last')
    print("raw export 완료")
#     return raw, list_raw
    return raw


def access_to_table(connect_info, uuid, table = 'uuid'):
    """
        작성자: sjyoo
        작성일: 190611
        기능: table 접속
        입력: connect_info: id, pw; uuid = taskuuid; table = 받고 싶은 데이터 table
        출력: pandas DataFrame : 현재는 performance 
        용례: raw = access_to_table(connect_info, uuid, table = 'uuid'&'raw'&'perf')
    """
    # base_url = 'http://ec2-15-164-48-95.ap-northeast-2.compute.amazonaws.com'
    base_url = 'http://obelab-api.com'
    api_uuid = base_url + '/api/analysis/taskuuid/'
    api_raw = base_url + '/api/analysis/metaraw/'
    api_perf = base_url + '/api/analysis/metamarker/'
    print('table access 시작')
    if table == 'uuid':
        return request_to_table(api_uuid, uuid, connect_info[0], connect_info[1])
    elif table == 'raw':
        return request_to_table(api_raw, uuid, connect_info[0], connect_info[1])
    elif table == 'perf':
        return request_to_table(api_perf, uuid, connect_info[0], connect_info[1])
    print("raw 완료")


def get_UUID(connect_info, date1 = '2000-01-01', date2 = '2030-01-01'):
    """
        작성자: sjyoo
        작성일: 190612
        기능: date로 아이디 뽑아내기. UUID 뽑을 거임.
        입력: 접속 정보, 시작일, 종료일
        출력: uuid 리스트
        용례: get_UUID(접속정보, 시작일, 종료일)
    """
    base_url = 'http://obelab-api.com'
    api_uuid = base_url + '/api/analysis/taskuuid/'
    uuid = pd.DataFrame()
    #지금은 다 불러와서 date로 filtering
    r = requests.get(url=api_uuid, auth=HTTPBasicAuth(connect_info[0], connect_info[1]))
    r = r.content.decode("utf-8")
    r = re.split('\n|\r', r)
    t_head = r.pop(0).split(',')
    t_head[-1] = t_head[-1][0:-1]
    t_body = [t.split(',') for t in r]
    data = pd.DataFrame(t_body, columns=t_head)
    data = data.query('taskCreated >= "' + date1 + '" and taskCreated <= "' + date2 +'"')
    pack = []
    for b, c in zip(data.childBirth, data.taskCreated):
#         birth = datetime.datetime.strptime(b, '%Y/%m/%d')
        birth = parse(b)
        testdate = datetime.datetime.strptime(c, '%Y-%m-%d %H:%M:%S.%f+00:00')
        ag = testdate.year - birth.year
        pack.append(ag)
    data['age'] = pack
    data.pop('sn')
    data = data.drop_duplicates(keep = 'last')
    return data


def server_connect_info():
    my_id = 'admin'
    my_pw = 'obe1234'

    return my_id, my_pw

# %%
connect_info = server_connect_info()
list_raw = get_UUID(connect_info, '2019-06-21', '2019-07-01')
target_child = list_raw.taskUUID
# target_child = List.taskUUID.unique()
# target_child = ['HgwQ9iNB', 'vnTJNL39']
# print(target_child)
# Out:
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\ipykernel_launcher.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# raw, list_raw = access_to_table(connect_info = connect_info, uuid=target_child, table = 'perf') #한예준
raw = access_to_table(connect_info = connect_info, uuid=target_child, table = 'perf') #한예준
# Out:
# table access 시작
# table 요청 시작
# gC9AsvWo_로딩 중....
# gC9AsvWo 완료
# kNkYISVX_로딩 중....
# kNkYISVX 완료
# XWs8g7W7_로딩 중....
# XWs8g7W7 완료
# 0VbY8s8y_로딩 중....
# 0VbY8s8y 완료
# 4amBUpGr_로딩 중....
# 4amBUpGr 완료
# ltaugEV0_로딩 중....
# ltaugEV0 완료
# DSy6ICtC_로딩 중....
# DSy6ICtC 완료
# 2fJ6f7jV_로딩 중....
# 2fJ6f7jV 완료
# BB9c6XWE_로딩 중....
# BB9c6XWE 완료
# bLClV9FD_로딩 중....
# bLClV9FD 완료
# VgV9xVTl_로딩 중....
# VgV9xVTl 완료
# rFBukveE_로딩 중....
# rFBukveE 완료
# Oa6gbbGg_로딩 중....
# Oa6gbbGg 완료
# SmRgdCu8_로딩 중....
# SmRgdCu8 완료
# DaBUUQI1_로딩 중....
# DaBUUQI1 완료
# tKGlt6hI_로딩 중....
# tKGlt6hI 완료
# RiWmyDhW_로딩 중....
# RiWmyDhW 완료
# xU1X7Dl9_로딩 중....
# xU1X7Dl9 완료
# x7LKQk4s_로딩 중....
# x7LKQk4s 완료
# AYmcwoid_로딩 중....
# AYmcwoid 완료
# RdE7k5PY_로딩 중....
# RdE7k5PY 완료
# u02vI3so_로딩 중....
# u02vI3so 완료
# Q5E07Fpg_로딩 중....
# Q5E07Fpg 완료
# wgYUFVYC_로딩 중....
# wgYUFVYC 완료
# 5Kezxygb_로딩 중....
# 5Kezxygb 완료
# uEl2EHo1_로딩 중....
# uEl2EHo1 완료
# MKfcvdHK_로딩 중....
# MKfcvdHK 완료
# RnCJh4Nq_로딩 중....
# RnCJh4Nq 완료
# k6BxPKL3_로딩 중....
# k6BxPKL3 완료
# yvQ4lcXD_로딩 중....
# yvQ4lcXD 완료
# ER1862nl_로딩 중....
# ER1862nl 완료
# OxWGYVDi_로딩 중....
# OxWGYVDi 완료
# eMxlSIcI_로딩 중....
# eMxlSIcI 완료
# ww7rsreK_로딩 중....
# ww7rsreK 완료
# hcwgcrXh_로딩 중....
# hcwgcrXh 완료
# kiAmbg6z_로딩 중....
# kiAmbg6z 완료
# uXnbto3j_로딩 중....
# uXnbto3j 완료
# tWSekl7h_로딩 중....
# tWSekl7h 완료
# tm1qIkmV_로딩 중....
# tm1qIkmV 완료
# OtiOrREn_로딩 중....
# OtiOrREn 완료
# 0mVSxzKi_로딩 중....
# 0mVSxzKi 완료
# KpDNCVUp_로딩 중....
# KpDNCVUp 완료
# xHe90oty_로딩 중....
# xHe90oty 완료
# IxKpftok_로딩 중....
# IxKpftok 완료
# oC0iO9f0_로딩 중....
# oC0iO9f0 완료
# n79Mc1NU_로딩 중....
# n79Mc1NU 완료
# PUaVTuhp_로딩 중....
# PUaVTuhp 완료
# JMcqWbzI_로딩 중....
# JMcqWbzI 완료
# BVGJWIlM_로딩 중....
# BVGJWIlM 완료
# gjhzk0NE_로딩 중....
# gjhzk0NE 완료
# BJVWd4g1_로딩 중....
# BJVWd4g1 완료
# 80oh8vSk_로딩 중....
# 80oh8vSk 완료
# XG3TBINu_로딩 중....
# XG3TBINu 완료
# V9Aw4O1u_로딩 중....
# V9Aw4O1u 완료
# ZNUFYQIt_로딩 중....
# ZNUFYQIt 완료
# RwR0hwIR_로딩 중....
# RwR0hwIR 완료
# bsRdyWvR_로딩 중....
# bsRdyWvR 완료
# K2HHOloq_로딩 중....
# K2HHOloq 완료
# 210ShqQ0_로딩 중....
# 210ShqQ0 완료
# X2FI5caK_로딩 중....
# X2FI5caK 완료
# FxOlmzkI_로딩 중....
# FxOlmzkI 완료
# x7D7OVZv_로딩 중....
# x7D7OVZv 완료
# 8Qj7lY67_로딩 중....
# 8Qj7lY67 완료
# MnhN21w5_로딩 중....
# MnhN21w5 완료
# bsafrmYf_로딩 중....
# bsafrmYf 완료
# 90pnFTMj_로딩 중....
# 90pnFTMj 완료
# Luq756Gg_로딩 중....
# Luq756Gg 완료
# MSaDq6iv_로딩 중....
# MSaDq6iv 완료
# ccqEI4pG_로딩 중....
# ccqEI4pG 완료
# me28c6u2_로딩 중....
# me28c6u2 완료
# WyOeHdQP_로딩 중....
# WyOeHdQP 완료
# 0SJAi4Yw_로딩 중....
# 0SJAi4Yw 완료
# KeQ22xmM_로딩 중....
# KeQ22xmM 완료
# 6P5EbzbH_로딩 중....
# 6P5EbzbH 완료
# ynFCCHJG_로딩 중....
# ynFCCHJG 완료
# 7Eo2495v_로딩 중....
# 7Eo2495v 완료
# kDcZ2OAZ_로딩 중....
# kDcZ2OAZ 완료
# oHwS0CQt_로딩 중....
# oHwS0CQt 완료
# rcc7FKsl_로딩 중....
# rcc7FKsl 완료
# p19acSKw_로딩 중....
# p19acSKw 완료
# XiYC6wdV_로딩 중....
# XiYC6wdV 완료
# TbqludOp_로딩 중....
# TbqludOp 완료
# pG4oJaDI_로딩 중....
# pG4oJaDI 완료
# HPOnGfcR_로딩 중....
# HPOnGfcR 완료
# j5ANHSic_로딩 중....
# j5ANHSic 완료
# KU03GD3j_로딩 중....
# KU03GD3j 완료
# zQZnOGWT_로딩 중....
# zQZnOGWT 완료
# X6z135iW_로딩 중....
# X6z135iW 완료
# Ph0ATJl6_로딩 중....
# Ph0ATJl6 완료
# mUdMuNLE_로딩 중....
# mUdMuNLE 완료
# ylufPEaF_로딩 중....
# ylufPEaF 완료
# iaSc3OFM_로딩 중....
# iaSc3OFM 완료
# 17a6ad7f-c5aa-4424-a277-9415ebf705af_로딩 중....
# 17a6ad7f-c5aa-4424-a277-9415ebf705af 완료
# cf0d7c92-75f5-4d8a-9542-779133166af7_로딩 중....
# cf0d7c92-75f5-4d8a-9542-779133166af7 완료
# 7a7d50ab-ceb1-4f06-b75c-7ac8e8ec170a_로딩 중....
# 7a7d50ab-ceb1-4f06-b75c-7ac8e8ec170a 완료
# f21336c7-46e5-4aa7-857c-048733461d3a_로딩 중....
# f21336c7-46e5-4aa7-857c-048733461d3a 완료
# L772Qcd2_로딩 중....
# L772Qcd2 완료
# moC28S3g_로딩 중....
# moC28S3g 완료
# 64af1b5f-9ebe-4788-af91-44fc56c4d48b_로딩 중....
# 64af1b5f-9ebe-4788-af91-44fc56c4d48b 완료
# 39337991-4823-4618-9f60-0fc8d74f7912_로딩 중....
# 39337991-4823-4618-9f60-0fc8d74f7912 완료
# 3266418e-ef1c-4dbd-9ba6-b4cfe54df9c7_로딩 중....
# 3266418e-ef1c-4dbd-9ba6-b4cfe54df9c7 완료
# MIcdhkZL_로딩 중....
# MIcdhkZL 완료
# wo9kGBto_로딩 중....
# wo9kGBto 완료
# 9nhRD6OB_로딩 중....
# 9nhRD6OB 완료
# n4C6NSvI_로딩 중....
# n4C6NSvI 완료
# 3C7p2Ma5_로딩 중....
# 3C7p2Ma5 완료
# Nzl7lzAg_로딩 중....
# Nzl7lzAg 완료
# GLlx3n2m_로딩 중....
# GLlx3n2m 완료
# vv58puHh_로딩 중....
# vv58puHh 완료
# o9NpfUyE_로딩 중....
# o9NpfUyE 완료
# hJrStq95_로딩 중....
# hJrStq95 완료
# DCKKpSYu_로딩 중....
# DCKKpSYu 완료
# 2rYTicgy_로딩 중....
# 2rYTicgy 완료
# JWx7jRnq_로딩 중....
# JWx7jRnq 완료
# m5mZJnMZ_로딩 중....
# m5mZJnMZ 완료
# w66SN85I_로딩 중....
# w66SN85I 완료
# Bs7h2TuL_로딩 중....
# Bs7h2TuL 완료
# 0wyBQdtV_로딩 중....
# 0wyBQdtV 완료
# 08WRPDYk_로딩 중....
# 08WRPDYk 완료
# G0ckvFL2_로딩 중....
# G0ckvFL2 완료
# WD9v7dlM_로딩 중....
# WD9v7dlM 완료
# uVco6IfQ_로딩 중....
# uVco6IfQ 완료
# Rcnw9zQj_로딩 중....
# Rcnw9zQj 완료
# agNfBhgx_로딩 중....
# agNfBhgx 완료
# c4JZrlEZ_로딩 중....
# c4JZrlEZ 완료
# B8WqUIAV_로딩 중....
# B8WqUIAV 완료
# yiCFK3G9_로딩 중....
# yiCFK3G9 완료
# I7GuLcIP_로딩 중....
# I7GuLcIP 완료
# LZyWCg7O_로딩 중....
# LZyWCg7O 완료
# Fp9uZ2lp_로딩 중....
# Fp9uZ2lp 완료
# YfeMAOsJ_로딩 중....
# YfeMAOsJ 완료
# AidXHXkb_로딩 중....
# AidXHXkb 완료
# RtKtvMHc_로딩 중....
# RtKtvMHc 완료
# dPLf4VHe_로딩 중....
# dPLf4VHe 완료
# 7d9gH6kD_로딩 중....
# 7d9gH6kD 완료
# BzKhB9qp_로딩 중....
# BzKhB9qp 완료
# jdz8NpHS_로딩 중....
# jdz8NpHS 완료
# xN7FdAoB_로딩 중....
# xN7FdAoB 완료
# pMQPSGTX_로딩 중....
# pMQPSGTX 완료
# UiCJBS2A_로딩 중....
# UiCJBS2A 완료
# HgwQ9iNB_로딩 중....
# HgwQ9iNB 완료
# Rk2Ecilm_로딩 중....
# Rk2Ecilm 완료
# vnTJNL39_로딩 중....
# vnTJNL39 완료
# Z5myGPDm_로딩 중....
# Z5myGPDm 완료
# pJgiCXra_로딩 중....
# pJgiCXra 완료
# 1RXAuLQJ_로딩 중....
# 1RXAuLQJ 완료
# 1Q9qFSOm_로딩 중....
# 1Q9qFSOm 완료
# KfB7q6O9_로딩 중....
# KfB7q6O9 완료
# fki6QenG_로딩 중....
# fki6QenG 완료
# spPJ1OAV_로딩 중....
# spPJ1OAV 완료
# neOZSkpM_로딩 중....
# neOZSkpM 완료
# z99SeBjE_로딩 중....
# z99SeBjE 완료
# umlAbA55_로딩 중....
# umlAbA55 완료
# hXHI6pum_로딩 중....
# hXHI6pum 완료
# Zbd8zJwd_로딩 중....
# Zbd8zJwd 완료
# t9Vd3FeT_로딩 중....
# t9Vd3FeT 완료
# TUnESKLZ_로딩 중....
# TUnESKLZ 완료
# zHe5JhkQ_로딩 중....
# zHe5JhkQ 완료
# suP74y0Q_로딩 중....
# suP74y0Q 완료
# nsLS0CQd_로딩 중....
# nsLS0CQd 완료
# bhvtp6v7_로딩 중....
# bhvtp6v7 완료
# jbaYTAOB_로딩 중....
# jbaYTAOB 완료
# dTya2VLA_로딩 중....
# dTya2VLA 완료
# 5Sdhc0kN_로딩 중....
# 5Sdhc0kN 완료
# 5XOBEjj2_로딩 중....
# 5XOBEjj2 완료
# Yr1iyrQm_로딩 중....
# Yr1iyrQm 완료
# mdeQNDLG_로딩 중....
# mdeQNDLG 완료
# HndNQBp2_로딩 중....
# HndNQBp2 완료
# Z24AxBYv_로딩 중....
# Z24AxBYv 완료
# Os70LsJ7_로딩 중....
# Os70LsJ7 완료
# jm4GPg80_로딩 중....
# jm4GPg80 완료
# EhGoqTgC_로딩 중....
# EhGoqTgC 완료
# VK6kyQ0a_로딩 중....
# VK6kyQ0a 완료
# GiiRw5HQ_로딩 중....
# GiiRw5HQ 완료
# CnnTZXyc_로딩 중....
# CnnTZXyc 완료
# DvzMaNtm_로딩 중....
# DvzMaNtm 완료
# 9ZQzm610_로딩 중....
# 9ZQzm610 완료
# LR9sQVZp_로딩 중....
# LR9sQVZp 완료
# Hpd2Y6Wt_로딩 중....
# Hpd2Y6Wt 완료
# L2pww7yZ_로딩 중....
# L2pww7yZ 완료
# LWkLgV3V_로딩 중....
# LWkLgV3V 완료
# b07TdYLb_로딩 중....
# b07TdYLb 완료
# zSGbu7dL_로딩 중....
# zSGbu7dL 완료
# jBdExZmr_로딩 중....
# jBdExZmr 완료
# PJft1QFV_로딩 중....
# PJft1QFV 완료
# Wuxh0mdk_로딩 중....
# Wuxh0mdk 완료
# t1SryqKp_로딩 중....
# t1SryqKp 완료
# Z4e2HtD2_로딩 중....
# Z4e2HtD2 완료
# hhyE8lk2_로딩 중....
# hhyE8lk2 완료
# PLHGiDZe_로딩 중....
# PLHGiDZe 완료
# TOYglSXB_로딩 중....
# TOYglSXB 완료
# xwjf9ZMy_로딩 중....
# xwjf9ZMy 완료
# TSY6fQME_로딩 중....
# TSY6fQME 완료
# KT8IJJ5H_로딩 중....
# KT8IJJ5H 완료
# FHJPNfHV_로딩 중....
# FHJPNfHV 완료
# WNQwDI0u_로딩 중....
# WNQwDI0u 완료
# 8JVhK65h_로딩 중....
# 8JVhK65h 완료
# bGISMepj_로딩 중....
# bGISMepj 완료
# nB0SxI3H_로딩 중....
# nB0SxI3H 완료
# 05qwdZZ2_로딩 중....
# 05qwdZZ2 완료
# NJ0vvQ7g_로딩 중....
# NJ0vvQ7g 완료
# uZr25Z6O_로딩 중....
# uZr25Z6O 완료
# 8xbT023E_로딩 중....
# 8xbT023E 완료
# BEUCE6av_로딩 중....
# BEUCE6av 완료
# VB0Zmb0x_로딩 중....
# VB0Zmb0x 완료
# P234cbtn_로딩 중....
# P234cbtn 완료
# IauirubD_로딩 중....
# IauirubD 완료
# Q3JTPNTo_로딩 중....
# Q3JTPNTo 완료
# eK3ECHZr_로딩 중....
# eK3ECHZr 완료
# uNZ0pTIv_로딩 중....
# uNZ0pTIv 완료
# D6qsOouh_로딩 중....
# D6qsOouh 완료
# V4qZF4mn_로딩 중....
# V4qZF4mn 완료
# XZSwjpRk_로딩 중....
# XZSwjpRk 완료
# dH213liL_로딩 중....
# dH213liL 완료
# 4InLBdn6_로딩 중....
# 4InLBdn6 완료
# pbmpR2fe_로딩 중....
# pbmpR2fe 완료
# HbEge1Hs_로딩 중....
# HbEge1Hs 완료
# DNY6xDFy_로딩 중....
# DNY6xDFy 완료
# BngxI53Y_로딩 중....
# BngxI53Y 완료
# 5UPEy4UN_로딩 중....
# 5UPEy4UN 완료
# 7z7JB6zs_로딩 중....
# 7z7JB6zs 완료
# 0mUuEmi2_로딩 중....
# 0mUuEmi2 완료
# LofRdlgl_로딩 중....
# LofRdlgl 완료
# nBQM3JA4_로딩 중....
# nBQM3JA4 완료
# 0gLgbNZl_로딩 중....
# 0gLgbNZl 완료
# D30YR5ET_로딩 중....
# D30YR5ET 완료
# IjOAipPV_로딩 중....
# IjOAipPV 완료
# t6PKKrTY_로딩 중....
# t6PKKrTY 완료
# 0EtpplJy_로딩 중....
# 0EtpplJy 완료
# CqB5QwHQ_로딩 중....
# CqB5QwHQ 완료
# 3KFrnlbc_로딩 중....
# 3KFrnlbc 완료
# LwzX0zex_로딩 중....
# LwzX0zex 완료
# PR0g6hI9_로딩 중....
# PR0g6hI9 완료
# a3GCiPN4_로딩 중....
# a3GCiPN4 완료
# raw export 완료

# %%
raw_data = raw_to_data(raw)
# Out:
# 1  실행
# 2  실행
# 3  실행
# 4  실행
# 5  실행
# 6  실행
# 7  실행
# 8  실행
# 9  실행
# 10  실행
# 11  실행

# %%
List = data_merge(list_raw, raw_data, '정상데이터 로직')
# Out:
# merge 시작
# key : 1, value : REST
# pass
# key : 2, value : CBTTF
# 정답률
# 과제 완료
# key : 3, value : CBTTB
# 정답률
# 과제 완료
# key : 4, value : GNG
# 정답률, 반응시간
# 과제 완료
# key : 5, value : TWOBACK
# 정답률, 반응시간
# 과제 완료
# key : 6, value : STRC
# 정답률, 반응시간
# 과제 완료
# key : 7, value : STRI
# 정답률, 반응시간
# 과제 완료
# key : 8, value : VFT
# pass
# key : 9, value : REPEAT
# 정답률
# 과제 완료
# key : 10, value : MIND
# 정답률
# 과제 완료
# key : 11, value : FOLD
# 정답률
# 과제 완료
# caculate 완료

# %%
s_data = data_scoring(raw, '분석용scoring0711')
# Out:
# scoring data listing 시작
# key : 1, value : REST
# key : 2, value : CBTTF
# CBTTF 과제 완료
# key : 3, value : CBTTB
# CBTTB 과제 완료
# key : 4, value : GNG
# GNG 과제 완료
# key : 5, value : TWOBACK
# TWOBACK 과제 완료
# key : 6, value : STRC
# STRC 과제 완료
# key : 7, value : STRI
# STRI 과제 완료
# key : 8, value : VFT
# key : 9, value : REPEAT
# REPEAT 과제 완료
# key : 10, value : MIND
# MIND 과제 완료
# key : 11, value : FOLD
# FOLD 과제 완료
# 정리 완료

# %%
FO = s_data['FOLD']
FO = FO[FO.FOLD_Cor != 'Cor']
for uni in FO.FOLD_LV.unique():
    print(uni)
    A = FO[FO.FOLD_LV == uni]
    B = A.FOLD_Cor.astype('int')
    print(B.mean())
# Out:
# LV1
# 0.7303370786516854
# LV2
# 0.4943820224719101
# LV3
# 0.4748603351955307
# LV4
# 0.3559322033898305
# LV5
# 0.2994350282485876
# LV6
# 0.3559322033898305
# LV7
# 0.5423728813559322
# LV8
# 0.3559322033898305
# LV9
# 0.6101694915254238
# LV10
# 0.4915254237288136
# LV11
# 0.42134831460674155
# LV12
# 0.327683615819209
# LV13
# 0.384180790960452
# LV14
# 0.4011299435028249

# %%
Stage = {'GNG_Stage' :{'LV1':0.1 ,'LV2':0.2,'LV3':0.3,'LV4':0.4,'LV5':0.5,'LV6':0.6,'LV7':0.7,'LV8':0.8,'LV9':0.9,'LV10':1,'LV11':1.1,'LV12':1.2,'LV13':1.3,'LV14':1.4, 'LV15' : 1.5},
'CBTTF_Stage' : {'LV1':0 ,'LV2':0,'LV3':0.5,'LV4':0.8,'LV5':1,'LV6':1.2,'LV7':1.5,'LV8':1.7,'LV9':0,'LV10':0,'LV11':0,'LV12':0,'LV13':0,'LV14':0},
'CBTTB_Stage' : {'LV1':0 ,'LV2':0,'LV3':0.5,'LV4':0.8,'LV5':1,'LV6':1.2,'LV7':1.5,'LV8':1.7,'LV9':0,'LV10':0,'LV11':0,'LV12':0,'LV13':0,'LV14':0},
'REPEAT_Stage' : {'LV1': 1,'LV2':1.2,'LV3':1.4,'LV4':1.6,'LV5':1.8,'LV6':2,'LV7':2.2,'LV8':2.4,'LV9':2.6,'LV10':0,'LV11':0,'LV12':0,'LV13':0,'LV14':0},
'FOLD_Stage' : {'LV1': 1,'LV2':1,'LV3':1,'LV4':3,'LV5':3,'LV6':3,'LV7':1,'LV8':3,'LV9':1,'LV10':2,'LV11':2,'LV12':3,'LV13':3,'LV14':2}}

# %%
print(s_data)
# Out:
# {'REST':     taskUUID       parentUUID parentName childName  appVersion  \
# 0   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 1   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 2   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 3   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 4   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 5   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 0   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 1   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 2   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 3   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 4   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 5   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 0   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# 1   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# 2   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# 3   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# 4   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# 5   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# 0   0VbY8s8y  20191530_060600        이서은       백은서  WJ v0.0.19
# 1   0VbY8s8y  20191530_060600        이서은       백은서  WJ v0.0.19
# 2   0VbY8s8y  20191530_060600        이서은       백은서  WJ v0.0.19
# 3   0VbY8s8y  20191530_060600        이서은       백은서  WJ v0.0.19
# 4   0VbY8s8y  20191530_060600        이서은       백은서  WJ v0.0.19
# 5   0VbY8s8y  20191530_060600        이서은       백은서  WJ v0.0.19
# 0   4amBUpGr  20191230_060650        서혜영       김도현  WJ v0.0.19
# 1   4amBUpGr  20191230_060650        서혜영       김도현  WJ v0.0.19
# 2   4amBUpGr  20191230_060650        서혜영       김도현  WJ v0.0.19
# 3   4amBUpGr  20191230_060650        서혜영       김도현  WJ v0.0.19
# 4   4amBUpGr  20191230_060650        서혜영       김도현  WJ v0.0.19
# 5   4amBUpGr  20191230_060650        서혜영       김도현  WJ v0.0.19
# ..       ...              ...        ...       ...         ...
# 5   CqB5QwHQ  20194821_030637        정원선       배지원  WJ v0.0.18
# 0   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 1   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 2   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 3   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 4   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 5   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 0   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 1   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 2   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 3   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 4   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 5   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 6   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 7   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 8   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 9   LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 10  LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 11  LwzX0zex  20193321_020650        정원선       배지원  WJ v0.0.18
# 0   PR0g6hI9  20191721_020641         하이        바이  WJ v0.0.18
# 46  PR0g6hI9  20191721_020641         하이        바이  WJ v0.0.18
# 0   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 1   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 2   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 3   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 4   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 5   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 6   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 7   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 8   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
#
#                               deviceAddr         deviceUUID taskSubID  \
# 0   594ed040-872e-4d96-956e-337311cb29a5          장비 접속중 .          1
# 1   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 2   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 3   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 4   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 5   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 0   b9aabe48-9764-40c5-8ef6-610d3206b831          장비 접속중 .          1
# 1   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 2   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 3   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 4   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 5   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 0   a02f84cf-388d-4e90-bd39-4740121af3e3          장비 접속중 .          1
# 1   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# 2   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# 3   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# 4   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# 5   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# 0   594ed040-872e-4d96-956e-337311cb29a5          장비 접속중 .          1
# 1   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 2   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 3   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 4   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 5   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 0   b9aabe48-9764-40c5-8ef6-610d3206b831          장비 접속중 .          1
# 1   b9aabe48-9764-40c5-8ef6-610d3206b831  D0:CF:5E:D8:8F:82         1
# 2   b9aabe48-9764-40c5-8ef6-610d3206b831  D0:CF:5E:D8:8F:82         1
# 3   b9aabe48-9764-40c5-8ef6-610d3206b831  D0:CF:5E:D8:8F:82         1
# 4   b9aabe48-9764-40c5-8ef6-610d3206b831  D0:CF:5E:D8:8F:82         1
# 5   b9aabe48-9764-40c5-8ef6-610d3206b831  D0:CF:5E:D8:8F:82         1
# ..                                   ...                ...       ...
# 5   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 0   183072ac-23c7-4981-bc1a-ffe0b7064923          장비 접속중 .          1
# 1   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 2   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 3   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 4   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 5   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 0   15fb6e69-f4f1-49b6-a008-60810c1dcc36          장비 접속중 .          1
# 1   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 2   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 3   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 4   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 5   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 6   15fb6e69-f4f1-49b6-a008-60810c1dcc36          장비 접속중 .          1
# 7   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 8   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 9   15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 10  15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 11  15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 0   2017a4be-1abc-4ef9-b278-30a8a29d5a00          장비 접속중 .          1
# 46  2017a4be-1abc-4ef9-b278-30a8a29d5a00          장비 접속중 .          1
# 0   2017a4be-1abc-4ef9-b278-30a8a29d5a00          장비 접속중 .          1
# 1   2017a4be-1abc-4ef9-b278-30a8a29d5a00          장비 접속중 .          1
# 2   2017a4be-1abc-4ef9-b278-30a8a29d5a00          장비 접속중 .          1
# 3   2017a4be-1abc-4ef9-b278-30a8a29d5a00          장비 접속중 .          1
# 4   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 5   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 6   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 7   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 8   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
#
#    taskStatus taskType appStatus index          ctime
# 0           4        1         1  3929  1561890703848
# 1           5        1         1  3930  1561890765188
# 2           0        1         1  3931  1561890765202
# 3           1        1         1  3932  1561890765227
# 4           7        1         1  3933  1561890945240
# 5           3        1         1  3934  1561890945380
# 0           4        1         1  4160  1561889576419
# 1           5        1         1  4161  1561889607286
# 2           0        1         1  4162  1561889607301
# 3           1        1         1  4163  1561889607329
# 4           7        1         1  4164  1561889787407
# 5           3        1         1  4165  1561889787597
# 0           4        1         1  4287  1561888245060
# 1           5        1         1  4288  1561888274500
# 2           0        1         1  4289  1561888274512
# 3           1        1         1  4290  1561888274532
# 4           7        1         1  4291  1561888454650
# 5           3        1         1  4292  1561888454856
# 0           4        1         1  3600  1561886514182
# 1           5        1         1  3601  1561886530871
# 2           0        1         1  3602  1561886530880
# 3           1        1         1  3603  1561886530898
# 4           7        1         1  3604  1561886710998
# 5           3        1         1  3605  1561886711315
# 0           4        1         1  3826  1561886386689
# 1           5        1         1  3827  1561886410568
# 2           0        1         1  3828  1561886410578
# 3           1        1         1  3829  1561886410602
# 4           7        1         1  3830  1561886590684
# 5           3        1         1  3831  1561886590918
# ..        ...      ...       ...   ...            ...
# 5           3        1         1   651  1561100241065
# 0           4        1         1     1  1561096385576
# 1           5        1         1     2  1561096408610
# 2           0        1         1     3  1561096408621
# 3           1        1         1     4  1561096408646
# 4           7        1         1     5  1561096588710
# 5           3        1         1     6  1561096588991
# 0           4        1         1   634  1561095460592
# 1           5        1         1   635  1561095563193
# 2           0        1         1   636  1561095563205
# 3           1        1         1   637  1561095563236
# 4           7        1         1   638  1561095743286
# 5           3        1         1   639  1561095743464
# 6           4        1         1   640  1561095757655
# 7           5        1         1   641  1561095764992
# 8           0        1         1   642  1561095765005
# 9           1        1         1   643  1561095765025
# 10          7        1         1   644  1561095945073
# 11          3        1         1   645  1561095945247
# 0           4        1         1   284  1561094284641
# 46          4        1         1   330  1561094783630
# 0           4        1         1     1  1561082367982
# 1           4        1         1     2  1561082455260
# 2           4        1         1     3  1561082488645
# 3           4        1         1     4  1561082497393
# 4           5        1         1     5  1561082523630
# 5           0        1         1     6  1561082523641
# 6           1        1         1     7  1561082523665
# 7           7        1         1     8  1561082703701
# 8           3        1         1     9  1561082703916
#
# [1370 rows x 13 columns], 'CBTTF':     taskUUID       parentUUID parentName childName  appVersion  \
# 6   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 7   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 8   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 9   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 10  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 11  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 12  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 13  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 14  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 15  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 16  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 17  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 18  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 19  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 20  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 6   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 7   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 8   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 9   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 10  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 11  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 12  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 13  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 14  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 15  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 16  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 17  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 18  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 19  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 6   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# ..       ...              ...        ...       ...         ...
# 18  CqB5QwHQ  20194821_030637        정원선       배지원  WJ v0.0.18
# 19  CqB5QwHQ  20194821_030637        정원선       배지원  WJ v0.0.18
# 6   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 7   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 8   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 9   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 10  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 11  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 12  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 13  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 14  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 15  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 16  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 17  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 18  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 19  3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 9   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 10  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 11  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 12  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 13  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 14  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 15  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 16  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 17  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 18  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 19  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 20  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 21  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 22  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
#
#                               deviceAddr         deviceUUID taskSubID  \
# 6   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 7   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 8   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 9   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 10  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 11  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 12  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 13  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 14  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 15  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 16  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 17  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 18  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 19  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 20  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 6   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 7   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 8   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 9   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 10  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 11  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 12  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 13  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 14  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 15  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 16  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 17  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 18  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 19  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 6   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# ..                                   ...                ...       ...
# 18  15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 19  15fb6e69-f4f1-49b6-a008-60810c1dcc36  08:6B:D7:7C:6B:CF         1
# 6   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 7   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 8   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 9   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 10  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 11  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 12  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 13  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 14  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 15  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 16  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 17  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 18  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 19  183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 9   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 10  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 11  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 12  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 13  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 14  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 15  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 16  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 17  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 18  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 19  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 20  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 21  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 22  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
#
#    taskStatus taskType appStatus index          ctime  \
# 6           5        2         1  3935  1561891054985
# 7           0        2         1  3936  1561891054991
# 8           1        2         1  3937  1561891085059
# 9           1        2         1  3938  1561891092142
# 10          1        2         1  3939  1561891102652
# 11          1        2         1  3940  1561891113510
# 12          1        2         1  3941  1561891125441
# 13          1        2         1  3942  1561891125471
# 14          1        2         1  3943  1561891133481
# 15          1        2         1  3944  1561891145562
# 16          1        2         1  3945  1561891153333
# 17          1        2         1  3946  1561891163105
# 18          1        2         1  3947  1561891174368
# 19          7        2         1  3948  1561891175129
# 20          3        2         1  3949  1561891180246
# 6           5        2         1  4166  1561889877549
# 7           0        2         1  4167  1561889877555
# 8           1        2         1  4168  1561889907637
# 9           1        2         1  4169  1561889915028
# 10          1        2         1  4170  1561889925260
# 11          1        2         1  4171  1561889936068
# 12          1        2         1  4172  1561889945875
# 13          1        2         1  4173  1561889955655
# 14          1        2         1  4174  1561889965952
# 15          1        2         1  4175  1561889976376
# 16          1        2         1  4176  1561889986259
# 17          1        2         1  4177  1561889996165
# 18          7        2         1  4178  1561889997679
# 19          3        2         1  4179  1561890002822
# 6           5        2         1  4293  1561888545266
# ..        ...      ...       ...   ...            ...
# 18          7        2         1   664  1561100785226
# 19          3        2         1   665  1561100790281
# 6           5        2         1     7  1561096743567
# 7           0        2         1     8  1561096743574
# 8           1        2         1     9  1561096773724
# 9           1        2         1    10  1561096783649
# 10          1        2         1    11  1561096793659
# 11          1        2         1    12  1561096803745
# 12          1        2         1    13  1561096813806
# 13          1        2         1    14  1561096823856
# 14          1        2         1    15  1561096833937
# 15          1        2         1    16  1561096843978
# 16          1        2         1    17  1561096854012
# 17          7        2         1    18  1561096863705
# 18          7        2         1    19  1561096863719
# 19          3        2         1    20  1561096868841
# 9           5        2         1    10  1561082801743
# 10          0        2         1    11  1561082801749
# 11          1        2         1    12  1561082831843
# 12          1        2         1    13  1561082841971
# 13          1        2         1    14  1561082851993
# 14          1        2         1    15  1561082862074
# 15          1        2         1    16  1561082872139
# 16          1        2         1    17  1561082882174
# 17          1        2         1    18  1561082889365
# 18          1        2         1    19  1561082898807
# 19          1        2         1    20  1561082908732
# 20          1        2         1    21  1561082919515
# 21          7        2         1    22  1561082921895
# 22          3        2         1    23  1561082927030
#
#                                ra CBTTF_LV CBTTF_Cor      CBTTF_Act  \
# 6                             NaN       LV       Cor            Act
# 7                             NaN       LV       Cor            Act
# 8                             NaN       LV       Cor            Act
# 9              LV3/1/631-631/2067      LV3         1        631-631
# 10             LV3/1/354-354/1972      LV3         1        354-354
# 11           LV4/1/2187-2187/2775      LV4         1      2187-2187
# 12            LV4/0/825-3825/4549      LV4         0       825-3825
# 13  LV4/0/8259-3825/1561891125465      LV4         0      8259-3825
# 14           LV4/1/2143-2143/2484      LV4         1      2143-2143
# 15            LV4/0/485-8465/4557      LV4         0       485-8465
# 16           LV4/1/6413-6413/2231      LV4         1      6413-6413
# 17           LV4/1/2758-2758/1909      LV4         1      2758-2758
# 18         LV5/1/58427-58427/3072      LV5         1    58427-58427
# 19                            NaN       LV       Cor            Act
# 20                            NaN       LV       Cor            Act
# 6                             NaN       LV       Cor            Act
# 7                             NaN       LV       Cor            Act
# 8                             NaN       LV       Cor            Act
# 9              LV3/1/437-437/2278      LV3         1        437-437
# 10             LV3/1/178-178/2042      LV3         1        178-178
# 11           LV4/1/5432-5432/2787      LV4         1      5432-5432
# 12           LV4/1/5283-5283/2538      LV4         1      5283-5283
# 13         LV5/1/24517-24517/2272      LV5         1    24517-24517
# 14         LV5/1/47162-47162/2537      LV5         1    47162-47162
# 15       LV6/0/452781-457281/3001      LV6         0  452781-457281
# 16       LV6/0/286347-268314/2688      LV6         0  286347-268314
# 17       LV6/0/175386-173586/2596      LV6         0  175386-173586
# 18                            NaN       LV       Cor            Act
# 19                            NaN       LV       Cor            Act
# 6                             NaN       LV       Cor            Act
# ..                            ...      ...       ...            ...
# 18               LV3/0/0-531/3184      LV3         0          0-531
# 19                            NaN       LV       Cor            Act
# 6                             NaN       LV       Cor            Act
# 7                             NaN       LV       Cor            Act
# 8                             NaN       LV       Cor            Act
# 9                LV3/0/0-358/4363      LV3         0          0-358
# 10               LV3/0/0-867/4454      LV3         0          0-867
# 11               LV3/0/0-342/4527      LV3         0          0-342
# 12               LV3/0/0-873/4504      LV3         0          0-873
# 13               LV3/0/0-781/4480      LV3         0          0-781
# 14               LV3/0/0-674/4420      LV3         0          0-674
# 15               LV3/0/0-523/4478      LV3         0          0-523
# 16               LV3/0/0-687/4474      LV3         0          0-687
# 17                            NaN       LV       Cor            Act
# 18               LV3/0/0-534/4143      LV3         0          0-534
# 19                            NaN       LV       Cor            Act
# 9                             NaN       LV       Cor            Act
# 10                            NaN       LV       Cor            Act
# 11                            NaN       LV       Cor            Act
# 12               LV3/0/0-325/4473      LV3         0          0-325
# 13               LV3/0/0-184/4421      LV3         0          0-184
# 14               LV3/0/0-823/4446      LV3         0          0-823
# 15               LV3/0/0-512/4457      LV3         0          0-512
# 16               LV3/0/0-136/4425      LV3         0          0-136
# 17             LV3/0/635-465/1624      LV3         0        635-465
# 18             LV3/1/271-271/1089      LV3         1        271-271
# 19              LV3/1/853-853/969      LV3         1        853-853
# 20           LV4/0/7524-1852/1676      LV4         0      7524-1852
# 21                            NaN       LV       Cor            Act
# 22                            NaN       LV       Cor            Act
#
#          CBTTF_RT
# 6              RT
# 7              RT
# 8              RT
# 9            2067
# 10           1972
# 11           2775
# 12           4549
# 13  1561891125465
# 14           2484
# 15           4557
# 16           2231
# 17           1909
# 18           3072
# 19             RT
# 20             RT
# 6              RT
# 7              RT
# 8              RT
# 9            2278
# 10           2042
# 11           2787
# 12           2538
# 13           2272
# 14           2537
# 15           3001
# 16           2688
# 17           2596
# 18             RT
# 19             RT
# 6              RT
# ..            ...
# 18           3184
# 19             RT
# 6              RT
# 7              RT
# 8              RT
# 9            4363
# 10           4454
# 11           4527
# 12           4504
# 13           4480
# 14           4420
# 15           4478
# 16           4474
# 17             RT
# 18           4143
# 19             RT
# 9              RT
# 10             RT
# 11             RT
# 12           4473
# 13           4421
# 14           4446
# 15           4457
# 16           4425
# 17           1624
# 18           1089
# 19            969
# 20           1676
# 21             RT
# 22             RT
#
# [2857 rows x 18 columns], 'CBTTB':      taskUUID       parentUUID parentName childName  appVersion  \
# 21   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 22   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 23   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 24   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 25   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 26   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 27   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 28   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 29   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 30   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 31   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 32   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 33   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 34   gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 20   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 21   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 22   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 23   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 24   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 25   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 26   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 27   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 28   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 29   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 30   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 31   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 32   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 33   kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 20   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# 21   XWs8g7W7  20194830_060624        최혜연       이예진  WJ v0.0.19
# ..        ...              ...        ...       ...         ...
# 177  0EtpplJy  20192721_020609         한일        예정  WJ v0.0.18
# 178  0EtpplJy  20192721_020609         한일        예정  WJ v0.0.18
# 20   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 21   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 22   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 23   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 24   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 25   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 26   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 27   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 28   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 29   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 30   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 31   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 32   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 33   3KFrnlbc  20195021_020622   qa0621.2  qa0621.2  WJ v0.0.18
# 23   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 24   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 25   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 26   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 27   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 28   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 29   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 30   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 31   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 32   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 33   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 34   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 35   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 36   a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
#
#                                deviceAddr         deviceUUID taskSubID  \
# 21   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 22   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 23   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 24   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 25   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 26   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 27   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 28   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 29   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 30   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 31   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 32   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 33   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 34   594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 20   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 21   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 22   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 23   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 24   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 25   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 26   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 27   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 28   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 29   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 30   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 31   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 32   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 33   b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 20   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# 21   a02f84cf-388d-4e90-bd39-4740121af3e3  08:6B:D7:7C:6B:CF         1
# ..                                    ...                ...       ...
# 177  032e3da0-8d2b-4a18-9723-d12dda08aa49  08:6B:D7:7C:6B:F4         2
# 178  032e3da0-8d2b-4a18-9723-d12dda08aa49  08:6B:D7:7C:6B:F4         2
# 20   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 21   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 22   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 23   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 24   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 25   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 26   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 27   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 28   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 29   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 30   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 31   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 32   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 33   183072ac-23c7-4981-bc1a-ffe0b7064923  08:6B:D7:7C:6B:B4         1
# 23   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 24   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 25   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 26   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 27   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 28   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 29   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 30   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 31   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 32   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 33   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 34   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 35   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 36   2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
#
#     taskStatus taskType appStatus index          ctime  \
# 21           5        3         1  3950  1561891277445
# 22           0        3         1  3951  1561891277450
# 23           1        3         1  3952  1561891307524
# 24           1        3         1  3953  1561891315673
# 25           1        3         1  3954  1561891325871
# 26           1        3         1  3955  1561891334716
# 27           1        3         1  3956  1561891345251
# 28           1        3         1  3957  1561891355851
# 29           1        3         1  3958  1561891365444
# 30           1        3         1  3959  1561891375524
# 31           1        3         1  3960  1561891386869
# 32           1        3         1  3961  1561891396045
# 33           7        3         1  3962  1561891397581
# 34           3        3         1  3963  1561891402641
# 20           5        3         1  4180  1561890081432
# 21           0        3         1  4181  1561890081438
# 22           1        3         1  4182  1561890111508
# 23           1        3         1  4183  1561890118081
# 24           1        3         1  4184  1561890128297
# 25           1        3         1  4185  1561890140283
# 26           1        3         1  4186  1561890149092
# 27           1        3         1  4187  1561890159902
# 28           1        3         1  4188  1561890169762
# 29           1        3         1  4189  1561890179946
# 30           1        3         1  4190  1561890190127
# 31           1        3         1  4191  1561890200700
# 32           7        3         1  4192  1561890201595
# 33           3        3         1  4193  1561890206653
# 20           5        3         1  4307  1561888734161
# 21           0        3         1  4308  1561888734168
# ..         ...      ...       ...   ...            ...
# 177          7        3         1  1077  1561100300424
# 178          3        3         1  1078  1561100305431
# 20           5        3         1    21  1561096962266
# 21           0        3         1    22  1561096962274
# 22           1        3         1    23  1561096992372
# 23           1        3         1    24  1561097002412
# 24           1        3         1    25  1561097012511
# 25           1        3         1    26  1561097022590
# 26           1        3         1    27  1561097032609
# 27           1        3         1    28  1561097042707
# 28           1        3         1    29  1561097052647
# 29           1        3         1    30  1561097062715
# 30           1        3         1    31  1561097072730
# 31           7        3         1    32  1561097082454
# 32           7        3         1    33  1561097082466
# 33           3        3         1    34  1561097087558
# 23           5        3         1    24  1561082984962
# 24           0        3         1    25  1561082984968
# 25           1        3         1    26  1561083014973
# 26           1        3         1    27  1561083025061
# 27           1        3         1    28  1561083035041
# 28           1        3         1    29  1561083045161
# 29           1        3         1    30  1561083055136
# 30           1        3         1    31  1561083065184
# 31           1        3         1    32  1561083075231
# 32           1        3         1    33  1561083085252
# 33           1        3         1    34  1561083095245
# 34           7        3         1    35  1561083105056
# 35           7        3         1    36  1561083105109
# 36           3        3         1    37  1561083110181
#
#                            ra CBTTB_LV CBTTB_Cor      CBTTB_Act CBTTB_RT
# 21                        NaN       LV       Cor            Act       RT
# 22                        NaN       LV       Cor            Act       RT
# 23                        NaN       LV       Cor            Act       RT
# 24         LV3/0/375-537/3110      LV3         0        375-537     3110
# 25         LV3/1/248-248/2711      LV3         1        248-248     2711
# 26         LV3/1/742-742/1522      LV3         1        742-742     1522
# 27       LV4/0/1354-1345/2052      LV4         0      1354-1345     2052
# 28       LV4/0/5847-7485/2499      LV4         0      5847-7485     2499
# 29       LV4/1/6372-6372/2076      LV4         1      6372-6372     2076
# 30       LV4/0/3278-3287/2157      LV4         0      3278-3287     2157
# 31       LV4/1/3741-3741/3352      LV4         1      3741-3741     3352
# 32       LV4/0/2184-2481/2559      LV4         0      2184-2481     2559
# 33                        NaN       LV       Cor            Act       RT
# 34                        NaN       LV       Cor            Act       RT
# 20                        NaN       LV       Cor            Act       RT
# 21                        NaN       LV       Cor            Act       RT
# 22                        NaN       LV       Cor            Act       RT
# 23         LV3/1/645-645/1507      LV3         1        645-645     1507
# 24         LV3/1/371-371/1216      LV3         1        371-371     1216
# 25       LV4/1/7286-7286/3179      LV4         1      7286-7286     3179
# 26       LV4/1/3526-3526/1946      LV4         1      3526-3526     1946
# 27     LV5/1/52478-52478/2722      LV5         1    52478-52478     2722
# 28     LV5/1/76253-76253/2492      LV5         1    76253-76253     2492
# 29   LV6/1/671258-671258/2672      LV6         1  671258-671258     2672
# 30   LV6/0/871253-871523/2771      LV6         0  871253-871523     2771
# 31   LV6/1/638521-638521/3238      LV6         1  638521-638521     3238
# 32                        NaN       LV       Cor            Act       RT
# 33                        NaN       LV       Cor            Act       RT
# 20                        NaN       LV       Cor            Act       RT
# 21                        NaN       LV       Cor            Act       RT
# ..                        ...      ...       ...            ...      ...
# 177          LV3/0/0-241/4214      LV3         0          0-241     4214
# 178                       NaN       LV       Cor            Act       RT
# 20                        NaN       LV       Cor            Act       RT
# 21                        NaN       LV       Cor            Act       RT
# 22                        NaN       LV       Cor            Act       RT
# 23           LV3/0/0-724/4426      LV3         0          0-724     4426
# 24           LV3/0/0-318/4541      LV3         0          0-318     4541
# 25           LV3/0/0-746/4521      LV3         0          0-746     4521
# 26           LV3/0/0-724/4466      LV3         0          0-724     4466
# 27           LV3/0/0-286/4542      LV3         0          0-286     4542
# 28           LV3/0/0-457/4366      LV3         0          0-457     4366
# 29           LV3/0/0-146/4518      LV3         0          0-146     4518
# 30           LV3/0/0-287/4463      LV3         0          0-287     4463
# 31                        NaN       LV       Cor            Act       RT
# 32           LV3/0/0-286/4198      LV3         0          0-286     4198
# 33                        NaN       LV       Cor            Act       RT
# 23                        NaN       LV       Cor            Act       RT
# 24                        NaN       LV       Cor            Act       RT
# 25                        NaN       LV       Cor            Act       RT
# 26           LV3/0/0-673/4432      LV3         0          0-673     4432
# 27           LV3/0/0-783/4401      LV3         0          0-783     4401
# 28           LV3/0/0-342/4539      LV3         0          0-342     4539
# 29           LV3/0/0-216/4401      LV3         0          0-216     4401
# 30           LV3/0/0-234/4470      LV3         0          0-234     4470
# 31           LV3/0/0-534/4447      LV3         0          0-534     4447
# 32           LV3/0/0-264/4410      LV3         0          0-264     4410
# 33           LV3/0/0-674/4431      LV3         0          0-674     4431
# 34                        NaN       LV       Cor            Act       RT
# 35           LV3/0/0-873/4302      LV3         0          0-873     4302
# 36                        NaN       LV       Cor            Act       RT
#
# [2707 rows x 18 columns], 'GNG':     taskUUID       parentUUID parentName childName  appVersion  \
# 35  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 36  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 37  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 38  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 39  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 40  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 41  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 42  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 43  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 44  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 45  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 46  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 47  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 48  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# ...
# 263      LV      Cor      Act      RT
#
# [4647 rows x 18 columns], 'FOLD':      taskUUID       parentUUID parentName childName  appVersion  \
# 310  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 311  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 312  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 313  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 314  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 315  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 316  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 317  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 318  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 319  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 320  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 321  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 322  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 323  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 324  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 325  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 326  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 327  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 328  gC9AsvWo  20192530_070645        김애경       심규연  WJ v0.0.19
# 306  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 307  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 308  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 309  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 310  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 311  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 312  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 313  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 314  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 315  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# 316  kNkYISVX  20190730_070609        김애경       심규민  WJ v0.0.19
# ..        ...              ...        ...       ...         ...
# 314  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 315  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 316  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 317  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 318  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 319  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 320  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 321  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 322  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 323  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 324  IjOAipPV  20195221_040617         ㅣㅣ       ㅛㅗㅠ  WJ v0.0.18
# 264  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 265  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 266  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 267  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 268  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 269  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 270  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 271  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 272  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 273  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 274  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 275  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 276  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 277  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 278  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 279  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 280  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 281  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
# 282  a3GCiPN4  20195721_100622     qa0621    qa0621  WJ v0.0.18
#
#                                deviceAddr         deviceUUID taskSubID  \
# 310  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 311  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 312  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 313  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 314  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 315  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 316  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 317  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 318  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 319  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 320  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 321  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 322  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 323  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 324  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 325  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 326  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 327  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 328  594ed040-872e-4d96-956e-337311cb29a5  D0:CF:5E:D8:91:1B         1
# 306  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 307  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 308  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 309  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 310  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 311  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 312  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 313  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 314  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 315  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# 316  b9aabe48-9764-40c5-8ef6-610d3206b831  08:6B:D7:7C:6C:54         1
# ..                                    ...                ...       ...
# 314  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 315  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 316  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 317  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 318  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 319  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 320  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 321  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 322  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 323  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 324  6fe5c2d0-80b7-4ed4-8b6f-4953d811d574  08:6B:D7:7C:6C:16         1
# 264  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 265  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 266  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 267  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 268  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 269  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 270  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 271  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 272  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 273  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 274  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 275  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 276  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 277  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 278  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 279  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 280  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 281  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
# 282  2017a4be-1abc-4ef9-b278-30a8a29d5a00  08:6B:D7:7C:6B:B4         1
#
#     taskStatus taskType appStatus index          ctime               ra  \
# 310          5       11         1  4239  1561892951001              NaN
# 311          0       11         1  4240  1561892951017              NaN
# 312          1       11         1  4241  1561892981176              NaN
# 313          1       11         1  4242  1561892989693   LV1/1/4-4/6797
# 314          1       11         1  4243  1561892998278   LV2/0/3-1/3451
# 315          1       11         1  4244  1561893006796   LV3/0/0-3/7500
# 316          1       11         1  4245  1561893015267   LV4/0/3-1/5419
# 317          1       11         1  4246  1561893023895   LV5/0/3-2/6161
# 318          1       11         1  4247  1561893032371   LV6/0/0-5/7500
# 319          1       11         1  4248  1561893040961   LV7/1/4-4/3651
# 320          1       11         1  4249  1561893049460   LV8/0/2-4/7886
# 321          1       11         1  4250  1561893057973   LV9/0/0-4/7500
# 322          1       11         1  4251  1561893066544  LV10/0/4-2/3980
# 323          1       11         1  4252  1561893075054  LV11/0/4-3/8152
# 324          1       11         1  4253  1561893083634  LV12/0/0-4/7500
# 325          1       11         1  4254  1561893092230  LV13/1/2-2/6710
# 326          7       11         1  4255  1561893100187              NaN
# 327          7       11         1  4256  1561893100210  LV14/0/0-3/7500
# 328          3       11         1  4257  1561893105244              NaN
# 306          5       11         1  4466  1561892019326              NaN
# 307          0       11         1  4467  1561892019333              NaN
# 308          1       11         1  4468  1561892049396              NaN
# 309          1       11         1  4469  1561892057915   LV1/1/4-4/8109
# 310          1       11         1  4470  1561892066506   LV2/1/1-1/6028
# 311          1       11         1  4471  1561892075065   LV3/1/3-3/5305
# 312          1       11         1  4472  1561892083556   LV4/1/1-1/5662
# 313          1       11         1  4473  1561892092085   LV5/0/0-2/7500
# 314          1       11         1  4474  1561892100664   LV6/0/3-5/6464
# 315          1       11         1  4475  1561892109162   LV7/1/4-4/4988
# 316          1       11         1  4476  1561892117749   LV8/1/4-4/6182
# ..         ...      ...       ...   ...            ...              ...
# 314          1       11         1   315  1561107221490   LV6/1/5-5/6824
# 315          1       11         1   316  1561107230011   LV7/1/4-4/3970
# 316          1       11         1   317  1561107238595   LV8/1/4-4/5482
# 317          1       11         1   318  1561107247193   LV9/1/4-4/4916
# 318          1       11         1   319  1561107255697  LV10/1/2-2/2813
# 319          1       11         1   320  1561107264330  LV11/1/3-3/4953
# 320          1       11         1   321  1561107272882  LV12/1/4-4/7168
# 321          1       11         1   322  1561107281451  LV13/1/2-2/6245
# 322          7       11         1   323  1561107289235              NaN
# 323          7       11         1   324  1561107289256  LV14/0/0-3/7500
# 324          3       11         1   325  1561107294370              NaN
# 264          5       11         1   265  1561093864073              NaN
# 265          0       11         1   266  1561093864078              NaN
# 266          1       11         1   267  1561093894098              NaN
# 267          1       11         1   268  1561093902728   LV1/1/4-4/3952
# 268          1       11         1   269  1561093911283   LV2/1/1-1/6709
# 269          1       11         1   270  1561093919858   LV3/1/3-3/3642
# 270          1       11         1   271  1561093928435   LV4/0/0-1/7500
# 271          1       11         1   272  1561093937139   LV5/0/1-2/4278
# 272          1       11         1   273  1561093945557   LV6/1/5-5/6006
# 273          1       11         1   274  1561093954147   LV7/1/4-4/5165
# 274          1       11         1   275  1561093962713   LV8/1/4-4/8152
# 275          1       11         1   276  1561093971285   LV9/1/4-4/5127
# 276          1       11         1   277  1561093979857  LV10/1/2-2/4584
# 277          1       11         1   278  1561093988428  LV11/1/3-3/4051
# 278          1       11         1   279  1561093997025  LV12/0/0-4/7500
# 279          1       11         1   280  1561094005575  LV13/1/2-2/7258
# 280          7       11         1   281  1561094013146              NaN
# 281          7       11         1   282  1561094013184  LV14/0/0-3/7500
# 282          3       11         1   283  1561094018229              NaN
#
#     FOLD_LV FOLD_Cor FOLD_Act FOLD_RT
# 310      LV      Cor      Act      RT
# 311      LV      Cor      Act      RT
# 312      LV      Cor      Act      RT
# 313     LV1        1      4-4    6797
# 314     LV2        0      3-1    3451
# 315     LV3        0      0-3    7500
# 316     LV4        0      3-1    5419
# 317     LV5        0      3-2    6161
# 318     LV6        0      0-5    7500
# 319     LV7        1      4-4    3651
# 320     LV8        0      2-4    7886
# 321     LV9        0      0-4    7500
# 322    LV10        0      4-2    3980
# 323    LV11        0      4-3    8152
# 324    LV12        0      0-4    7500
# 325    LV13        1      2-2    6710
# 326      LV      Cor      Act      RT
# 327    LV14        0      0-3    7500
# 328      LV      Cor      Act      RT
# 306      LV      Cor      Act      RT
# 307      LV      Cor      Act      RT
# 308      LV      Cor      Act      RT
# 309     LV1        1      4-4    8109
# 310     LV2        1      1-1    6028
# 311     LV3        1      3-3    5305
# 312     LV4        1      1-1    5662
# 313     LV5        0      0-2    7500
# 314     LV6        0      3-5    6464
# 315     LV7        1      4-4    4988
# 316     LV8        1      4-4    6182
# ..      ...      ...      ...     ...
# 314     LV6        1      5-5    6824
# 315     LV7        1      4-4    3970
# 316     LV8        1      4-4    5482
# 317     LV9        1      4-4    4916
# 318    LV10        1      2-2    2813
# 319    LV11        1      3-3    4953
# 320    LV12        1      4-4    7168
# 321    LV13        1      2-2    6245
# 322      LV      Cor      Act      RT
# 323    LV14        0      0-3    7500
# 324      LV      Cor      Act      RT
# 264      LV      Cor      Act      RT
# 265      LV      Cor      Act      RT
# 266      LV      Cor      Act      RT
# 267     LV1        1      4-4    3952
# 268     LV2        1      1-1    6709
# 269     LV3        1      3-3    3642
# 270     LV4        0      0-1    7500
# 271     LV5        0      1-2    4278
# 272     LV6        1      5-5    6006
# 273     LV7        1      4-4    5165
# 274     LV8        1      4-4    8152
# 275     LV9        1      4-4    5127
# 276    LV10        1      2-2    4584
# 277    LV11        1      3-3    4051
# 278    LV12        0      0-4    7500
# 279    LV13        1      2-2    7258
# 280      LV      Cor      Act      RT
# 281    LV14        0      0-3    7500
# 282      LV      Cor      Act      RT
#
# [3403 rows x 18 columns]}

# %%
pack = pd.DataFrame()

for task in s_data:
    print(task)
    score = []
    if 'REST' in task or 'VFT' in task or 'TWOBACK' in task or 'STRC' in task or 'STRI' in task or 'MIND' in task :
        print('pass')
        pass
    else:
        print('start')
        ta = s_data[task]
        ta = ta[ta['%s_Cor' % task] != 'Cor']
        children = List.taskUUID
        pack['taskUUID'] = children
        for uni_c in children:
            Cor_list = []
            ta_c = ta[ta.taskUUID == uni_c]
            keys = ta_c['%s_LV' % task]
            for k in keys.unique():
                Cor_values = ta_c['%s_Cor' % task][ta_c['%s_LV' % task] == k]
                Cor = np.sum(Cor_values.astype('int'))
                Cor_list.append(Cor)

            ta_c_dict = dict(zip(keys.unique(),Cor_list))
#             score = 0
#             for k in TA_c_dict.keys():
#                 score += TA_c_dict[k]*Stage['%s_Stage' % task][k]
            score.append(sum(ta_c_dict[k]*Stage['%s_Stage' % task][k] for k in ta_c_dict.keys()))
        
        pack['%s_score' % task ] = score
        print(pack.columns)
List_s = List.merge(pack, on='taskUUID', how ='inner')
#         List_s = pd.concat([List_s,pack], ignore_index = True, sort = False)
# Out:
# REST
# pass
# CBTTF
# start
# Index(['taskUUID', 'CBTTF_score'], dtype='object')
# CBTTB
# start
# Index(['taskUUID', 'CBTTF_score', 'CBTTB_score'], dtype='object')
# GNG
# start
# Index(['taskUUID', 'CBTTF_score', 'CBTTB_score', 'GNG_score'], dtype='object')
# TWOBACK
# pass
# STRC
# pass
# STRI
# pass
# VFT
# pass
# REPEAT
# start
# Index(['taskUUID', 'CBTTF_score', 'CBTTB_score', 'GNG_score', 'REPEAT_score'], dtype='object')
# MIND
# pass
# FOLD
# start
# Index(['taskUUID', 'CBTTF_score', 'CBTTB_score', 'GNG_score', 'REPEAT_score',
#        'FOLD_score'],
#       dtype='object')

# %%
List_s.columns
# Out:
# Index(['parentUUID', 'taskUUID', 'parentName', 'childName', 'childSex',
#        'childBirth', 'taskCreated', 'taskUpdated', 'completed', 'age',
#        'CBTTF_Cor', 'CBTTF_ACC', 'CBTTF_max', 'CBTTB_Cor', 'CBTTB_ACC',
#        'CBTTB_max', 'GNG_Cor', 'GNG_RT', 'GNG_ACC', 'GNG_max', 'TWOBACK_Cor',
#        'TWOBACK_RT', 'TWOBACK_ACC', 'STRC_Cor', 'STRC_RT', 'STRC_ACC',
#        'STRI_Cor', 'STRI_RT', 'STRI_ACC', 'REPEAT_Cor', 'REPEAT_ACC',
#        'REPEAT_max', 'MIND_Cor', 'MIND_ACC', 'MIND_max', 'FOLD_Cor',
#        'FOLD_ACC', 'FOLD_max', 'GNG_z', 'STRC_z', 'STRI_z', 'STRE', 'STRE_z',
#        'CBTTF_score', 'CBTTB_score', 'GNG_score', 'REPEAT_score',
#        'FOLD_score'],
#       dtype='object')

# %%
List_s.to_excel('List_s20190715.xlsx')

# %%
path = os.getcwd()
k_wisc_file = os.path.join(path, 'K-WISC-V_coding.xlsx')
k_wisc = pd.read_excel(k_wisc_file, columns = 0, index_col = 0)

# %%
List_s_k = List_s.merge(k_wisc, left_on= 'childName', right_on = '아동명', how = 'outer')

# %%
List_s_k1 = List_s.merge(k_wisc, left_on= 'childName', right_on = '아동명', how = 'inner')

# %%
List_s_k1.to_excel('List_s_k0715.xlsx')

# %%
age_sex = pd.crosstab(List_s_k1.childSex, List_s_k1.age,  margins=True)
print(age_sex.index)

# %%
sns.set(font_scale=0.5)
mpl.rcParams['axes.unicode_minus'] = False
path = 'C:/Windows/Fonts/HYSNRL.ttf'
font_name = fm.FontProperties(fname=path).get_name()
plt.rc('font', family=font_name)


List_s_k1[List_s_k1.dtypes[(List_s_k1.dtypes=="float64")|(List_s_k1.dtypes=="int64")]
                        .index.values].hist(figsize=[15,15])

# %%
sns.set(font_scale=1)
for feature in List_s_k1:
    print(feature)
    if 'RT' in feature or 'ACC' in feature or 'max' in feature or '_z' in feature or 'raw' in feature or 'score' in feature: 
        a = List_s_k1[feature]
        qqplot(a,line='r')
        plt.show()
    else:
        print('pass')
        pass

# %%
for feature in List_s:
    print(feature)
    if 'RT' in feature or 'ACC' in feature or 'max' in feature or '_z' in feature or 'raw' in feature or 'score' in feature: 
        a = List_s[feature]
        sns.distplot(a.dropna())
        plt.show()
    else:
        print('pass')
        pass

# %%
g = sns.FacetGrid(List_s, row='age', col='childSex')
g.map(sns.distplot, "FOLD_ACC")
plt.show()

# %%
List_s_k_corr = List_s_k1[['childName', 'childSex', 'age',
       'CBTTF_Cor', 'CBTTF_ACC', 'CBTTF_max', 'CBTTB_Cor', 'CBTTB_ACC',
       'CBTTB_max', 'GNG_Cor', 'GNG_RT', 'GNG_ACC', 'GNG_max', 'TWOBACK_Cor',
       'TWOBACK_RT', 'TWOBACK_ACC', 'STRC_Cor', 'STRC_RT', 'STRC_ACC',
       'STRI_Cor', 'STRI_RT', 'STRI_ACC', 'REPEAT_Cor', 'REPEAT_ACC',
       'REPEAT_max', 'MIND_Cor', 'MIND_ACC', 'FOLD_Cor',
       'FOLD_ACC', 'GNG_z', 'STRC_z', 'STRI_z', 'STRE_z',
       'CBTTF_score', 'CBTTB_score', 'GNG_score', 'REPEAT_score', 'FOLD_score',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]

OBE_corr = List_s_k1[['childName', 'childSex', 'age',
       'CBTTF_Cor', 'CBTTF_ACC', 'CBTTF_max', 'CBTTB_Cor', 'CBTTB_ACC',
       'CBTTB_max', 'GNG_Cor', 'GNG_RT', 'GNG_ACC', 'GNG_max', 'TWOBACK_Cor',
       'TWOBACK_RT', 'TWOBACK_ACC', 'STRC_Cor', 'STRC_RT', 'STRC_ACC',
       'STRI_Cor', 'STRI_RT', 'STRI_ACC', 'REPEAT_Cor', 'REPEAT_ACC',
       'REPEAT_max', 'MIND_Cor', 'MIND_ACC', 'FOLD_Cor',
       'FOLD_ACC', 'GNG_z', 'STRC_z', 'STRI_z', 'STRE_z',
       'CBTTF_score', 'CBTTB_score', 'GNG_score', 'REPEAT_score', 'FOLD_score']]

CBTT_corr = List_s_k1[['childName', 'childSex', 'age',
       'CBTTF_Cor', 'CBTTF_ACC', 'CBTTF_max',
       'CBTTB_Cor', 'CBTTB_ACC', 'CBTTB_max', 
       'CBTTF_score', 'CBTTB_score',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]

GNG_corr = List_s_k1[['childName', 'childSex', 'age',
       'GNG_Cor', 'GNG_RT', 'GNG_ACC', 'GNG_max', 'GNG_score',  'GNG_z',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]

TWOBACK_corr = List_s_k1[['childName', 'childSex', 'age',
       'TWOBACK_Cor', 'TWOBACK_RT', 'TWOBACK_ACC',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]

STR_corr = List_s_k1[['childName', 'childSex', 'age',
       'STRC_Cor', 'STRC_RT', 'STRC_ACC',
       'STRI_Cor', 'STRI_RT', 'STRI_ACC', 
       'STRC_z', 'STRI_z', 'STRE_z',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]

STR_corr['STRE'] = STR_corr['STRI_RT'] - STR_corr['STRC_RT']

REPEAT_corr = List_s_k1[['childName', 'childSex', 'age',
       'REPEAT_Cor', 'REPEAT_ACC', 'REPEAT_max', 'REPEAT_score',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]

MIND_corr = List_s_k1[['childName', 'childSex', 'age',
       'MIND_Cor', 'MIND_ACC',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]

FOLD_corr = List_s_k1[['childName', 'childSex', 'age',
       'FOLD_ACC', 'FOLD_score',
       'toamc_raw', 'tomac_z_score', 'Similarities_raw',
       'Similarities_z_score', 'Matrix_raw', 'Matrix_z_score', 'Digit_raw',
       'Digit_z_score', 'Symbol_raw', 'Symbol_z_score', 'Vocabulary_raw',
       'Vocabulary_z_score', 'weight_raw', 'weight_z_score']]


# OBE_s_corr = List_s[['childName', 'childSex', 'age',+
#        'CBTTF_Cor', 'CBTTF_ACC', 'CBTTF_max', 'CBTTB_Cor', 'CBTTB_ACC',
#        'CBTTB_max', 'GNG_Cor', 'GNG_RT', 'GNG_ACC', 'GNG_max', 'TWOBACK_Cor',
#        'TWOBACK_RT', 'TWOBACK_ACC', 'STRC_Cor', 'STRC_RT', 'STRC_ACC',
#        'STRI_Cor', 'STRI_RT', 'STRI_ACC', 'REPEAT_Cor', 'REPEAT_ACC',
#        'REPEAT_max', 'MIND_Cor', 'MIND_ACC', 'FOLD_Cor',
#        'FOLD_ACC', 'GNG_z', 'STRC_z', 'STRI_z', 'STRE_z',
#        'CBTTF_score', 'CBTTB_score', 'GNG_score', 'REPEAT_score', 'FOLD_score']]

# OBE_s_corr['STRE'] = STR_corr['STRI_RT'] - STR_corr['STRC_RT']
# Out:
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
OBE_corr.corr()

# %%
sns.set(font_scale=0.2)
mpl.rcParams['axes.unicode_minus'] = False
path = 'C:/Windows/Fonts/HYSNRL.ttf'
font_name = fm.FontProperties(fname=path).get_name()
plt.rc('font', family=font_name)


sns.heatmap(OBE_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('heatmap.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.4)
sns.heatmap(CBTT_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('CBTT_corr.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.4)
sns.heatmap(GNG_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('GNG_corr.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.4)
sns.heatmap(TWOBACK_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('TWOBACK_corr.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.4)
sns.heatmap(STR_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('STR_corr.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.4)
sns.heatmap(REPEAT_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('REPEAT_corr.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.4)
sns.heatmap(MIND_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('MIND_corr.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.4)
sns.heatmap(FOLD_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('FOLD_corr.png', format='png', dpi=500)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.set(font_scale=0.2)
sns.heatmap(OBE_s_corr.corr(), annot=True, fmt=".2f" )
plt.savefig('OBE_s_corr.png', format='png', dpi=500)
plt.show

# %%
for feature in List_s_k1:
    print(feature)
    if 'CBTT' in feature or 'GNG' in feature or 'TWOBACK' in feature or 'STR' in feature or 'REPEAT' in feature or 'MIND' in feature or 'FOLD' in feature: 
        sns.jointplot(data=List_s_k1, x='age', y=feature, kind='reg', color='g')
        plt.savefig('%s_age0716.png' % feature, format = 'png', dpi=500)
        plt.show()
    else:
        print('pass')
        pass
# Out:
# parentUUID
# pass
# taskUUID
# pass
# parentName
# pass
# childName
# pass
# childSex
# pass
# childBirth
# pass
# taskCreated
# pass
# taskUpdated
# pass
# completed
# pass
# age
# pass
# CBTTF_Cor
# CBTTF_ACC
# CBTTF_max
# CBTTB_Cor
# CBTTB_ACC
# CBTTB_max
# GNG_Cor
# GNG_RT
# GNG_ACC
# GNG_max
# TWOBACK_Cor
# TWOBACK_RT
# TWOBACK_ACC
# STRC_Cor
# STRC_RT
# STRC_ACC
# STRI_Cor
# STRI_RT
# STRI_ACC
# REPEAT_Cor
# REPEAT_ACC
# REPEAT_max
# MIND_Cor
# MIND_ACC
# MIND_max
# FOLD_Cor
# FOLD_ACC
# FOLD_max
# GNG_z
# STRC_z
# STRI_z
# STRE
# STRE_z
# CBTTF_score
# CBTTB_score
# GNG_score
# REPEAT_score
# FOLD_score
# 검사일자
# pass
# 검사장소
# pass
# 아동연구번호
# pass
# 아동명
# pass
# 성별
# pass
# 생년월일
# pass
# 연령(세.개월)
# pass
# K-WISC-V 검사자
# pass
# toamc_raw
# pass
# tomac_z_score
# pass
# Similarities_raw
# pass
# Similarities_z_score
# pass
# Matrix_raw
# pass
# Matrix_z_score
# pass
# Digit_raw
# pass
# Digit_z_score
# pass
# Symbol_raw
# pass
# Symbol_z_score
# pass
# Vocabulary_raw
# pass
# Vocabulary_z_score
# pass
# weight_raw
# pass
# weight_z_score
# pass

# %%
List_s_k_fillna = pd.read_excel('1.xlsx')

# %%
for feature in List_s_k_fillna:
    print('------'+feature+'------------------------------------------------')
#     if 'CBTT' in feature or 'GNG' in feature or 'STR' in feature or 'REPEAT' in feature or 'MIND' in feature or 'FODL' in feature: 
    if 'CBTT' in feature or 'GNG' in feature or 'STR' in feature or 'MIND' in feature or 'FOLD' in feature: 
        X = List_s_k_fillna.age.values.reshape((-1,1))
        y = List_s_k_fillna[feature].values
        model_sci = LinearRegression()
        model_sci.fit(X, y)
        params = np.append(model_sci.intercept_,model_sci.coef_)
        predictions = model_sci.predict(X)

        newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
        MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

        # Note if you don't want to use a DataFrame replace the two lines above with
        # newX = np.append(np.ones((len(X),1)), X, axis=1)
        # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

        var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
        sd_b = np.sqrt(var_b)
        ts_b = params/ sd_b

        p_values =[2*(1-st.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

        sd_b = np.round(sd_b,3)
        ts_b = np.round(ts_b,3)
#         p_values = np.round(p_values, 3)
        params = np.round(params,4)

        myDF3 = pd.DataFrame()
        myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilites"] = [params,sd_b,ts_b,p_values]
        print(myDF3)
       
        r_sq = model_sci.score(X, y)
        print('coefficient of determination:', r_sq)
        print('slope:', model_sci.coef_)
        print('intercept:', model_sci.intercept_)
        model_ols = sm.OLS(y, X)
        result = model_ols.fit()
        print(result.summary())
        print()
    else:
        print('pass')
        pass
# Out:
# ------Unnamed: 0------------------------------------------------
# pass
# ------parentUUID------------------------------------------------
# pass
# ------taskUUID------------------------------------------------
# pass
# ------parentName------------------------------------------------
# pass
# ------childName------------------------------------------------
# pass
# ------childSex------------------------------------------------
# pass
# ------childBirth------------------------------------------------
# pass
# ------taskCreated------------------------------------------------
# pass
# ------taskUpdated------------------------------------------------
# pass
# ------completed------------------------------------------------
# pass
# ------age------------------------------------------------
# pass
# ------CBTTF_Cor------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        2.1327            0.842     2.534      0.013634
# 1        0.4324            0.090     4.827      0.000008
# coefficient of determination: 0.2609394238859678
# slope: [0.43239625]
# intercept: 2.1326876131978896
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     1595.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.92e-48
# Time:                        10:58:08   Log-Likelihood:                -112.38
# No. Observations:                  68   AIC:                             226.8
# Df Residuals:                      67   BIC:                             229.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6558      0.016     39.932      0.000       0.623       0.689
# ==============================================================================
# Omnibus:                        0.907   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.635   Jarque-Bera (JB):                0.399
# Skew:                          -0.138   Prob(JB):                        0.819
# Kurtosis:                       3.253   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------CBTTF_ACC------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.2300            0.094     2.454      0.016744
# 1        0.0487            0.010     4.885      0.000007
# coefficient of determination: 0.265525037428184
# slope: [0.04871337]
# intercept: 0.229956864495017
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     1594.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.93e-48
# Time:                        10:58:08   Log-Likelihood:                 37.084
# No. Observations:                  68   AIC:                            -72.17
# Df Residuals:                      67   BIC:                            -69.95
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0728      0.002     39.926      0.000       0.069       0.076
# ==============================================================================
# Omnibus:                        0.859   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.651   Jarque-Bera (JB):                0.356
# Skew:                          -0.122   Prob(JB):                        0.837
# Kurtosis:                       3.257   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------CBTTF_max------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        3.7285            0.488     7.644  1.052722e-10
# 1        0.1995            0.052     3.843  2.726296e-04
# coefficient of determination: 0.1828605288568922
# slope: [0.19946452]
# intercept: 3.7284825576817067
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     2237.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.33e-53
# Time:                        10:58:08   Log-Likelihood:                -93.675
# No. Observations:                  68   AIC:                             189.3
# Df Residuals:                      67   BIC:                             191.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5900      0.012     47.300      0.000       0.565       0.615
# ==============================================================================
# Omnibus:                        2.568   Durbin-Watson:                   1.833
# Prob(Omnibus):                  0.277   Jarque-Bera (JB):                1.873
# Skew:                           0.224   Prob(JB):                        0.392
# Kurtosis:                       2.322   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------CBTTB_Cor------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.3743            0.995     0.376  7.080047e-01
# 1        0.5716            0.106     5.398  9.528668e-07
# coefficient of determination: 0.30629572743373756
# slope: [0.57161981]
# intercept: 0.37428143948342285
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     1084.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           4.25e-43
# Time:                        10:58:08   Log-Likelihood:                -120.67
# No. Observations:                  68   AIC:                             243.3
# Df Residuals:                      67   BIC:                             245.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6108      0.019     32.922      0.000       0.574       0.648
# ==============================================================================
# Omnibus:                        4.331   Durbin-Watson:                   2.286
# Prob(Omnibus):                  0.115   Jarque-Bera (JB):                3.456
# Skew:                          -0.507   Prob(JB):                        0.178
# Kurtosis:                       3.437   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------CBTTB_ACC------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.0281            0.110     0.255  7.992013e-01
# 1        0.0646            0.012     5.523  5.868692e-07
# coefficient of determination: 0.3160645095026149
# slope: [0.06456939]
# intercept: 0.02805995222720936
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     1087.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.86e-43
# Time:                        10:58:08   Log-Likelihood:                 29.205
# No. Observations:                  68   AIC:                            -56.41
# Df Residuals:                      67   BIC:                            -54.19
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0675      0.002     32.973      0.000       0.063       0.072
# ==============================================================================
# Omnibus:                        4.187   Durbin-Watson:                   2.252
# Prob(Omnibus):                  0.123   Jarque-Bera (JB):                3.308
# Skew:                          -0.492   Prob(JB):                        0.191
# Kurtosis:                       3.448   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------CBTTB_max------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        2.6372            0.548     4.816      0.000009
# 1        0.2825            0.058     4.847      0.000008
# coefficient of determination: 0.2625538866184267
# slope: [0.28246319]
# intercept: 2.637215528781794
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     2221.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           4.25e-53
# Time:                        10:58:08   Log-Likelihood:                -90.224
# No. Observations:                  68   AIC:                             182.4
# Df Residuals:                      67   BIC:                             184.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5587      0.012     47.122      0.000       0.535       0.582
# ==============================================================================
# Omnibus:                        0.884   Durbin-Watson:                   1.787
# Prob(Omnibus):                  0.643   Jarque-Bera (JB):                0.333
# Skew:                           0.040   Prob(JB):                        0.846
# Kurtosis:                       3.334   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------GNG_Cor------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0       37.0821            3.413    10.864  2.220446e-16
# 1        2.1151            0.363     5.823  1.794538e-07
# coefficient of determination: 0.33941306176449504
# slope: [2.11512718]
# intercept: 37.08213245137412
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     3194.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.94e-58
# Time:                        10:58:08   Log-Likelihood:                -239.28
# No. Observations:                  68   AIC:                             480.6
# Df Residuals:                      67   BIC:                             482.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             5.9993      0.106     56.514      0.000       5.787       6.211
# ==============================================================================
# Omnibus:                        4.357   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.113   Jarque-Bera (JB):                3.814
# Skew:                          -0.352   Prob(JB):                        0.149
# Kurtosis:                       3.923   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------GNG_RT------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0      991.5419           65.436    15.153      0.000000
# 1      -18.9304            6.963    -2.719      0.008339
# coefficient of determination: 0.10070482791938185
# slope: [-18.93041047]
# intercept: 991.5419492622165
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     1084.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           4.22e-43
# Time:                        10:58:08   Log-Likelihood:                -456.23
# No. Observations:                  68   AIC:                             914.5
# Df Residuals:                      67   BIC:                             916.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            84.9297      2.579     32.927      0.000      79.781      90.078
# ==============================================================================
# Omnibus:                        7.251   Durbin-Watson:                   1.669
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                2.744
# Skew:                          -0.095   Prob(JB):                        0.254
# Kurtosis:                       2.034   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------GNG_ACC------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.6555            0.033    19.862  0.000000e+00
# 1        0.0234            0.004     6.671  5.853582e-09
# coefficient of determination: 0.40271876060332457
# slope: [0.0234291]
# intercept: 0.6555240452018586
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     3217.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.33e-58
# Time:                        10:58:08   Log-Likelihood:                 44.970
# No. Observations:                  68   AIC:                            -87.94
# Df Residuals:                      67   BIC:                            -85.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0921      0.002     56.716      0.000       0.089       0.095
# ==============================================================================
# Omnibus:                        0.648   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.723   Jarque-Bera (JB):                0.717
# Skew:                           0.003   Prob(JB):                        0.699
# Kurtosis:                       2.497   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------GNG_max------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0         4.759            0.952     5.000  4.384263e-06
# 1         0.573            0.101     5.657  3.470856e-07
# coefficient of determination: 0.3265073661395792
# slope: [0.5729585]
# intercept: 4.758957398220332
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     2649.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.35e-55
# Time:                        10:58:08   Log-Likelihood:                -128.50
# No. Observations:                  68   AIC:                             259.0
# Df Residuals:                      67   BIC:                             261.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.0714      0.021     51.469      0.000       1.030       1.113
# ==============================================================================
# Omnibus:                        0.846   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.655   Jarque-Bera (JB):                0.372
# Skew:                          -0.144   Prob(JB):                        0.830
# Kurtosis:                       3.221   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------TWOBACK_Cor------------------------------------------------
# pass
# ------TWOBACK_RT------------------------------------------------
# pass
# ------TWOBACK_ACC------------------------------------------------
# pass
# ------STRC_Cor------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0       40.8036            1.530    26.677      0.000000
# 1        0.2597            0.163     1.596      0.115282
# coefficient of determination: 0.037142614981464095
# slope: [0.25970549]
# intercept: 40.803606583195524
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     2149.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.22e-52
# Time:                        10:58:08   Log-Likelihood:                -233.70
# No. Observations:                  68   AIC:                             469.4
# Df Residuals:                      67   BIC:                             471.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             4.5337      0.098     46.362      0.000       4.339       4.729
# ==============================================================================
# Omnibus:                        2.520   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.284   Jarque-Bera (JB):                1.562
# Skew:                          -0.075   Prob(JB):                        0.458
# Kurtosis:                       2.273   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------STRC_RT------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0     1480.5258           74.291    19.929      0.000000
# 1      -24.8927            7.906    -3.149      0.002449
# coefficient of determination: 0.13060034984727897
# slope: [-24.89266481]
# intercept: 1480.525769381828
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     1261.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.47e-45
# Time:                        10:58:08   Log-Likelihood:                -480.13
# No. Observations:                  68   AIC:                             962.3
# Df Residuals:                      67   BIC:                             964.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           130.1866      3.666     35.517      0.000     122.870     137.503
# ==============================================================================
# Omnibus:                        4.278   Durbin-Watson:                   1.719
# Prob(Omnibus):                  0.118   Jarque-Bera (JB):                2.032
# Skew:                           0.008   Prob(JB):                        0.362
# Kurtosis:                       2.153   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------STRC_ACC------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.9118            0.033    27.347      0.000000
# 1        0.0056            0.004     1.578      0.119188
# coefficient of determination: 0.036373796259235536
# slope: [0.00559988]
# intercept: 0.9117692950969792
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     2150.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.22e-52
# Time:                        10:58:08   Log-Likelihood:                 24.917
# No. Observations:                  68   AIC:                            -47.83
# Df Residuals:                      67   BIC:                            -45.62
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1011      0.002     46.364      0.000       0.097       0.105
# ==============================================================================
# Omnibus:                        2.462   Durbin-Watson:                   1.461
# Prob(Omnibus):                  0.292   Jarque-Bera (JB):                1.541
# Skew:                          -0.073   Prob(JB):                        0.463
# Kurtosis:                       2.277   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------STRI_Cor------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0       25.7923            3.353     7.692  8.649215e-11
# 1        1.6091            0.357     4.509  2.683007e-05
# coefficient of determination: 0.23553978850347013
# slope: [1.60910308]
# intercept: 25.79226710764627
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     2512.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           7.62e-55
# Time:                        10:58:08   Log-Likelihood:                -224.97
# No. Observations:                  68   AIC:                             451.9
# Df Residuals:                      67   BIC:                             454.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             4.3107      0.086     50.121      0.000       4.139       4.482
# ==============================================================================
# Omnibus:                        0.995   Durbin-Watson:                   1.513
# Prob(Omnibus):                  0.608   Jarque-Bera (JB):                0.921
# Skew:                           0.056   Prob(JB):                        0.631
# Kurtosis:                       2.441   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------STRI_RT------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0     1697.1236           94.472    17.964      0.000000
# 1      -43.6750           10.053    -4.344      0.000048
# coefficient of determination: 0.22237764083091885
# slope: [-43.67503068]
# intercept: 1697.1236292106698
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                     986.0
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           8.37e-42
# Time:                        10:58:08   Log-Likelihood:                -490.51
# No. Observations:                  68   AIC:                             983.0
# Df Residuals:                      67   BIC:                             985.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           134.0920      4.270     31.401      0.000     125.568     142.615
# ==============================================================================
# Omnibus:                        3.863   Durbin-Watson:                   1.455
# Prob(Omnibus):                  0.145   Jarque-Bera (JB):                1.935
# Skew:                           0.037   Prob(JB):                        0.380
# Kurtosis:                       2.177   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------STRI_ACC------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.5840            0.076     7.676  9.248602e-11
# 1        0.0348            0.008     4.296  5.745861e-05
# coefficient of determination: 0.21854764605421206
# slope: [0.03478349]
# intercept: 0.5839815497634235
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     2423.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.49e-54
# Time:                        10:58:08   Log-Likelihood:                 32.536
# No. Observations:                  68   AIC:                            -63.07
# Df Residuals:                      67   BIC:                            -60.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0960      0.002     49.219      0.000       0.092       0.100
# ==============================================================================
# Omnibus:                        1.040   Durbin-Watson:                   1.545
# Prob(Omnibus):                  0.594   Jarque-Bera (JB):                0.933
# Skew:                           0.024   Prob(JB):                        0.627
# Kurtosis:                       2.428   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------REPEAT_Cor------------------------------------------------
# pass
# ------REPEAT_ACC------------------------------------------------
# pass
# ------REPEAT_max------------------------------------------------
# pass
# ------MIND_Cor------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        4.9985            1.622     3.082  2.986845e-03
# 1        1.0669            0.173     6.181  4.282654e-08
# coefficient of determination: 0.3666496117797762
# slope: [1.0669344]
# intercept: 4.998503819198362
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     2423.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.48e-54
# Time:                        10:58:08   Log-Likelihood:                -158.40
# No. Observations:                  68   AIC:                             318.8
# Df Residuals:                      67   BIC:                             321.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.5905      0.032     49.224      0.000       1.526       1.655
# ==============================================================================
# Omnibus:                        1.495   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.474   Jarque-Bera (JB):                1.139
# Skew:                          -0.010   Prob(JB):                        0.566
# Kurtosis:                       2.366   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------MIND_ACC------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.2499            0.081     3.082  2.986845e-03
# 1        0.0533            0.009     6.181  4.282654e-08
# coefficient of determination: 0.366649611779776
# slope: [0.05334672]
# intercept: 0.24992519095991805
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     2423.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.48e-54
# Time:                        10:58:08   Log-Likelihood:                 45.312
# No. Observations:                  68   AIC:                            -88.62
# Df Residuals:                      67   BIC:                            -86.40
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0795      0.002     49.224      0.000       0.076       0.083
# ==============================================================================
# Omnibus:                        1.495   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.474   Jarque-Bera (JB):                1.139
# Skew:                          -0.010   Prob(JB):                        0.566
# Kurtosis:                       2.366   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------MIND_max------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0          20.0              0.0       inf           0.0
# 1           0.0              0.0       NaN           NaN
# coefficient of determination: 1.0
# slope: [0.]
# intercept: 20.0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     2087.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.17e-52
# Time:                        10:58:08   Log-Likelihood:                -182.20
# No. Observations:                  68   AIC:                             366.4
# Df Residuals:                      67   BIC:                             368.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             2.0949      0.046     45.688      0.000       2.003       2.186
# ==============================================================================
# Omnibus:                       11.120   Durbin-Watson:                   1.572
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):                3.303
# Skew:                          -0.064   Prob(JB):                        0.192
# Kurtosis:                       1.928   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------FOLD_Cor------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0       -2.3189            1.348    -1.720  9.011331e-02
# 1        0.9518            0.143     6.633  6.837332e-09
# coefficient of determination: 0.39997545373930443
# slope: [0.95180723]
# intercept: -2.3189227498228204
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     762.5
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.50e-38
# Time:                        10:58:08   Log-Likelihood:                -142.76
# No. Observations:                  68   AIC:                             287.5
# Df Residuals:                      67   BIC:                             289.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7089      0.026     27.613      0.000       0.658       0.760
# ==============================================================================
# Omnibus:                        2.311   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.315   Jarque-Bera (JB):                1.898
# Skew:                           0.268   Prob(JB):                        0.387
# Kurtosis:                       2.382   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------FOLD_ACC------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0       -0.1656            0.096    -1.720  9.011331e-02
# 1        0.0680            0.010     6.633  6.837332e-09
# coefficient of determination: 0.39997545373930454
# slope: [0.06798623]
# intercept: -0.16563733927305868
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     762.5
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.50e-38
# Time:                        10:58:08   Log-Likelihood:                 36.698
# No. Observations:                  68   AIC:                            -71.40
# Df Residuals:                      67   BIC:                            -69.18
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0506      0.002     27.613      0.000       0.047       0.054
# ==============================================================================
# Omnibus:                        2.311   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.315   Jarque-Bera (JB):                1.898
# Skew:                           0.268   Prob(JB):                        0.387
# Kurtosis:                       2.382   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------FOLD_max------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0          14.0              0.0       inf           0.0
# 1           0.0              0.0       NaN           NaN
# coefficient of determination: 1.0
# slope: [0.]
# intercept: 14.0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     2087.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.17e-52
# Time:                        10:58:08   Log-Likelihood:                -157.94
# No. Observations:                  68   AIC:                             317.9
# Df Residuals:                      67   BIC:                             320.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.4664      0.032     45.688      0.000       1.402       1.531
# ==============================================================================
# Omnibus:                       11.120   Durbin-Watson:                   1.572
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):                3.303
# Skew:                          -0.064   Prob(JB):                        0.192
# Kurtosis:                       1.928   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------GNG_z------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.5581            0.105     5.308      0.000001
# 1        0.0573            0.011     5.119      0.000003
# coefficient of determination: 0.2841961174142119
# slope: [0.05728035]
# intercept: 0.5581489499082081
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     2448.
# ...
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------STRE------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.2861            0.058     4.895      0.000006
# 1       -0.0172            0.006    -2.772      0.007209
# coefficient of determination: 0.10427548812925513
# slope: [-0.01723939]
# intercept: 0.28610607627034
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     100.3
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           6.02e-15
# Time:                        10:58:08   Log-Likelihood:                 61.629
# No. Observations:                  68   AIC:                            -121.3
# Df Residuals:                      67   BIC:                            -119.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0127      0.001     10.016      0.000       0.010       0.015
# ==============================================================================
# Omnibus:                        3.906   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.142   Jarque-Bera (JB):                3.802
# Skew:                           0.534   Prob(JB):                        0.149
# Kurtosis:                       2.554   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1738: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= self.b) & cond0
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\OBELAB_JH_DESKTOP\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1738: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= self.b) & cond0
# ------STRE_z------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.3728            0.069     5.421  8.738715e-07
# 1       -0.0255            0.007    -3.488  8.646574e-04
# coefficient of determination: 0.15563995305391953
# slope: [-0.02552418]
# intercept: 0.37276037624054714
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     77.11
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           9.44e-13
# Time:                        10:58:08   Log-Likelihood:                 48.581
# No. Observations:                  68   AIC:                            -95.16
# Df Residuals:                      67   BIC:                            -92.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0135      0.002      8.781      0.000       0.010       0.017
# ==============================================================================
# Omnibus:                       20.536   Durbin-Watson:                   1.621
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.100
# Skew:                           1.201   Prob(JB):                     4.80e-07
# Kurtosis:                       5.122   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------CBTTF_score------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.4984            0.913     0.546      0.587115
# 1        0.4652            0.097     4.786      0.000010
# coefficient of determination: 0.2576259079023535
# slope: [0.46519411]
# intercept: 0.49842507284038184
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     920.7
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           7.17e-41
# Time:                        10:58:08   Log-Likelihood:                -114.93
# No. Observations:                  68   AIC:                             231.9
# Df Residuals:                      67   BIC:                             234.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5174      0.017     30.343      0.000       0.483       0.551
# ==============================================================================
# Omnibus:                        0.036   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.982   Jarque-Bera (JB):                0.190
# Skew:                           0.035   Prob(JB):                        0.910
# Kurtosis:                       2.751   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------CBTTB_score------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0       -1.0332            0.985    -1.048  2.981787e-01
# 1        0.5758            0.105     5.491  6.651922e-07
# coefficient of determination: 0.31355175824134796
# slope: [0.57576975]
# intercept: -1.033223088432159
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     638.3
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           5.78e-36
# Time:                        10:58:08   Log-Likelihood:                -120.50
# No. Observations:                  68   AIC:                             243.0
# Df Residuals:                      67   BIC:                             245.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4675      0.019     25.264      0.000       0.431       0.504
# ==============================================================================
# Omnibus:                        0.365   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.833   Jarque-Bera (JB):                0.363
# Skew:                          -0.164   Prob(JB):                        0.834
# Kurtosis:                       2.855   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------GNG_score------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0        8.8107            4.277     2.060  4.329000e-02
# 1        2.5858            0.455     5.681  3.148229e-07
# coefficient of determination: 0.32843076958826345
# slope: [2.58580991]
# intercept: 8.81067013150642
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     1823.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.57e-50
# Time:                        10:58:08   Log-Likelihood:                -221.88
# No. Observations:                  68   AIC:                             445.8
# Df Residuals:                      67   BIC:                             448.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             3.5087      0.082     42.693      0.000       3.345       3.673
# ==============================================================================
# Omnibus:                        4.700   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.116
# Skew:                          -0.392   Prob(JB):                        0.128
# Kurtosis:                       3.915   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------REPEAT_score------------------------------------------------
# pass
# ------FOLD_score------------------------------------------------
#    Coefficients  Standard Errors  t values  Probabilites
# 0       -9.1391            2.946    -3.102  2.808986e-03
# 1        2.3266            0.313     7.422  2.645371e-10
# coefficient of determination: 0.45494971724533273
# slope: [2.32663989]
# intercept: -9.139066068194346
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     543.6
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           7.27e-34
# Time:                        10:58:08   Log-Likelihood:                -199.03
# No. Observations:                  68   AIC:                             400.1
# Df Residuals:                      67   BIC:                             402.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.3694      0.059     23.316      0.000       1.252       1.487
# ==============================================================================
# Omnibus:                        1.673   Durbin-Watson:                   1.737
# Prob(Omnibus):                  0.433   Jarque-Bera (JB):                1.533
# Skew:                           0.247   Prob(JB):                        0.465
# Kurtosis:                       2.454   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------검사일자------------------------------------------------
# pass
# ------검사장소------------------------------------------------
# pass
# ------아동연구번호------------------------------------------------
# pass
# ------아동명------------------------------------------------
# pass
# ------성별------------------------------------------------
# pass
# ------생년월일------------------------------------------------
# pass
# ------연령(세.개월)------------------------------------------------
# pass
# ------K-WISC-V 검사자------------------------------------------------
# pass
# ------toamc_raw------------------------------------------------
# pass
# ------tomac_z_score------------------------------------------------
# pass
# ------Similarities_raw------------------------------------------------
# pass
# ------Similarities_z_score------------------------------------------------
# pass
# ------Matrix_raw------------------------------------------------
# pass
# ------Matrix_z_score------------------------------------------------
# pass
# ------Digit_raw------------------------------------------------
# pass
# ------Digit_z_score------------------------------------------------
# pass
# ------Symbol_raw------------------------------------------------
# pass
# ------Symbol_z_score------------------------------------------------
# pass
# ------Vocabulary_raw------------------------------------------------
# pass
# ------Vocabulary_z_score------------------------------------------------
# pass
# ------weight_raw------------------------------------------------
# pass
# ------weight_z_score------------------------------------------------
# pass

# %%
for feature in List_s_k1_1:
    if 'CBTTB_ACC' in feature or 'CBTTB_score' in feature: 
        print('------'+feature+'------')
        for feature1 in List_s_k1_1:
            if 'toamc_raw' in feature1 or 'Similarities_raw' in feature1 or 'Matrix_raw' in feature1 or 'Digit_raw' in feature1 or 'Symbol_raw' in feature1 or 'Vocabulary_raw' in feature1 or 'weight_raw' in feature1 :
                print('+++++++'+feature1+'+++++++')
                X = List_s_k1_1[feature1].values.reshape((-1,1))
                y = List_s_k1_1[feature].values
                model_sci = LinearRegression()
                model_sci.fit(X, y)
                params = np.append(model_sci.intercept_,model_sci.coef_)
                predictions = model_sci.predict(X)

                newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
                MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

                # Note if you don't want to use a DataFrame replace the two lines above with
                # newX = np.append(np.ones((len(X),1)), X, axis=1)
                # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

                var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
                sd_b = np.sqrt(var_b)
                ts_b = params/ sd_b

                p_values =[2*(1-st.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

                sd_b = np.round(sd_b,3)
                ts_b = np.round(ts_b,3)
                p_values = np.round(p_values, 3)
                params = np.round(params,4)

                myDF3 = pd.DataFrame()
                myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilites"] = [params,sd_b,ts_b,p_values]
                print(myDF3)

                r_sq = model_sci.score(X, y)
                print('coefficient of determination:', r_sq)
                print('slope:', model_sci.coef_)
                print('intercept:', model_sci.intercept_)
                model_ols = sm.OLS(y, X)
                result = model_ols.fit()
                print(result.summary())
                print()
            else:
                pass
    else:
        pass

# %%
for feature in List_s_k_fillna:
    if 'GNG_z' in feature or 'GNG_score' in feature: 
        print('------'+feature+'------')
        for feature1 in List_s_k_fillna:
            if 'toamc_raw' in feature1 or 'Similarities_raw' in feature1 or 'Matrix_raw' in feature1 or 'Digit_raw' in feature1 or 'Symbol_raw' in feature1 or 'Vocabulary_raw' in feature1 or 'weight_raw' in feature1 :
                print('+++++++'+feature1+'+++++++')
                X = List_s_k_fillna[feature1].values.reshape((-1,1))
                y = List_s_k_fillna[feature].values
                model_sci = LinearRegression()
                model_sci.fit(X, y)
                params = np.append(model_sci.intercept_,model_sci.coef_)
                predictions = model_sci.predict(X)

                newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
                MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

                # Note if you don't want to use a DataFrame replace the two lines above with
                # newX = np.append(np.ones((len(X),1)), X, axis=1)
                # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

                var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
                sd_b = np.sqrt(var_b)
                ts_b = params/ sd_b

                p_values =[2*(1-st.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

                sd_b = np.round(sd_b,3)
                ts_b = np.round(ts_b,3)
                p_values = np.round(p_values, 3)
                params = np.round(params,4)

                myDF3 = pd.DataFrame()
                myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilites"] = [params,sd_b,ts_b,p_values]
                print(myDF3)

                r_sq = model_sci.score(X, y)
                print('coefficient of determination:', r_sq)
                print('slope:', model_sci.coef_)
                print('intercept:', model_sci.intercept_)
                model_ols = sm.OLS(y, X)
                result = model_ols.fit()
                print(result.summary())
                print()
            else:
                pass
    else:
        pass
# Out:
# ------GNG_z------
# +++++++toamc_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.8239            0.082    10.022         0.000
# 1        0.0077            0.002     3.315         0.001
# coefficient of determination: 0.14276763933630932
# slope: [0.00765197]
# intercept: 0.823886626455437
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     1121.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.47e-43
# Time:                        11:06:26   Log-Likelihood:                -5.3593
# No. Observations:                  68   AIC:                             12.72
# Df Residuals:                      67   BIC:                             14.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0301      0.001     33.482      0.000       0.028       0.032
# ==============================================================================
# Omnibus:                        1.859   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.395   Jarque-Bera (JB):                1.314
# Skew:                          -0.068   Prob(JB):                        0.518
# Kurtosis:                       2.332   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Similarities_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.8938            0.064    13.885         0.000
# 1        0.0085            0.003     3.182         0.002
# coefficient of determination: 0.13297038444371723
# slope: [0.00846617]
# intercept: 0.893768247480963
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     688.5
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           5.76e-37
# Time:                        11:06:26   Log-Likelihood:                -20.751
# No. Observations:                  68   AIC:                             43.50
# Df Residuals:                      67   BIC:                             45.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0435      0.002     26.239      0.000       0.040       0.047
# ==============================================================================
# Omnibus:                        1.018   Durbin-Watson:                   1.463
# Prob(Omnibus):                  0.601   Jarque-Bera (JB):                0.786
# Skew:                           0.263   Prob(JB):                        0.675
# Kurtosis:                       2.977   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Matrix_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.8681            0.097     8.904         0.000
# 1        0.0115            0.005     2.311         0.024
# coefficient of determination: 0.07484449210853761
# slope: [0.01153978]
# intercept: 0.8680575113976923
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     1194.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.98e-44
# Time:                        11:06:26   Log-Likelihood:                -3.3284
# No. Observations:                  68   AIC:                             8.657
# Df Residuals:                      67   BIC:                             10.88
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0550      0.002     34.556      0.000       0.052       0.058
# ==============================================================================
# Omnibus:                        1.877   Durbin-Watson:                   1.599
# Prob(Omnibus):                  0.391   Jarque-Bera (JB):                1.872
# Skew:                          -0.353   Prob(JB):                        0.392
# Kurtosis:                       2.598   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Digit_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.8342            0.086     9.723         0.000
# 1        0.0097            0.003     3.046         0.003
# coefficient of determination: 0.12325943106468662
# slope: [0.00974929]
# intercept: 0.8342239427620909
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     1137.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           9.28e-44
# Time:                        11:06:26   Log-Likelihood:                -4.8944
# No. Observations:                  68   AIC:                             11.79
# Df Residuals:                      67   BIC:                             14.01
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0400      0.001     33.725      0.000       0.038       0.042
# ==============================================================================
# Omnibus:                        1.824   Durbin-Watson:                   1.537
# Prob(Omnibus):                  0.402   Jarque-Bera (JB):                1.787
# Skew:                          -0.374   Prob(JB):                        0.409
# Kurtosis:                       2.731   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Symbol_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.8413            0.078    10.776         0.000
# 1        0.0051            0.002     3.273         0.002
# coefficient of determination: 0.13963604479770042
# slope: [0.00509883]
# intercept: 0.8412989596796038
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     1015.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.39e-42
# Time:                        11:06:26   Log-Likelihood:                -8.5444
# No. Observations:                  68   AIC:                             19.09
# Df Residuals:                      67   BIC:                             21.31
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0213      0.001     31.856      0.000       0.020       0.023
# ==============================================================================
# Omnibus:                        4.818   Durbin-Watson:                   2.164
# Prob(Omnibus):                  0.090   Jarque-Bera (JB):                3.911
# Skew:                          -0.511   Prob(JB):                        0.141
# Kurtosis:                       3.580   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Vocabulary_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.9514            0.052    18.292         0.000
# 1        0.0060            0.002     2.862         0.006
# coefficient of determination: 0.110421247654784
# slope: [0.00597354]
# intercept: 0.9513915266680679
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     408.7
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.19e-30
# Time:                        11:06:26   Log-Likelihood:                -36.481
# No. Observations:                  68   AIC:                             74.96
# Df Residuals:                      67   BIC:                             77.18
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0410      0.002     20.215      0.000       0.037       0.045
# ==============================================================================
# Omnibus:                        8.709   Durbin-Watson:                   1.592
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.700
# Skew:                          -0.870   Prob(JB):                       0.0129
# Kurtosis:                       3.207   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++weight_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0        0.8165            0.080    10.211         0.000
# 1        0.0128            0.004     3.508         0.001
# coefficient of determination: 0.15716487030829185
# slope: [0.01275841]
# intercept: 0.8165007920527357
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     1114.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.78e-43
# Time:                        11:06:26   Log-Likelihood:                -5.5544
# No. Observations:                  68   AIC:                             13.11
# Df Residuals:                      67   BIC:                             15.33
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0487      0.001     33.380      0.000       0.046       0.052
# ==============================================================================
# Omnibus:                        1.087   Durbin-Watson:                   1.747
# Prob(Omnibus):                  0.581   Jarque-Bera (JB):                1.071
# Skew:                           0.165   Prob(JB):                        0.585
# Kurtosis:                       2.482   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ------GNG_score------
# +++++++toamc_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0       20.0398            3.362     5.961           0.0
# 1        0.3677            0.094     3.895           0.0
# coefficient of determination: 0.18690197552557652
# slope: [0.3676576]
# intercept: 20.039817889362894
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     1013.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           3.61e-42
# Time:                        11:06:26   Log-Likelihood:                -240.91
# No. Observations:                  68   AIC:                             483.8
# Df Residuals:                      67   BIC:                             486.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.9129      0.029     31.825      0.000       0.856       0.970
# ==============================================================================
# Omnibus:                        1.480   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.477   Jarque-Bera (JB):                1.242
# Skew:                           0.143   Prob(JB):                        0.537
# Kurtosis:                       2.403   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Similarities_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0       22.5480            2.585     8.724           0.0
# 1        0.4438            0.107     4.153           0.0
# coefficient of determination: 0.2072096021119384
# slope: [0.44380552]
# intercept: 22.547991058297548
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.915
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     724.3
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.22e-37
# Time:                        11:06:26   Log-Likelihood:                -251.48
# No. Observations:                  68   AIC:                             505.0
# Df Residuals:                      67   BIC:                             507.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.3279      0.049     26.913      0.000       1.229       1.426
# ==============================================================================
# Omnibus:                        1.027   Durbin-Watson:                   1.698
# Prob(Omnibus):                  0.598   Jarque-Bera (JB):                1.067
# Skew:                           0.192   Prob(JB):                        0.586
# Kurtosis:                       2.522   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Matrix_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0       19.1201            3.895     4.909         0.000
# 1        0.7141            0.200     3.579         0.001
# coefficient of determination: 0.16251274714894226
# slope: [0.71406796]
# intercept: 19.12011650485437
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     1114.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           1.77e-43
# Time:                        11:06:26   Log-Likelihood:                -237.85
# No. Observations:                  68   AIC:                             477.7
# Df Residuals:                      67   BIC:                             479.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.6704      0.050     33.383      0.000       1.570       1.770
# ==============================================================================
# Omnibus:                        0.919   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.632   Jarque-Bera (JB):                0.880
# Skew:                           0.053   Prob(JB):                        0.644
# Kurtosis:                       2.453   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Digit_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0       18.0355            3.367     5.357           0.0
# 1        0.5645            0.126     4.495           0.0
# coefficient of determination: 0.23434936496925218
# slope: [0.56451158]
# intercept: 18.035507353095884
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     1163.
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           4.64e-44
# Time:                        11:06:26   Log-Likelihood:                -236.49
# No. Observations:                  68   AIC:                             475.0
# Df Residuals:                      67   BIC:                             477.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.2178      0.036     34.096      0.000       1.146       1.289
# ==============================================================================
# Omnibus:                        1.343   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.511   Jarque-Bera (JB):                1.211
# Skew:                          -0.166   Prob(JB):                        0.546
# Kurtosis:                       2.437   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Symbol_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0       20.6947            3.184     6.500           0.0
# 1        0.2487            0.064     3.915           0.0
# coefficient of determination: 0.18844973001180332
# slope: [0.24874099]
# intercept: 20.6947374035487
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     947.8
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           2.90e-41
# Time:                        11:06:26   Log-Likelihood:                -243.02
# No. Observations:                  68   AIC:                             488.0
# Df Residuals:                      67   BIC:                             490.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6475      0.021     30.786      0.000       0.605       0.689
# ==============================================================================
# Omnibus:                        2.111   Durbin-Watson:                   2.335
# Prob(Omnibus):                  0.348   Jarque-Bera (JB):                1.366
# Skew:                          -0.273   Prob(JB):                        0.505
# Kurtosis:                       3.429   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++Vocabulary_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0       26.6443            2.167    12.295         0.000
# 1        0.2661            0.087     3.060         0.003
# coefficient of determination: 0.12425721287919757
# slope: [0.26609946]
# intercept: 26.644343296971677
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     401.7
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           5.23e-30
# Time:                        11:06:26   Log-Likelihood:                -269.28
# No. Observations:                  68   AIC:                             540.6
# Df Residuals:                      67   BIC:                             542.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.2472      0.062     20.043      0.000       1.123       1.371
# ==============================================================================
# Omnibus:                        6.925   Durbin-Watson:                   1.692
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                6.510
# Skew:                          -0.750   Prob(JB):                       0.0386
# Kurtosis:                       3.213   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# +++++++weight_raw+++++++
#    Coefficients  Standard Errors  t values  Probabilites
# 0       20.2262            3.294     6.141           0.0
# 1        0.5876            0.150     3.922           0.0
# coefficient of determination: 0.1890283353160358
# slope: [0.58757091]
# intercept: 20.226248454664265
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     992.9
# Date:                Tue, 16 Jul 2019   Prob (F-statistic):           6.73e-42
# Time:                        11:06:26   Log-Likelihood:                -241.54
# No. Observations:                  68   AIC:                             485.1
# Df Residuals:                      67   BIC:                             487.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.4779      0.047     31.510      0.000       1.384       1.572
# ==============================================================================
# Omnibus:                        1.205   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.548   Jarque-Bera (JB):                1.060
# Skew:                           0.301   Prob(JB):                        0.589
# Kurtosis:                       2.890   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for feature in List_s_k_fillna:
    if 'STRI_z' in feature or 'STRE_z' in feature: 
        print('------'+feature+'------')
        for feature1 in List_s_k_fillna:
            if 'toamc_raw' in feature1 or 'Similarities_raw' in feature1 or 'Matrix_raw' in feature1 or 'Digit_raw' in feature1 or 'Symbol_raw' in feature1 or 'Vocabulary_raw' in feature1 or 'weight_raw' in feature1 :
                print('+++++++'+feature1+'+++++++')
                X = List_s_k_fillna[feature1].values.reshape((-1,1))
                y = List_s_k_fillna[feature].values
                model_sci = LinearRegression()
                model_sci.fit(X, y)
                params = np.append(model_sci.intercept_,model_sci.coef_)
                predictions = model_sci.predict(X)

                newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
                MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

                # Note if you don't want to use a DataFrame replace the two lines above with
                # newX = np.append(np.ones((len(X),1)), X, axis=1)
                # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

                var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
                sd_b = np.sqrt(var_b)
                ts_b = params/ sd_b

                p_values =[2*(1-st.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

                sd_b = np.round(sd_b,3)
                ts_b = np.round(ts_b,3)
                p_values = np.round(p_values, 3)
                params = np.round(params,4)

                myDF3 = pd.DataFrame()
                myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilites"] = [params,sd_b,ts_b,p_values]
                print(myDF3)

                r_sq = model_sci.score(X, y)
                print('coefficient of determination:', r_sq)
                print('slope:', model_sci.coef_)
                print('intercept:', model_sci.intercept_)
                model_ols = sm.OLS(y, X)
                result = model_ols.fit()
                print(result.summary())
                print()
            else:
                pass
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-c7750a8edfd3> in <module>
# ----> 1 for feature in List_s_k1_1:
#       2     if 'STRI_z' in feature or 'STRE_z' in feature:
#       3         print('------'+feature+'------')
#       4         for feature1 in List_s_k1_1:
#       5             if 'toamc_raw' in feature1 or 'Similarities_raw' in feature1 or 'Matrix_raw' in feature1 or 'Digit_raw' in feature1 or 'Symbol_raw' in feature1 or 'Vocabulary_raw' in feature1 or 'weight_raw' in feature1 :
#
# NameError: name 'List_s_k1_1' is not defined

# %%
List_s_k1_2 = List_s_k1[List_s_k1.childName != '서태림']
List_s_k1_2 = List_s_k1_2[List_s_k1_2.childName != '최아영']

print(List_s_k1_2)
for feature in List_s_k1_2:
    if 'REPEAT_ACC' in feature or 'REPEAT_score' in feature: 
        print('------'+feature+'------')
        for feature1 in List_s_k1_2:
            if 'toamc_raw' in feature1 or 'Similarities_raw' in feature1 or 'Matrix_raw' in feature1 or 'Digit_raw' in feature1 or 'Symbol_raw' in feature1 or 'Vocabulary_raw' in feature1 or 'weight_raw' in feature1 :
                print('+++++++'+feature1+'+++++++')
                X = List_s_k1_2[feature1].values.reshape((-1,1))
                y = List_s_k1_2[feature].values
                model_sci = LinearRegression()
                model_sci.fit(X, y)
                params = np.append(model_sci.intercept_,model_sci.coef_)
                predictions = model_sci.predict(X)

                newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
                MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

                # Note if you don't want to use a DataFrame replace the two lines above with
                # newX = np.append(np.ones((len(X),1)), X, axis=1)
                # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

                var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
                sd_b = np.sqrt(var_b)
                ts_b = params/ sd_b

                p_values =[2*(1-st.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

                sd_b = np.round(sd_b,3)
                ts_b = np.round(ts_b,3)
                p_values = np.round(p_values, 3)
                params = np.round(params,4)

                myDF3 = pd.DataFrame()
                myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilites"] = [params,sd_b,ts_b,p_values]
                print(myDF3)

                r_sq = model_sci.score(X, y)
                print('coefficient of determination:', r_sq)
                print('slope:', model_sci.coef_)
                print('intercept:', model_sci.intercept_)
                model_ols = sm.OLS(y, X)
                result = model_ols.fit()
                print(result.summary())
                print()
            else:
                pass
    else:
        pass

# %%
for feature in List_s_k1_1:
    if 'MIND_ACC' in feature: 
        print('------'+feature+'------')
        for feature1 in List_s_k1_1:
            if 'toamc_raw' in feature1 or 'Similarities_raw' in feature1 or 'Matrix_raw' in feature1 or 'Digit_raw' in feature1 or 'Symbol_raw' in feature1 or 'Vocabulary_raw' in feature1 or 'weight_raw' in feature1 :
                print('+++++++'+feature1+'+++++++')
                X = List_s_k1_1[feature1].values.reshape((-1,1))
                y = List_s_k1_1[feature].values
                model_sci = LinearRegression()
                model_sci.fit(X, y)
                params = np.append(model_sci.intercept_,model_sci.coef_)
                predictions = model_sci.predict(X)

                newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
                MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

                # Note if you don't want to use a DataFrame replace the two lines above with
                # newX = np.append(np.ones((len(X),1)), X, axis=1)
                # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

                var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
                sd_b = np.sqrt(var_b)
                ts_b = params/ sd_b

                p_values =[2*(1-st.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

                sd_b = np.round(sd_b,3)
                ts_b = np.round(ts_b,3)
                p_values = np.round(p_values, 3)
                params = np.round(params,4)

                myDF3 = pd.DataFrame()
                myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilites"] = [params,sd_b,ts_b,p_values]
                print(myDF3)

                r_sq = model_sci.score(X, y)
                print('coefficient of determination:', r_sq)
                print('slope:', model_sci.coef_)
                print('intercept:', model_sci.intercept_)
                model_ols = sm.OLS(y, X)
                result = model_ols.fit()
                print(result.summary())
                print()
            else:
                pass
    else:
        pass

# %%
List_s_k1_3 = List_s_k1_1[List_s_k1_1.childName != '조윤우']
for feature in List_s_k1_3:
    if 'FOLD_ACC' in feature or 'FOLD_score' in feature: 
        print('------'+feature+'------')
        for feature1 in List_s_k1_3:
            if 'toamc_raw' in feature1 or 'Similarities_raw' in feature1 or 'Matrix_raw' in feature1 or 'Digit_raw' in feature1 or 'Symbol_raw' in feature1 or 'Vocabulary_raw' in feature1 or 'weight_raw' in feature1 :
                print('+++++++'+feature1+'+++++++')
                X = List_s_k1_3[feature1].values.reshape((-1,1))
                y = List_s_k1_3[feature].values
                model_sci = LinearRegression()
                model_sci.fit(X, y)
                params = np.append(model_sci.intercept_,model_sci.coef_)
                predictions = model_sci.predict(X)

                newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
                MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

                # Note if you don't want to use a DataFrame replace the two lines above with
                # newX = np.append(np.ones((len(X),1)), X, axis=1)
                # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

                var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
                sd_b = np.sqrt(var_b)
                ts_b = params/ sd_b

                p_values =[2*(1-st.t.cdf(np.abs(i),(len(newX)-1))) for i in ts_b]

                sd_b = np.round(sd_b,3)
                ts_b = np.round(ts_b,3)
                p_values = np.round(p_values, 3)
                params = np.round(params,4)

                myDF3 = pd.DataFrame()
                myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilites"] = [params,sd_b,ts_b,p_values]
                print(myDF3)

                r_sq = model_sci.score(X, y)
                print('coefficient of determination:', r_sq)
                print('slope:', model_sci.coef_)
                print('intercept:', model_sci.intercept_)
                model_ols = sm.OLS(y, X)
                result = model_ols.fit()
                print(result.summary())
                print()
            else:
                pass
    else:
        pass
